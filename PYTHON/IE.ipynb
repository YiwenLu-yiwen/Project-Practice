# %% [markdown]
# # Data Loading & Pre- cleaning

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

# %%
df = pd.read_excel('statefloracatalogdata.xlsx', sheet_name='StateFlora')

# %%
df.head()
# Out:
#                Type    Genus Tube colour           Botanical name  \
# 0  Trees and Shrubs  Acacia            B                acinacea
# 1  Trees and Shrubs  Acacia            B                   anceps
# 2  Trees and Shrubs  Acacia            B                   aneura
# 3  Trees and Shrubs  Acacia            B             argyrophylla
# 4  Trees and Shrubs  Acacia            B  baileyana var. purpurea
#
#                  Common name       States   NW   LE   NU   GT  \
# 0        round-leaved wattle      SA, N,V  NaN  NaN    I    I
# 1        Port Lincoln wattle        SA, W  NaN  NaN    I  NaN
# 2                      mulga  SA,Q,N,W,NT    I    I    I    I
# 3          golden-grey mulga         SA,V  NaN  NaN  NaN  NaN
# 4  purple Cootamundra wattle         Form  NaN  NaN  NaN  NaN
#
#          ...        Spread (m) Rain (mm) Soil texture Soil pH Frost  \
# 0        ...               1-2       300     Sa,Lo,Cl     ANC     R
# 1        ...               1-3       250        Sa,Li     ANC     M
# 2        ...               3-6       150     Sa,Lo,Li     ANC     R
# 3        ...               2-6       350     Sa,Lo,Li     ANC     R
# 4        ...               4-7       500        Lo,Cl    AN/C     R
#
#   Flower colour Flower (time) License  \
# 0             Y          W,Sp   CC-BY
# 1             Y          Sp,S   CC-BY
# 2             Y          W,Sp   CC-BY
# 3             Y          W,Sp   CC-BY
# 4             Y          W,Sp   CC-BY
#
#                                     Attribution link Attribution Label
# 0  http://www.environment.sa.gov.au/our-places/St...       State Flora
# 1  http://www.environment.sa.gov.au/our-places/St...       State Flora
# 2  http://www.environment.sa.gov.au/our-places/St...       State Flora
# 3  http://www.environment.sa.gov.au/our-places/St...       State Flora
# 4  http://www.environment.sa.gov.au/our-places/St...       State Flora
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['Type', 'Genus', 'Tube colour', 'Botanical name', 'Common name',
#        'States', 'NW', 'LE', 'NU', 'GT', 'FR', 'EA', 'EP', 'NL', 'MU', 'YP',
#        'SL', 'KI', 'SE', 'Height (m)', 'Spread (m)', 'Rain (mm)',
#        'Soil texture', 'Soil pH', 'Frost', 'Flower colour', 'Flower (time)',
#        'License', 'Attribution link', 'Attribution Label'],
#       dtype='object')

# %%
df = df[['Type', 'Genus', 'Tube colour', 'Botanical name', 'Common name',
       'States','Height (m)', 'Spread (m)', 'Rain (mm)',
       'Soil texture', 'Soil pH', 'Frost', 'Flower colour', 'Flower (time)']]

# %%
df = df.dropna()

# %%
df = df.reset_index(drop = True)

# %% [markdown]
# # Filter data to only victoria State

# %%
for index, row in df.iterrows():
    if "V" not in row.States:
        df = df.drop([index])
df
# Out:
#                                  Type            Genus Tube colour  \
# 0                    Trees and Shrubs          Acacia            B
# 3                    Trees and Shrubs          Acacia            B
# 5                    Trees and Shrubs          Acacia            B
# 6                    Trees and Shrubs          Acacia            B
# 13                   Trees and Shrubs          Acacia            B
# 16                   Trees and Shrubs          Acacia            B
# 18                   Trees and Shrubs          Acacia            B
# 21                   Trees and Shrubs          Acacia            B
# 22                   Trees and Shrubs          Acacia            B
# 23                   Trees and Shrubs          Acacia            B
# 26                   Trees and Shrubs          Acacia            B
# 27                   Trees and Shrubs          Acacia            B
# 28                   Trees and Shrubs          Acacia            B
# 29                   Trees and Shrubs          Acacia            B
# 32                   Trees and Shrubs          Acacia            B
# 33                   Trees and Shrubs          Acacia            B
# 35                   Trees and Shrubs          Acacia            B
# 36                   Trees and Shrubs          Acacia            B
# 39                   Trees and Shrubs          Acacia            B
# 40                   Trees and Shrubs          Acacia            B
# 43                   Trees and Shrubs          Acacia            B
# 44                   Trees and Shrubs          Acacia            B
# 45                   Trees and Shrubs          Acacia            B
# 48                   Trees and Shrubs          Acacia            B
# 49                   Trees and Shrubs          Acacia            B
# 50                   Trees and Shrubs          Acacia            B
# 51                   Trees and Shrubs          Acacia            B
# 57                   Trees and Shrubs          Acacia            B
# 58                   Trees and Shrubs          Acacia            B
# 61                   Trees and Shrubs          Acacia            B
# ..                                ...              ...         ...
# 625                           Grasses       Distichlis           B
# 626                           Grasses           Elymus           B
# 627                           Grasses       Enneapogon           B
# 630                           Grasses              Poa           B
# 631                           Grasses              Poa           B
# 632                           Grasses              Poa           B
# 634                           Grasses          Triodia           B
# 641         Other Strap-leaved Plants         Dianella           B
# 642         Other Strap-leaved Plants       Diplarrena           B
# 645         Other Strap-leaved Plants         Lomandra           B
# 646         Other Strap-leaved Plants         Lomandra           B
# 647         Other Strap-leaved Plants         Lomandra           B
# 649         Other Strap-leaved Plants    Orthrosanthus           B
# 650         Other Strap-leaved Plants       Patersonia           B
# 651         Other Strap-leaved Plants     Xanthorrhoea           B
# 655                  Bulbs and Lilies    Arthropodium            B
# 656                  Bulbs and Lilies         Bulbine            B
# 657                  Bulbs and Lilies       Burchardia           B
# 658                  Bulbs and Lilies       Calostemma           B
# 659  Aquatic and Riparian Zone Plants         Centella           G
# 660  Aquatic and Riparian Zone Plants         Lobelia            G
# 661  Aquatic and Riparian Zone Plants           Mazus            G
# 662  Aquatic and Riparian Zone Plants          Mentha            G
# 663  Aquatic and Riparian Zone Plants         Mimulus            G
# 666                 Rushes and Sedges            Carex           B
# 667                 Rushes and Sedges            Carex           B
# 671                 Rushes and Sedges       Eleocharis           B
# 673                 Rushes and Sedges           Gahnia           B
# 675                 Rushes and Sedges        Isolepis            B
# 679                 Rushes and Sedges  Schoenoplectus            B
#
#                      Botanical name              Common name         States  \
# 0                         acinacea       round-leaved wattle        SA, N,V
# 3                      argyrophylla        golden-grey mulga           SA,V
# 5                      brachybotrya               grey mulga         SA,N,V
# 6                       calamifolia                 wallowa          SA,N,V
# 13                         farinosa             mealy wattle           SA,V
# 16                       floribunda          gossamer wattle          Q,N,V
# 18                    glandulicarpa         hairy-pod wattle           SA,V
# 21                           gunnii       ploughshare wattle     SA,Q,N,V,T
# 22                        hakeoides             hakea wattle     SA,Q,N,V,W
# 23                         howittii            sticky wattle              V
# 26                         ligulata          umbrella wattle    SA,W,Q,NT,V
# 27                          lineata          streaked wattle       SA,Q,N,V
# 28         longifolia var. sophorae           coastal wattle       SA,Q,V,T
# 29             melanoxylon SA forms                blackwood     SA,Q,N,V,T
# 32                       microcarpa             manna wattle         SA,N,V
# 33                          montana            mallee wattle       SA,Q,N,V
# 35                       myrtifolia            myrtle wattle   SA,Q,N,V,T,W
# 36                        notabilis           notable wattle         SA,N,V
# 39                        paradoxa            kangaroo thorn   SA,Q,N,V,T,W
# 40                          pendula            weeping myall       Q,N,V,SA
# 43                       pravissima            Oven’s wattle            N,V
# 44                        pycnantha            golden wattle         SA,N,V
# 45                       retinodes                   wirilda         SA,V,T
# 48                           rigens                   nealie     SA,Q,N,V,W
# 49                         rupicola              rock wattle           SA,V
# 50                         salicina        Broughton willow     SA,Q,N,V,NT
# 51   sclerophylla var. sclerophylla         hard-leaf wattle     SA,Q,N,V,W
# 57                      verniciflua           varnish wattle     SA,N,V,Q,T
# 58         verticillata ssp ovoidea            prickly moses       SA,N,V,T
# 61                      wilhelmiana             dwarf nealie         SA,N,V
# ..                              ...                      ...            ...
# 625                  distichophylla                emu-grass       N,V,SA,T
# 626               scaber var scaber       common wheat-grass       SA,N,V,W
# 627                       nigricans           bottle washers     SA,Q,N,V,W
# 630                  labillardieri            tussock grass         Q,N,V,T
# 631                       poiformis       blue tussock grass     SA,N,V,T,W
# 632                      sieberiana       grey tussock grass     SA,Q,N,V,T
# 634                        scariosa          porcupine grass     SA,N,Q,V,W
# 641                       tasmanica         Tasman flax-lily          N,V,T
# 642                          moraea           butterfly flag          N,V,T
# 645                          effusa         scented mat-rush       SA,N,W,V
# 646                      longifolia    spiny headed mat-rush       SA,Q,N,V
# 647         micrantha ssp micrantha  small-flowered mat-rush       SA,W,N,V
# 649                     multiflorus             morning iris         SA,V,W
# 650                    occidentalis         long purple flag       SA,V,T,W
# 651                       australis       Austral grass tree     SA,N,V,T,Q
# 655                        strictum             vanilla lily     SA,Q,N,V,T
# 656                         bulbosa              native leek   SA,Q,N,V,T,W
# 657                       umbellata                milkmaids   SA,Q,N,V,T,W
# 658                       purpureum             purple bells       SA,Q,N,V
# 659                        asiatica                pennywort   SA,Q,N,V,T,W
# 660              anceps  syn: alata           angled lobelia     SA,Q,N,V,T
# 661                         pumilio              swamp mazus     SA,Q,N,V,T
# 662                       australis               river mint  SA,Q,N,V,T,NT
# 663                          repens   creeping monkey flower   SA,Q,N,V,T,W
# 666                    fascicularis             tassel sedge   SA,Q,N,V,T,W
# 667                        gunniana           mountain sedge       SA,V,N,T
# 671                           acuta        common spike rush   SA,Q,N,V,T,W
# 673                           filum         chaffy saw sedge     SA,W,N,V,T
# 675                        inundata          swamp club rush   SA,Q,N,V,T,W
# 679                         validus          river club-rush   SA,Q,N,V,T,W
#
#     Height (m) Spread (m) Rain (mm) Soil texture Soil pH Frost Flower colour  \
# 0          1-2        1-2       300     Sa,Lo,Cl     ANC     R             Y
# 3          1-5        2-6       350     Sa,Lo,Li     ANC     R             Y
# 5          2-4      1.5-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 6          2-5        2-4       200  Sa,Lo,Cl,Li     ANC     M             Y
# 13         1-2        2-4       350   Sa, Lo, Li     ANC     M             Y
# 16         4-7        4-6       550        Lo,Cl    AN/C     M             Y
# 18         1-3        1-3       350        Sa,Lo     ANC     R             Y
# 21     0.2-0.8        1-2       500     Sa,Lo,Cl      AN     R             Y
# 22       2.5-4        3-5       250        Sa,Lo     ANC     R             Y
# 23         4-8        3-6       450        Lo,Cl     ANC     R             Y
# 26         2-4        4-6       150  Sa,Lo,Cl Li     ANC     R             Y
# 27       0.5-3        1-3       500     Sa,Lo,Cl     ANC     M             Y
# 28         2-5        4-8       450        Sa,Lo     ANC     M             Y
# 29        7-20       4-10       500        Lo,Cl    AN/C     R             Y
# 32         1-3        2-4       300  Sa,Cl,Lo,Li     ANC     R             Y
# 33         2-4        2-5       325  Sa,Cl,Lo,Li     ANC     R             Y
# 35         1-2        1-2       500        Lo,Cl    AN/C     M             Y
# 36         3-6        3-4       250     Lo,Li,Cl     ANC     R             Y
# 39         2-4        3-4       300  Sa,Lo,Cl,Li     ANC     M             Y
# 40        6-10        6-8       250        Lo,Cl     ANC     M             Y
# 43         4-8        4-8       500     Sa,Lo,Cl    AN/C     M             Y
# 44         4-6        2-6       450     Sa,Lo,Cl     ANC     M             Y
# 45         5-8        3-7       500        Lo,Cl     ANC     M             Y
# 48         2-4        2-4       200  Sa,Lo,Cl,Li     ANC     R             Y
# 49       1-2.5      1-2.5       350  Sa,Lo,Cl,Li     ANC     R             Y
# 50        4-10        3-5       300        Lo,Cl     ANC     R             Y
# 51         1-2        2-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 57         3-5        3-5       450     Sa,Lo,Cl    AN/C     M             Y
# 58         2-4        1-3       600        Lo,Cl    AN/C     M             Y
# 61         1-3        2-3       250     Cl,Lo,Li     ANC     R             Y
# ..         ...        ...       ...          ...     ...   ...           ...
# 625        0.4        1-2       350     Sa,Lo,Cl     ANC     R            Br
# 626      0.2-1    0.3-0.5       300     Sa,Lo,Cl     ANC     R            Cr
# 627    0.2-0.5        0.5       350    Sa, Lo,Cl     ANC     R         Br/Bl
# 630      0.3-1    0.3-0.7       400   Sa, Lo, Cl     ANC     R          G/Cr
# 631    0.6-1.2    0.5-1.5       350     Sa,Lo,Cl     ANC     R            Cr
# 632    0.3-0.8    0.3-0.8       500   Sa, Lo, Cl     ANC     M          G/Cr
# 634        0.6          1       300        Sa,Lo     ANC     M          G/Cr
# 641    0.6-1.7      0.5-2       650     Sa,Lo,Cl      AN     M             B
# 642    0.3-0.6      0.5-1       550     Sa,Lo,Cl     ANC     R             W
# 645    0.2-0.5    0.2-0.5       400       Sa, Lo     ANC     M          Cr/Y
# 646      0.5-1      0.5-1       500   Sa, Lo, Cl     ANC     R          Cr/Y
# 647    0.2-0.8    0.2-0.8       500   Sa, Lo, Cl     ANC     R             W
# 649    0.3-0.6      0.4-1       450     Sa,Lo,Cl     ANC     M             B
# 650        0.5        0.5       500       Lo, Cl      AN     M            Pu
# 651      0.5-2      0.6-1       500    Sa, Lo,Cl     ANC     R             W
# 655        0.4        0.4       400     Sa,Lo,Cl     ANC     M             P
# 656        0.3        0.3       500     Sa,Lo,Cl     ANC     M             Y
# 657        0.3        0.2       500     Sa,Lo,Cl     ANC     M             W
# 658    0.2-0.5        0.2       400     Sa,Lo,Cl     ANC     M         Pk, P
# 659    0.1-0.4      0.5-1       500     Sa,Lo,Cl     ANC     S             I
# 660    0.1-0.3      0.3-2       500        Lo,Cl    AN/C     M             P
# 661        0.1          1       600     Sa,Lo,Cl     ANC     M             P
# 662    0.3-0.8    0.3-1.5       600     Sa,Lo,Cl      AN     M             W
# 663        0.2        1-2       500     Sa,Lo,Cl     ANC     M             P
# 666          1          1       AQU     Sa,Lo,Cl     ANC     R             G
# 667    0.2-0.7      0.5-1       AQU     Sa,Lo,Cl     ANC     M            Br
# 671    0.3-0.9        2-3       AQU     Sa,Lo,Cl    AN/C     M            Br
# 673      1-1.5      1-1.5       550        Sa,Lo    AN/C     R             B
# 675        0.5      0.5-1       AQU     Sa,Lo,Cl     ANC     R            Br
# 679    1.5-2.5      1.5-3       AQU     Sa,Lo,Cl     ANC     R             B
#
#     Flower (time)
# 0            W,Sp
# 3            W,Sp
# 5            W,Sp
# 6            W,Sp
# 13          W, Sp
# 16           W,Sp
# 18           W,Sp
# 21           W,Sp
# 22           W,Sp
# 23             Sp
# 26             Sp
# 27             Sp
# 28           W,Sp
# 29           W,Sp
# 32           W,Sp
# 33             Sp
# 35             Sp
# 36           W,Sp
# 39             Sp
# 40         A,W,Sp
# 43           W,Sp
# 44           W,Sp
# 45           W,Sp
# 48           W,Sp
# 49           Sp,S
# 50           W,Sp
# 51             Sp
# 57         W,Sp,S
# 58         W,Sp,S
# 61           W,Sp
# ..            ...
# 625          Sp,S
# 626          W,Sp
# 627          Sp,S
# 630         Sp, S
# 631         Sp,Su
# 632         Sp, S
# 634          W,Sp
# 641          Sp,S
# 642          Sp,S
# 645          W,Sp
# 646         Sp, S
# 647        A,W,Sp
# 649            Sp
# 650            Sp
# 651        W,Sp,S
# 655            Sp
# 656            Sp
# 657            Sp
# 658             A
# 659            Sp
# 660          Sp,S
# 661          Sp,S
# 662            Sp
# 663          Sp,S
# 666          Sp,S
# 667          Sp,S
# 671          Sp,S
# 673             F
# 675            Sp
# 679           S,A
#
# [242 rows x 14 columns]

# %%
df = df.drop(columns='States')
df = df.reset_index(drop = True)
df
# Out:
#                                  Type            Genus Tube colour  \
# 0                    Trees and Shrubs          Acacia            B
# 1                    Trees and Shrubs          Acacia            B
# 2                    Trees and Shrubs          Acacia            B
# 3                    Trees and Shrubs          Acacia            B
# 4                    Trees and Shrubs          Acacia            B
# 5                    Trees and Shrubs          Acacia            B
# 6                    Trees and Shrubs          Acacia            B
# 7                    Trees and Shrubs          Acacia            B
# 8                    Trees and Shrubs          Acacia            B
# 9                    Trees and Shrubs          Acacia            B
# 10                   Trees and Shrubs          Acacia            B
# 11                   Trees and Shrubs          Acacia            B
# 12                   Trees and Shrubs          Acacia            B
# 13                   Trees and Shrubs          Acacia            B
# 14                   Trees and Shrubs          Acacia            B
# 15                   Trees and Shrubs          Acacia            B
# 16                   Trees and Shrubs          Acacia            B
# 17                   Trees and Shrubs          Acacia            B
# 18                   Trees and Shrubs          Acacia            B
# 19                   Trees and Shrubs          Acacia            B
# 20                   Trees and Shrubs          Acacia            B
# 21                   Trees and Shrubs          Acacia            B
# 22                   Trees and Shrubs          Acacia            B
# 23                   Trees and Shrubs          Acacia            B
# 24                   Trees and Shrubs          Acacia            B
# 25                   Trees and Shrubs          Acacia            B
# 26                   Trees and Shrubs          Acacia            B
# 27                   Trees and Shrubs          Acacia            B
# 28                   Trees and Shrubs          Acacia            B
# 29                   Trees and Shrubs          Acacia            B
# ..                                ...              ...         ...
# 212                           Grasses       Distichlis           B
# 213                           Grasses           Elymus           B
# 214                           Grasses       Enneapogon           B
# 215                           Grasses              Poa           B
# 216                           Grasses              Poa           B
# 217                           Grasses              Poa           B
# 218                           Grasses          Triodia           B
# 219         Other Strap-leaved Plants         Dianella           B
# 220         Other Strap-leaved Plants       Diplarrena           B
# 221         Other Strap-leaved Plants         Lomandra           B
# 222         Other Strap-leaved Plants         Lomandra           B
# 223         Other Strap-leaved Plants         Lomandra           B
# 224         Other Strap-leaved Plants    Orthrosanthus           B
# 225         Other Strap-leaved Plants       Patersonia           B
# 226         Other Strap-leaved Plants     Xanthorrhoea           B
# 227                  Bulbs and Lilies    Arthropodium            B
# 228                  Bulbs and Lilies         Bulbine            B
# 229                  Bulbs and Lilies       Burchardia           B
# 230                  Bulbs and Lilies       Calostemma           B
# 231  Aquatic and Riparian Zone Plants         Centella           G
# 232  Aquatic and Riparian Zone Plants         Lobelia            G
# 233  Aquatic and Riparian Zone Plants           Mazus            G
# 234  Aquatic and Riparian Zone Plants          Mentha            G
# 235  Aquatic and Riparian Zone Plants         Mimulus            G
# 236                 Rushes and Sedges            Carex           B
# 237                 Rushes and Sedges            Carex           B
# 238                 Rushes and Sedges       Eleocharis           B
# 239                 Rushes and Sedges           Gahnia           B
# 240                 Rushes and Sedges        Isolepis            B
# 241                 Rushes and Sedges  Schoenoplectus            B
#
#                      Botanical name              Common name Height (m)  \
# 0                         acinacea       round-leaved wattle        1-2
# 1                      argyrophylla        golden-grey mulga        1-5
# 2                      brachybotrya               grey mulga        2-4
# 3                       calamifolia                 wallowa         2-5
# 4                          farinosa             mealy wattle        1-2
# 5                        floribunda          gossamer wattle        4-7
# 6                     glandulicarpa         hairy-pod wattle        1-3
# 7                            gunnii       ploughshare wattle    0.2-0.8
# 8                         hakeoides             hakea wattle      2.5-4
# 9                          howittii            sticky wattle        4-8
# 10                         ligulata          umbrella wattle        2-4
# 11                          lineata          streaked wattle      0.5-3
# 12         longifolia var. sophorae           coastal wattle        2-5
# 13             melanoxylon SA forms                blackwood       7-20
# 14                       microcarpa             manna wattle        1-3
# 15                          montana            mallee wattle        2-4
# 16                       myrtifolia            myrtle wattle        1-2
# 17                        notabilis           notable wattle        3-6
# 18                        paradoxa            kangaroo thorn        2-4
# 19                          pendula            weeping myall       6-10
# 20                       pravissima            Oven’s wattle        4-8
# 21                        pycnantha            golden wattle        4-6
# 22                       retinodes                   wirilda        5-8
# 23                           rigens                   nealie        2-4
# 24                         rupicola              rock wattle      1-2.5
# 25                         salicina        Broughton willow        4-10
# 26   sclerophylla var. sclerophylla         hard-leaf wattle        1-2
# 27                      verniciflua           varnish wattle        3-5
# 28         verticillata ssp ovoidea            prickly moses        2-4
# 29                      wilhelmiana             dwarf nealie        1-3
# ..                              ...                      ...        ...
# 212                  distichophylla                emu-grass        0.4
# 213               scaber var scaber       common wheat-grass      0.2-1
# 214                       nigricans           bottle washers    0.2-0.5
# 215                  labillardieri            tussock grass       0.3-1
# 216                       poiformis       blue tussock grass    0.6-1.2
# 217                      sieberiana       grey tussock grass    0.3-0.8
# 218                        scariosa          porcupine grass        0.6
# 219                       tasmanica         Tasman flax-lily    0.6-1.7
# 220                          moraea           butterfly flag    0.3-0.6
# 221                          effusa         scented mat-rush    0.2-0.5
# 222                      longifolia    spiny headed mat-rush      0.5-1
# 223         micrantha ssp micrantha  small-flowered mat-rush    0.2-0.8
# 224                     multiflorus             morning iris    0.3-0.6
# 225                    occidentalis         long purple flag        0.5
# 226                       australis       Austral grass tree      0.5-2
# 227                        strictum             vanilla lily        0.4
# 228                         bulbosa              native leek        0.3
# 229                       umbellata                milkmaids        0.3
# 230                       purpureum             purple bells    0.2-0.5
# 231                        asiatica                pennywort    0.1-0.4
# 232              anceps  syn: alata           angled lobelia    0.1-0.3
# 233                         pumilio              swamp mazus        0.1
# 234                       australis               river mint    0.3-0.8
# 235                          repens   creeping monkey flower        0.2
# 236                    fascicularis             tassel sedge          1
# 237                        gunniana           mountain sedge    0.2-0.7
# 238                           acuta        common spike rush    0.3-0.9
# 239                           filum         chaffy saw sedge      1-1.5
# 240                        inundata          swamp club rush        0.5
# 241                         validus          river club-rush    1.5-2.5
#
#     Spread (m) Rain (mm) Soil texture Soil pH Frost Flower colour  \
# 0          1-2       300     Sa,Lo,Cl     ANC     R             Y
# 1          2-6       350     Sa,Lo,Li     ANC     R             Y
# 2        1.5-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 3          2-4       200  Sa,Lo,Cl,Li     ANC     M             Y
# 4          2-4       350   Sa, Lo, Li     ANC     M             Y
# 5          4-6       550        Lo,Cl    AN/C     M             Y
# 6          1-3       350        Sa,Lo     ANC     R             Y
# 7          1-2       500     Sa,Lo,Cl      AN     R             Y
# 8          3-5       250        Sa,Lo     ANC     R             Y
# 9          3-6       450        Lo,Cl     ANC     R             Y
# 10         4-6       150  Sa,Lo,Cl Li     ANC     R             Y
# 11         1-3       500     Sa,Lo,Cl     ANC     M             Y
# 12         4-8       450        Sa,Lo     ANC     M             Y
# 13        4-10       500        Lo,Cl    AN/C     R             Y
# 14         2-4       300  Sa,Cl,Lo,Li     ANC     R             Y
# 15         2-5       325  Sa,Cl,Lo,Li     ANC     R             Y
# 16         1-2       500        Lo,Cl    AN/C     M             Y
# 17         3-4       250     Lo,Li,Cl     ANC     R             Y
# 18         3-4       300  Sa,Lo,Cl,Li     ANC     M             Y
# 19         6-8       250        Lo,Cl     ANC     M             Y
# 20         4-8       500     Sa,Lo,Cl    AN/C     M             Y
# 21         2-6       450     Sa,Lo,Cl     ANC     M             Y
# 22         3-7       500        Lo,Cl     ANC     M             Y
# 23         2-4       200  Sa,Lo,Cl,Li     ANC     R             Y
# 24       1-2.5       350  Sa,Lo,Cl,Li     ANC     R             Y
# 25         3-5       300        Lo,Cl     ANC     R             Y
# 26         2-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 27         3-5       450     Sa,Lo,Cl    AN/C     M             Y
# 28         1-3       600        Lo,Cl    AN/C     M             Y
# 29         2-3       250     Cl,Lo,Li     ANC     R             Y
# ..         ...       ...          ...     ...   ...           ...
# 212        1-2       350     Sa,Lo,Cl     ANC     R            Br
# 213    0.3-0.5       300     Sa,Lo,Cl     ANC     R            Cr
# 214        0.5       350    Sa, Lo,Cl     ANC     R         Br/Bl
# 215    0.3-0.7       400   Sa, Lo, Cl     ANC     R          G/Cr
# 216    0.5-1.5       350     Sa,Lo,Cl     ANC     R            Cr
# 217    0.3-0.8       500   Sa, Lo, Cl     ANC     M          G/Cr
# 218          1       300        Sa,Lo     ANC     M          G/Cr
# 219      0.5-2       650     Sa,Lo,Cl      AN     M             B
# 220      0.5-1       550     Sa,Lo,Cl     ANC     R             W
# 221    0.2-0.5       400       Sa, Lo     ANC     M          Cr/Y
# 222      0.5-1       500   Sa, Lo, Cl     ANC     R          Cr/Y
# 223    0.2-0.8       500   Sa, Lo, Cl     ANC     R             W
# 224      0.4-1       450     Sa,Lo,Cl     ANC     M             B
# 225        0.5       500       Lo, Cl      AN     M            Pu
# 226      0.6-1       500    Sa, Lo,Cl     ANC     R             W
# 227        0.4       400     Sa,Lo,Cl     ANC     M             P
# 228        0.3       500     Sa,Lo,Cl     ANC     M             Y
# 229        0.2       500     Sa,Lo,Cl     ANC     M             W
# 230        0.2       400     Sa,Lo,Cl     ANC     M         Pk, P
# 231      0.5-1       500     Sa,Lo,Cl     ANC     S             I
# 232      0.3-2       500        Lo,Cl    AN/C     M             P
# 233          1       600     Sa,Lo,Cl     ANC     M             P
# 234    0.3-1.5       600     Sa,Lo,Cl      AN     M             W
# 235        1-2       500     Sa,Lo,Cl     ANC     M             P
# 236          1       AQU     Sa,Lo,Cl     ANC     R             G
# 237      0.5-1       AQU     Sa,Lo,Cl     ANC     M            Br
# 238        2-3       AQU     Sa,Lo,Cl    AN/C     M            Br
# 239      1-1.5       550        Sa,Lo    AN/C     R             B
# 240      0.5-1       AQU     Sa,Lo,Cl     ANC     R            Br
# 241      1.5-3       AQU     Sa,Lo,Cl     ANC     R             B
#
#     Flower (time)
# 0            W,Sp
# 1            W,Sp
# 2            W,Sp
# 3            W,Sp
# 4           W, Sp
# 5            W,Sp
# 6            W,Sp
# 7            W,Sp
# 8            W,Sp
# 9              Sp
# 10             Sp
# 11             Sp
# 12           W,Sp
# 13           W,Sp
# 14           W,Sp
# 15             Sp
# 16             Sp
# 17           W,Sp
# 18             Sp
# 19         A,W,Sp
# 20           W,Sp
# 21           W,Sp
# 22           W,Sp
# 23           W,Sp
# 24           Sp,S
# 25           W,Sp
# 26             Sp
# 27         W,Sp,S
# 28         W,Sp,S
# 29           W,Sp
# ..            ...
# 212          Sp,S
# 213          W,Sp
# 214          Sp,S
# 215         Sp, S
# 216         Sp,Su
# 217         Sp, S
# 218          W,Sp
# 219          Sp,S
# 220          Sp,S
# 221          W,Sp
# 222         Sp, S
# 223        A,W,Sp
# 224            Sp
# 225            Sp
# 226        W,Sp,S
# 227            Sp
# 228            Sp
# 229            Sp
# 230             A
# 231            Sp
# 232          Sp,S
# 233          Sp,S
# 234            Sp
# 235          Sp,S
# 236          Sp,S
# 237          Sp,S
# 238          Sp,S
# 239             F
# 240            Sp
# 241           S,A
#
# [242 rows x 13 columns]

# %% [markdown]
# ### Write to new_csv

# %%
df.to_csv('Cleaned State Flora.csv',index = False)

# %% [markdown]
# ## Visualization Part
#
# ### Soil PH Pie Chart
#
# __This part is for Flora Soil PH visualization__

# %%
df['Soil pH'].unique()
# Out:
# array(['ANC', 'AN/C', 'AN'], dtype=object)

# %%
anc = df[df['Soil pH'] == 'ANC']['Type']
anc.count()
# Out:
# 176

# %%
c = df[df['Soil pH'] == 'AN/C']['Type']
c.count()
# Out:
# 35

# %%
an = df[df['Soil pH'] == 'AN']['Type']
an.count()
# Out:
# 31

# %%
# Data to plot
labels = 'Soil PH <=7 or >7','Soils pH<=8', 'Soils PH<=7'
sizes = [anc.count(), c.count(), an.count()]
colors = ['gold', 'yellowgreen', 'lightskyblue']
explode = (0, 0, 0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('Flora suitable Soil')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Frost resistant Pie Chart
#
# __This part is for Frost resistant visualization__

# %%
df['Frost'].unique()
# Out:
# array(['R', 'M', 'S/M', 'S'], dtype=object)

# %%
r = df[df.Frost == 'R']['Frost']
m = df[df.Frost == 'M']['Frost']
sm = df[df.Frost == 'S/M']['Frost']
s = df[df.Frost == 'S']['Frost']

# %%
# Data to plot
labels = 'Resistant to most frosts','Moderately sensitive to frosts', 'Sensitive to frosts', 'Moderately/sensitive to frosts'
sizes = [r.count(), m.count(), s.count(), sm.count()]
colors = ['gold', 'yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0,0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('Flora Resistant / Sensitive to Frosts')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Soil Texture
#
# __This part is for Soil Texture needed by flora visualization__

# %%
df['Soil texture'].unique()
# Out:
# array(['Sa,Lo,Cl', 'Sa,Lo,Li', 'Sa,Lo,Cl,Li', 'Sa, Lo, Li', 'Lo,Cl',
#        'Sa,Lo', 'Sa,Lo,Cl Li', 'Sa,Cl,Lo,Li', 'Lo,Li,Cl', 'Cl,Lo,Li',
#        'Sa,Li', 'Sa, Lo', 'Sa, Lo, Cl', 'Lo, Cl', 'Lo, Cl, Li',
#        'Sa,Lo, Cl, Li', 'Sa, Li, Cl,Li', 'Sa,Lo, Cl', 'Sa,,Lo,Cl,Li',
#        'Sa,Lo,Cl/Lo', 'Sa, Lo,Cl', 'Sa Lo Cl'], dtype=object)

# %%
length = len(df['Type'])
sa = 0
li = 0
cl = 0
lo = 0
for i in range(length):
    if type(df['Soil texture'][i]) != str:
        continue
    if bool(re.match(r'(.*?)Sa(.*?)', df['Soil texture'][i], re.IGNORECASE)):
        sa += 1
    
    if bool(re.match(r'(.*?)Lo(.*?)', df['Soil texture'][i], re.IGNORECASE)):
        lo += 1
        
    if bool(re.match(r'(.*?)Cl(.*?)', df['Soil texture'][i], re.IGNORECASE)):
        cl += 1
    if bool(re.match(r'(.*?)Li(.*?)', df['Soil texture'][i], re.IGNORECASE)):
        li += 1

# %%
# Data to plot
labels = 'Sand','Loam', 'Clay', 'Limestone'
sizes = [sa, lo, cl, li]
colors = ['gold', 'yellowgreen', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0,0)  # explode 1st slice

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)

plt.title('Soil Texture')
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Annual Rain
#
# __This part is for Annual Rain needed by flora visualization__

# %%
df['Rain (mm)'].unique()
# Out:
# array([300, 350, 250, 200, 550, 500, 450, 150, 325, 600, 400, 650, 750,
#        700, 800, 'AQU'], dtype=object)

# %%
pre_list = df['Rain (mm)'].unique()
rain_list = []
rain_dict = {}
for each in pre_list:
    if type(each) == int:
        rain_list.append(each)
        
for each in rain_list:
    rain_dict[each] = 0
    
    
for i in range(length):
    if type(df['Rain (mm)'][i]) != int:
        continue
    rain_dict[df['Rain (mm)'][i]] += 1

# %%
plt.bar(list(rain_dict.keys()), rain_dict.values(), width=20, color='g')
plt.title('Flora Annual Rain')
plt.show()

# %% [markdown]
# # SQL Quiries
#
# __This part is used for auto making sql queries__

# %%
def pri(list1):
    new_list = []
    for each in list1:
        new_list.append((each,""))
    return print(new_list)

# %%
genus_list = list(df['Genus'].unique())
pri(genus_list)
# Out:
# [('Acacia ', ''), ('Adriana', ''), ('Allocasuarina', ''), ('Atriplex', ''), ('Babingtonia syn Baeckea', ''), ('Banksia', ''), ('Bauera', ''), ('Boronia ', ''), ('Brachychiton', ''), ('Callistemon', ''), ('Casuarina', ''), ('Cheiranthera', ''), ('Correa', ''), ('Corymbia  formerly Eucalyptus', ''), ('Crowea ', ''), ('Daviesia ', ''), ('Dillwynia', ''), ('Dodonaea', ''), ('Eremophila', ''), ('Eucalyptus ', ''), ('Glischrocaryon', ''), ('Goodenia', ''), ('Grevillea', ''), ('Hakea', ''), ('Hardenbergia', ''), ('Hibbertia', ''), ('Hybanthus', ''), ('Isopogon', ''), ('Lasiopetalum', ''), ('Leptospermum', ''), ('Leucophyta', ''), ('Leucopogon', ''), ('Linum ', ''), ('Maireana', ''), ('Melaleuca', ''), ('Micromyrtus', ''), ('Myoporum', ''), ('Olearia', ''), ('Philotheca Syn:Eriostemon', ''), ('Pimelea', ''), ('Platylobium', ''), ('Prostanthera', ''), ('Pultenaea', ''), ('Rhagodia', ''), ('Senna', ''), ('Solanum ', ''), ('Syzygium', ''), ('Tetratheca', ''), ('Thomasia', ''), ('Thryptomene', ''), ('Viminaria', ''), ('Westringia ', ''), ('Ajuga', ''), ('Brachyscome ', ''), ('Carpobrotus', ''), ('Chrysocephalum ', ''), ('Helichrysum', ''), ('Kennedia', ''), ('Kunzea', ''), ('Pelargonium', ''), ('Pratia', ''), ('Scaevola', ''), ('Viola', ''), ('Muehlenbeckia', ''), ('Aristida ', ''), ('Austrodanthonia  syn. Danthonia', ''), ('Austrostipa  syn. Stipa', ''), ('Bothriochloa', ''), ('Distichlis', ''), ('Elymus', ''), ('Enneapogon', ''), ('Poa', ''), ('Triodia', ''), ('Dianella', ''), ('Diplarrena', ''), ('Lomandra', ''), ('Orthrosanthus', ''), ('Patersonia', ''), ('Xanthorrhoea', ''), ('Arthropodium ', ''), ('Bulbine ', ''), ('Burchardia', ''), ('Calostemma', ''), ('Centella', ''), ('Lobelia ', ''), ('Mazus ', ''), ('Mentha ', ''), ('Mimulus ', ''), ('Carex', ''), ('Eleocharis', ''), ('Gahnia', ''), ('Isolepis ', ''), ('Schoenoplectus ', '')]

# %%
df.columns
# Out:
# Index(['Type', 'Genus', 'Tube colour', 'Botanical name', 'Common name',
#        'Height (m)', 'Spread (m)', 'Rain (mm)', 'Soil texture', 'Soil pH',
#        'Frost', 'Flower colour', 'Flower (time)', 'plantid'],
#       dtype='object')

# %%
df_plants = df[[ 'plantid', 'Tube colour','Botanical name', 'Common name',
       'Height (m)', 'Spread (m)', 'Rain (mm)', 'Type', 'Genus', 'Soil pH',
       'Frost']]

# %%
new_list = []
for index, row in df_plants.iterrows():
    if row.Frost == 'S/M':
        row.Frost = 'S'
        print(index)
    print((row['plantid'],row['Tube colour'],row['Botanical name'],row['Common name'], 
                    str(row['Height (m)']),str(row['Spread (m)']),str(row['Rain (mm)']),row['Type'],row['Genus'],
                    row['Soil pH'],row['Frost']), ",")
# Out:
# (0, 'B', 'acinacea ', 'round-leaved wattle', '1-2', '1-2', '300', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (1, 'B', 'argyrophylla', 'golden-grey mulga', '1-5', '2-6', '350', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (2, 'B', 'brachybotrya', 'grey mulga', '2-4', '1.5-4', '250', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (3, 'B', 'calamifolia', 'wallowa ', '2-5', '2-4', '200', 'Trees and Shrubs', 'Acacia ', 'ANC', 'M') ,
# (4, 'B', 'farinosa', 'mealy wattle', '1-2', '2-4', '350', 'Trees and Shrubs', 'Acacia ', 'ANC', 'M') ,
# (5, 'B', 'floribunda', 'gossamer wattle', '4-7', '4-6', '550', 'Trees and Shrubs', 'Acacia ', 'AN/C', 'M') ,
# (6, 'B', 'glandulicarpa', 'hairy-pod wattle', '1-3', '1-3', '350', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (7, 'B', 'gunnii', 'ploughshare wattle', '0.2-0.8', '1-2', '500', 'Trees and Shrubs', 'Acacia ', 'AN', 'R') ,
# (8, 'B', 'hakeoides', 'hakea wattle', '2.5-4', '3-5', '250', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (9, 'B', 'howittii', 'sticky wattle', '4-8', '3-6', '450', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (10, 'B', 'ligulata', 'umbrella wattle', '2-4', '4-6', '150', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (11, 'B', 'lineata', 'streaked wattle', '0.5-3', '1-3', '500', 'Trees and Shrubs', 'Acacia ', 'ANC', 'M') ,
# (12, 'B', 'longifolia var. sophorae', 'coastal wattle', '2-5', '4-8', '450', 'Trees and Shrubs', 'Acacia ', 'ANC', 'M') ,
# (13, 'B', 'melanoxylon SA forms', 'blackwood', '7-20', '4-10', '500', 'Trees and Shrubs', 'Acacia ', 'AN/C', 'R') ,
# (14, 'B', 'microcarpa', 'manna wattle', '1-3', '2-4', '300', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (15, 'B', 'montana', 'mallee wattle', '2-4', '2-5', '325', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (16, 'B', 'myrtifolia', 'myrtle wattle', '1-2', '1-2', '500', 'Trees and Shrubs', 'Acacia ', 'AN/C', 'M') ,
# (17, 'B', 'notabilis', 'notable wattle', '3-6', '3-4', '250', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (18, 'B', 'paradoxa ', 'kangaroo thorn', '2-4', '3-4', '300', 'Trees and Shrubs', 'Acacia ', 'ANC', 'M') ,
# (19, 'B', 'pendula', 'weeping myall', '6-10', '6-8', '250', 'Trees and Shrubs', 'Acacia ', 'ANC', 'M') ,
# (20, 'B', 'pravissima', 'Oven’s wattle', '4-8', '4-8', '500', 'Trees and Shrubs', 'Acacia ', 'AN/C', 'M') ,
# (21, 'B', 'pycnantha', 'golden wattle', '4-6', '2-6', '450', 'Trees and Shrubs', 'Acacia ', 'ANC', 'M') ,
# (22, 'B', 'retinodes ', 'wirilda', '5-8', '3-7', '500', 'Trees and Shrubs', 'Acacia ', 'ANC', 'M') ,
# (23, 'B', 'rigens', 'nealie', '2-4', '2-4', '200', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (24, 'B', 'rupicola', 'rock wattle', '1-2.5', '1-2.5', '350', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (25, 'B', 'salicina', 'Broughton willow ', '4-10', '3-5', '300', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (26, 'B', 'sclerophylla var. sclerophylla', 'hard-leaf wattle', '1-2', '2-4', '250', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (27, 'B', 'verniciflua', 'varnish wattle', '3-5', '3-5', '450', 'Trees and Shrubs', 'Acacia ', 'AN/C', 'M') ,
# (28, 'B', 'verticillata ssp ovoidea', 'prickly moses', '2-4', '1-3', '600', 'Trees and Shrubs', 'Acacia ', 'AN/C', 'M') ,
# (29, 'B', 'wilhelmiana', 'dwarf nealie', '1-3', '2-3', '250', 'Trees and Shrubs', 'Acacia ', 'ANC', 'R') ,
# (30, 'B', 'quadripartita syn.klotzschii', 'coastal bitter bush', '1-2', '1-3', '350', 'Trees and Shrubs', 'Adriana', 'ANC', 'M') ,
# (31, 'B', 'luehmannii', 'bull oak', '8-20', '5-8', '550', 'Trees and Shrubs', 'Allocasuarina', 'ANC', 'R') ,
# (32, 'B', 'muelleriana ssp muelleriana', 'slaty sheoak', '1-3', '2-3', '400', 'Trees and Shrubs', 'Allocasuarina', 'ANC', 'M') ,
# (33, 'B', 'pusilla', 'dwarf sheoak', '1-2', '1-2', '350', 'Trees and Shrubs', 'Allocasuarina', 'ANC', 'R') ,
# (34, 'B', 'verticillata Coastal form', 'drooping sheoak', '5-8', '4-6', '400', 'Trees and Shrubs', 'Allocasuarina', 'ANC', 'R') ,
# (35, 'B', 'verticillata Dryland form  ', 'drooping sheoak', '5-8', '4-6', '350', 'Trees and Shrubs', 'Allocasuarina', 'ANC', 'R') ,
# (36, 'B', 'verticillata Hills form', 'drooping sheoak', '5-8', '4-6', '500', 'Trees and Shrubs', 'Allocasuarina', 'ANC', 'M') ,
# (37, 'B', 'cinerea', 'coastal saltbush', '1', '1-2', '350', 'Trees and Shrubs', 'Atriplex', 'ANC', 'M') ,
# (38, 'B', 'paludosa', 'marsh saltbush', '0.5-1', '0.5-1', '300', 'Trees and Shrubs', 'Atriplex', 'ANC', 'R') ,
# (39, 'B', 'rhagodioides', 'river saltbush', '0.5-2', '1-2', '250', 'Trees and Shrubs', 'Atriplex', 'ANC', 'R') ,
# (40, 'B', 'vesicaria', 'bladder saltbush', '0.5-1', '1-2', '250', 'Trees and Shrubs', 'Atriplex', 'ANC', 'R') ,
# (41, 'B', 'behrii', 'silver broombush', '2-3', '1-2', '350', 'Trees and Shrubs', 'Babingtonia syn Baeckea', 'ANC', 'R') ,
# (42, 'G', 'integrifolia', 'coast banksia', '8-15', '5-8', '450', 'Trees and Shrubs', 'Banksia', 'ANC', 'M') ,
# (43, 'B', 'marginata', 'silver banksia', '2-8', '1-5', '500', 'Trees and Shrubs', 'Banksia', 'ANC', 'R') ,
# (44, 'B', 'ornata', 'desert banksia', '1-2', '1-2', '400', 'Trees and Shrubs', 'Banksia', 'AN/C', 'M') ,
# (45, 'G', 'serrata', 'old man banksia', '2-10', '2-7', '500', 'Trees and Shrubs', 'Banksia', 'AN', 'M') ,
# (46, 'G', 'spinulosa', 'hairpin banksia', '2-4', '2-5', '600', 'Trees and Shrubs', 'Banksia', 'AN', 'R') ,
# (47, 'G', 'rubioides ', 'wiry bauera', '0.5-2', '1-3', '650', 'Trees and Shrubs', 'Bauera', 'AN', 'M') ,
# (48, 'G', 'coerulescens ssp coerulescens', 'blue boronia', '0.5', '0.5', '400', 'Trees and Shrubs', 'Boronia ', 'ANC', 'R') ,
# (49, 'G', 'filifolia', 'slender boronia', '0.5-1', '0.5–1', '450', 'Trees and Shrubs', 'Boronia ', 'ANC', 'M') ,
# (50, 'B', 'populneus', 'kurrajong', '8-15', '6-10', '400', 'Trees and Shrubs', 'Brachychiton', 'ANC', 'R') ,
# (51, 'B', 'brachyandrus', 'prickly bottlebrush', '2-3', '1-3.5', '450', 'Trees and Shrubs', 'Callistemon', 'ANC', 'R') ,
# (52, 'B', 'citrinus', 'crimson bottlebrush', '2-5', '2-5', '450', 'Trees and Shrubs', 'Callistemon', 'ANC', 'M') ,
# (53, 'B', 'pallidus', 'lemon bottlebrush', '2-5', '2-4', '550', 'Trees and Shrubs', 'Callistemon', 'ANC', 'R') ,
# (54, 'B', 'sieberi', 'river bottlebrush', '2-4', '2-3', '500', 'Trees and Shrubs', 'Callistemon', 'ANC', 'M') ,
# (55, 'B', 'obesa', 'swamp oak', '10-15', '5-10', '350', 'Trees and Shrubs', 'Casuarina', 'ANC', 'R') ,
# (56, 'B', 'pauper syn C.cristata', 'black oak, belah', '6-15', '4-8', '200', 'Trees and Shrubs', 'Casuarina', 'ANC', 'R') ,
# (57, 'G', 'alternifolia ', 'finger flower', '0.3', '0.3', '450', 'Trees and Shrubs', 'Cheiranthera', 'AN', 'M') ,
# (58, 'G', 'alba var. alba', 'white correa', '2-2.5', '2-2.5', '400', 'Trees and Shrubs', 'Correa', 'ANC', 'M') ,
# (59, 'G', 'backhouseana ', 'velvet correa', '1-2', '2-3', '500', 'Trees and Shrubs', 'Correa', 'ANC', 'M') ,
# (60, 'G', 'glabra var. turnbullii', 'rock correa', '1-1.5', '1-1.5', '400', 'Trees and Shrubs', 'Correa', 'ANC', 'R') ,
# 61
# (61, 'B', 'maculata ', 'spotted gum', '10-40', '8-20', '500', 'Trees and Shrubs', 'Corymbia  formerly Eucalyptus', 'ANC', 'S') ,
# (62, 'G', 'exalata', 'wax flower', '0.5-1', '0.5-1.5', '600', 'Trees and Shrubs', 'Crowea ', 'AN', 'M') ,
# (63, 'B', 'leptophylla', 'blunt leaf bitter-pea', '1-2.5', '1-2', '500', 'Trees and Shrubs', 'Daviesia ', 'AN', 'M') ,
# (64, 'G', 'hispida', 'red parrot-pea', '0.2-0.6', '0.3-1', '450', 'Trees and Shrubs', 'Dillwynia', 'ANC', 'M') ,
# (65, 'B', 'bursariifolia', 'low hop bush', '0.5-1.5', '0.7-1.5', '400', 'Trees and Shrubs', 'Dodonaea', 'ANC', 'R') ,
# (66, 'B', 'stenozyga', 'desert hop bush', '0.5-1', '1-3', '300', 'Trees and Shrubs', 'Dodonaea', 'ANC', 'R') ,
# (67, 'G', 'crassifolia', 'trim emu bush', '1', '1', '350', 'Trees and Shrubs', 'Eremophila', 'ANC', 'R') ,
# (68, 'G', 'divaricata ssp divaricata', 'spreading emu bush', '1-2', '1-3', '350', 'Trees and Shrubs', 'Eremophila', 'ANC', 'M') ,
# (69, 'G', 'oppositifolia', 'twin-leaf emu bush', '1.5-4', '1-3', '300', 'Trees and Shrubs', 'Eremophila', 'ANC', 'R') ,
# (70, 'G', 'polyclada', 'flowering lignum', '2-4', '2-4', '400', 'Trees and Shrubs', 'Eremophila', 'ANC', 'M') ,
# (71, 'G', 'scoparia', 'broom emu bush', '1-3', '1-1.5', '250', 'Trees and Shrubs', 'Eremophila', 'ANC', 'R') ,
# (72, 'B', 'albens', 'white box', '15-25', '10-15', '450', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (73, 'B', 'arenacea ', 'sand stringybark', '4-8', '4-8', '450', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (74, 'B', 'baxteri', 'brown stringybark', '6-25', '6-15', '650', 'Trees and Shrubs', 'Eucalyptus ', 'AN', 'R') ,
# 75
# (75, 'B', 'botryoides', 'bangalay', '10-30', '10-15', '600', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'S') ,
# (76, 'B', 'calycogona', 'square-fruited mallee', '3-10', '3-8', '300', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (77, 'B', 'cinerea', 'argyle apple', '7-15', '5-8', '600', 'Trees and Shrubs', 'Eucalyptus ', 'AN/C', 'R') ,
# (78, 'B', 'crenulata', 'Victorian silver gum', '4-12', '3-10', '600', 'Trees and Shrubs', 'Eucalyptus ', 'AN/C', 'R') ,
# (79, 'B', 'cyanophylla', 'blue-leaved mallee', '2-6', '3-8', '250', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (80, 'B', 'dalrympleana ssp dalrympleana', 'candlebark gum', '15-35', '10-30', '750', 'Trees and Shrubs', 'Eucalyptus ', 'AN', 'R') ,
# (81, 'B', 'diversifolia ssp diversifolia', 'SA coastal white mallee', '2-10', '2-8', '350', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (82, 'B', 'dumosa', 'white mallee', '4-8', '4-5', '300', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (83, 'B', 'fasciculosa', 'pink gum', '5-18', '5-12', '450', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (84, 'B', 'globulus', 'Tasmanian blue gum', '15-50', '10-20', '700', 'Trees and Shrubs', 'Eucalyptus ', 'AN/C', 'R') ,
# (85, 'B', 'goniocalyx ssp. goniocalyx', 'long-leaved box', '8-20', '6-15', '500', 'Trees and Shrubs', 'Eucalyptus ', 'AN/C', 'M') ,
# (86, 'B', 'gracilis ', 'yorrell', '3-9', '3-8', '200', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (87, 'B', 'incrassata', 'ridge-fruited mallee', '3-7', '3-6', '350', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (88, 'B', 'largiflorens', 'river box', '6-20', '6-15', '350', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (89, 'B', 'leptophylla', 'narrow-leaved red mallee', '2-6', '3-8', '200', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (90, 'B', 'leucoxylon ssp leucoxylon', 'S.A. blue gum', '8-30', '8-25', '500', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (91, 'B', 'leucoxylon ssp megalocarpa', 'large-fruited SA.blue gum', '6-12', '6-10', '400', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (92, 'B', 'leucoxylon ssp pruinosa', 'inland blue gum', '6-20', '3-12', '400', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (93, 'B', 'leucoxylon ssp stephaniae', 'scrubby blue gum', '4-15', '2-10', '450', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (94, 'B', 'melliodora', 'yellow box', '20-35', '20-30', '400', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (95, 'B', 'microcarpa', 'grey box', '6-20', '8-20', '500', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (96, 'B', 'obliqua', 'messmate stringybark', '15-40', '12-25', '800', 'Trees and Shrubs', 'Eucalyptus ', 'AN', 'M') ,
# (97, 'B', 'odorata', 'peppermint box', '7-15', '6-12', '350', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (98, 'B', 'oleosa ssp oleosa', 'red mallee', '3-12', '3-12', '300', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (99, 'B', 'ovata var. ovata', 'swamp gum', '6-20', '5-15', '650', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (100, 'B', 'perriniana', 'spinning gum', '4-10', '4-8', '650', 'Trees and Shrubs', 'Eucalyptus ', 'AN/C', 'R') ,
# (101, 'B', 'phenax ssp phenax', 'white mallee', '3-7', '3-5', '300', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (102, 'B', 'polyanthemos', 'red box', '10-25', '5-15', '500', 'Trees and Shrubs', 'Eucalyptus ', 'AN', 'R') ,
# (103, 'B', 'polybractea', 'blue mallee', '4-10', '4-8', '400', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (104, 'B', 'porosa', 'mallee box', '5-14', '5-12', '300', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (105, 'B', 'sideroxylon ssp. sideroxylon', 'red ironbark', '10-30', '8-15', '500', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (106, 'B', 'socialis ssp socialis', 'red mallee', '4-8', '4-8', '250', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'R') ,
# (107, 'B', 'viminalis ssp cygnetensis', 'rough-barked manna gum', '6-20', '8-20', '550', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (108, 'B', 'viminalis ssp viminalis', 'manna gum', '15-40', '12-30', '650', 'Trees and Shrubs', 'Eucalyptus ', 'AN', 'R') ,
# (109, 'B', 'viridis', 'green mallee', '4-8', '3-5', '250', 'Trees and Shrubs', 'Eucalyptus ', 'ANC', 'M') ,
# (110, 'G', 'behrii', 'golden pennants', '0.2-1', '0.3-1', '300', 'Trees and Shrubs', 'Glischrocaryon', 'ANC', 'M') ,
# (111, 'G', 'amplexans', 'clasping goodenia', '0.5-1.2', '0.5-1', '400', 'Trees and Shrubs', 'Goodenia', 'ANC', 'M') ,
# (112, 'G', 'ovata ', 'hop goodenia', '1-2.5', '1-3', '450', 'Trees and Shrubs', 'Goodenia', 'AN/C', 'M') ,
# (113, 'G', 'huegelii', 'comb grevillea', '0.5-2.5', '1.5-3', '300', 'Trees and Shrubs', 'Grevillea', 'AN/C', 'M') ,
# (114, 'G', 'ilicifolia ssp ilicifolia', 'holly grevillea', '0.1-2', '1-3', '400', 'Trees and Shrubs', 'Grevillea', 'ANC', 'M') ,
# (115, 'G', 'pterosperma', 'desert grevillea', '2-3', '2-4', '250', 'Trees and Shrubs', 'Grevillea', 'ANC', 'R') ,
# (116, 'B', 'mitchellii syn H. muelleriana', 'desert hakea', '1-4', '1-3', '350', 'Trees and Shrubs', 'Hakea', 'ANC', 'R') ,
# (117, 'B', 'nodosa', 'yellow hakea', '1-3', '2-4', '600', 'Trees and Shrubs', 'Hakea', 'AN/C', 'M') ,
# (118, 'B', 'rostrata', 'beaked hakea', '1-4', '1-3', '400', 'Trees and Shrubs', 'Hakea', 'ANC', 'M') ,
# (119, 'B', 'rugosa', 'wrinkled hakea', '0.5-2.5', '1-2', '450', 'Trees and Shrubs', 'Hakea', 'AN/C', 'M') ,
# (120, 'B', 'violacea Shrub form', 'native lilac', '1.5-2', '2-3', '500', 'Trees and Shrubs', 'Hardenbergia', 'ANC', 'M') ,
# (121, 'B', 'violacea alba ', 'white native lilac', '1.5-2', '2-3', '500', 'Trees and Shrubs', 'Hardenbergia', 'ANC', 'M') ,
# (122, 'B', 'violacea rosea', 'pink native lilac', '1.5-2', '2-3', '500', 'Trees and Shrubs', 'Hardenbergia', 'ANC', 'M') ,
# (123, 'G', 'empetrifolia', 'scrambling guinea flower', '0.5-1', '1-2', '600', 'Trees and Shrubs', 'Hibbertia', 'AN', 'M') ,
# (124, 'G', 'sericea', 'silky guinea flower', '0.2-0.4', '0.2-0.5', '350', 'Trees and Shrubs', 'Hibbertia', 'AN', 'M') ,
# (125, 'G', 'floribundus', 'shrub violet', '0.5-1.5', '0.5-1.5', '450', 'Trees and Shrubs', 'Hybanthus', 'AN', 'M') ,
# (126, 'B', 'ceratophyllus', 'wild Irishman', '0.5-1', '0.5-1', '500', 'Trees and Shrubs', 'Isopogon', 'AN/C', 'M') ,
# (127, 'B', 'baueri', 'slender velvet bush', '05-1.5', '1-2', '400', 'Trees and Shrubs', 'Lasiopetalum', 'ANC', 'R') ,
# (128, 'B', 'behrii', 'pink velvet bush', '0.5-1.5', '1-2', '400', 'Trees and Shrubs', 'Lasiopetalum', 'ANC', 'R') ,
# (129, 'B', 'schulzenii', 'drooping velvet bush', '0.5-1.5', '0.5-2', '400', 'Trees and Shrubs', 'Lasiopetalum', 'ANC', 'M') ,
# (130, 'B', 'continentale ', 'prickly tea tree', '1.5-4', '2-4', '500', 'Trees and Shrubs', 'Leptospermum', 'AN', 'R') ,
# (131, 'B', 'coriaceum', 'green tea tree', '1-3', '2-4', '350', 'Trees and Shrubs', 'Leptospermum', 'ANC', 'R') ,
# (132, 'B', 'lanigerum', 'woolly tea tree', '2-5', '1.5-4', '550', 'Trees and Shrubs', 'Leptospermum', 'AN/C', 'R') ,
# (133, 'B', 'myrsinoides', 'silky tea tree', '1-4', '1-4', '450', 'Trees and Shrubs', 'Leptospermum', 'AN', 'R') ,
# (134, 'B', 'brownii', 'cushion bush', '0.2-1', '1-2', '400', 'Trees and Shrubs', 'Leucophyta', 'ANC', 'M') ,
# (135, 'G', 'parviflorus', 'coast beard heath', '2-4', '1-3', '500', 'Trees and Shrubs', 'Leucopogon', 'ANC', 'S') ,
# (136, 'B', 'marginale', 'native flax', '0.3-0.6', '0.2-0.4', '500', 'Trees and Shrubs', 'Linum ', 'ANC', 'R') ,
# (137, 'B', 'pyramidata', 'shrubby bluebush', '0.5-1', '0.5-1', '300', 'Trees and Shrubs', 'Maireana', 'ANC', 'R') ,
# (138, 'B', 'sedifolia', 'pearl bluebush', '0.6-1.5', '0.6-2', '350', 'Trees and Shrubs', 'Maireana', 'ANC', 'R') ,
# (139, 'B', 'acuminata ssp acuminata', 'mallee honey myrtle', '2-4', '2', '300', 'Trees and Shrubs', 'Melaleuca', 'ANC', 'M') ,
# (140, 'B', 'armillaris', 'bracelet honey myrtle', '3-8', '3-5', '450', 'Trees and Shrubs', 'Melaleuca', 'ANC', 'M') ,
# (141, 'B', 'brevifolia', 'white-flowered paperbark', '2-4', '2-4', '400', 'Trees and Shrubs', 'Melaleuca', 'ANC', 'R') ,
# (142, 'B', 'decussata', 'cross-leaved honey myrtle', '2-5', '2-4', '450', 'Trees and Shrubs', 'Melaleuca', 'ANC', 'M') ,
# (143, 'B', 'gibbosa', 'slender honey myrtle', '2-3', '2-3', '400', 'Trees and Shrubs', 'Melaleuca', 'ANC', 'M') ,
# (144, 'B', 'halmaturorum', 'SA swamp paperbark', '2-6', '2-6', '350', 'Trees and Shrubs', 'Melaleuca', 'ANC', 'M') ,
# (145, 'B', 'lanceolata', 'dryland tea tree', '3-8', '3-5', '250', 'Trees and Shrubs', 'Melaleuca', 'ANC', 'R') ,
# (146, 'B', 'squamea', 'swamp honey myrtle', '1-3', '1-3', '500', 'Trees and Shrubs', 'Melaleuca', 'AN', 'R') ,
# (147, 'B', 'squarrosa', 'scented paperbark', '2-5', '2-4', '550', 'Trees and Shrubs', 'Melaleuca', 'ANC', 'R') ,
# (148, 'B', 'wilsonii', 'Wilson’s honey myrtle', '1-2', '1-3', '400', 'Trees and Shrubs', 'Melaleuca', 'ANC', 'M') ,
# (149, 'G', 'ciliata', 'fringed heath myrtle', '0.5-1', '0.5-2', '500', 'Trees and Shrubs', 'Micromyrtus', 'AN/C', 'R') ,
# (150, 'G', 'floribundum', 'slender myoporum', '2-3', '2-3', '500', 'Trees and Shrubs', 'Myoporum', 'AN/C', 'R') ,
# (151, 'G', 'montanum', 'water bush', '1-2', '1.5-2.5', '400', 'Trees and Shrubs', 'Myoporum', 'ANC', 'R') ,
# (152, 'B', 'petiolatum   ', 'sticky boobialla', '1-2.5', '1-3', '350', 'Trees and Shrubs', 'Myoporum', 'ANC', 'R') ,
# (153, 'B', 'platycarpum', 'false sandalwood', '3-6', '2-4', '300', 'Trees and Shrubs', 'Myoporum', 'ANC', 'M') ,
# (154, 'B', 'axillaris', 'coast daisy-bush', '2-3', '1.5-2', '400', 'Trees and Shrubs', 'Olearia', 'ANC', 'R') ,
# (155, 'B', 'pannosa', 'silver-leaved daisy', '1-2', '1-2', '400', 'Trees and Shrubs', 'Olearia', 'ANC', 'R') ,
# (156, 'G', 'phlogopappa', 'Otway daisy-bush', '1-2', '1-2', '550', 'Trees and Shrubs', 'Olearia', 'AN', 'M') ,
# (157, 'B', 'pimeleoides', 'showy daisy-bush', '0.5-1', '0.5-1', '400', 'Trees and Shrubs', 'Olearia', 'ANC', 'M') ,
# (158, 'B', 'ramulosa', 'twiggy daisy-bush', '1-1.5', '1-2', '500', 'Trees and Shrubs', 'Olearia', 'AN/C', 'M') ,
# (159, 'G', 'angustifolia ssp angustifolia', 'narrow leaved wax flower', '1-1.5', '1-1.5', '450', 'Trees and Shrubs', 'Philotheca Syn:Eriostemon', 'AN/C', 'R') ,
# (160, 'G', 'myoporoides ', 'native daphne', '1-2', '1-2', '550', 'Trees and Shrubs', 'Philotheca Syn:Eriostemon', 'AN/C', 'R') ,
# (161, 'G', 'glauca', 'smooth rice flower', '0.1-1', '0.3-1.5', '400', 'Trees and Shrubs', 'Pimelea', 'ANC', 'M') ,
# (162, 'B', 'obtusangulum', 'common flat pea', '0.3-1', '0.5-1', '550', 'Trees and Shrubs', 'Platylobium', 'AN', 'M') ,
# (163, 'G', 'aspalathoides', 'scarlet mintbush', '0.5', '0.5', '400', 'Trees and Shrubs', 'Prostanthera', 'ANC', 'M') ,
# (164, 'G', 'serpyllifolia ssp microphylla', 'small-leaved mintbush', '0.5', '0.5', '350', 'Trees and Shrubs', 'Prostanthera', 'ANC', 'M') ,
# (165, 'B', 'daphnoides', 'long-leaved bush-pea', '1-2', '0.5-1', '550', 'Trees and Shrubs', 'Pultenaea', 'AN/C', 'M') ,
# (166, 'B', 'largiflorens', 'twiggy bush-pea', '1-1.5', '0.5-1.5', '550', 'Trees and Shrubs', 'Pultenaea', 'AN/C', 'M') ,
# (167, 'B', 'candolleana', 'seaberry saltbush', '1-1.5', '1-1.5', '350', 'Trees and Shrubs', 'Rhagodia', 'ANC', 'M') ,
# (168, 'B', 'crassifolia', 'fleshy saltbush', '1.5', '1.5', '350', 'Trees and Shrubs', 'Rhagodia', 'ANC', 'R') ,
# (169, 'B', 'parabolica', 'fragrant saltbush', '1-2', '1-2', '350', 'Trees and Shrubs', 'Rhagodia', 'ANC', 'R') ,
# (170, 'B', 'artemisioides ssp artemisioides', 'silver cassia', '1-2.5', '1-2.5', '250', 'Trees and Shrubs', 'Senna', 'ANC', 'M') ,
# (171, 'B', 'laciniatum', 'large kangaroo apple', '1-3', '1-3', '500', 'Trees and Shrubs', 'Solanum ', 'AN', 'M') ,
# (172, 'G', 'smithii', 'lilly pilly', '5-15', '5-8', '550', 'Trees and Shrubs', 'Syzygium', 'ANC', 'M') ,
# (173, 'G', 'ciliata', 'pink bells', '0.5', '0.5', '500', 'Trees and Shrubs', 'Tetratheca', 'AN', 'M') ,
# (174, 'G', 'pilosa', 'pink-eyed susan', '0.2-0.5', '0.2-0.5', '550', 'Trees and Shrubs', 'Tetratheca', 'AN', 'M') ,
# (175, 'G', 'thymifolia', 'black eyed susan', '0.5', '0.5', '500', 'Trees and Shrubs', 'Tetratheca', 'AN', 'M') ,
# (176, 'B', 'petalocalyx', 'paper flower', '0.6', '0.6-1', '450', 'Trees and Shrubs', 'Thomasia', 'ANC', 'M') ,
# (177, 'G', 'calycina', 'Grampians thryptomene', '1-2', '1-2', '600', 'Trees and Shrubs', 'Thryptomene', 'AN', 'M') ,
# (178, 'B', 'juncea', 'golden spray', '4-6', '2-4', '650', 'Trees and Shrubs', 'Viminaria', 'AN/C', 'M') ,
# (179, 'G', 'eremicola', 'slender westringia', '1-1.5', '1-1.5', '250', 'Trees and Shrubs', 'Westringia ', 'ANC', 'R') ,
# (180, 'G', 'glabra', 'violet westringia', '1-1.5', '1-1.5', '550', 'Trees and Shrubs', 'Westringia ', 'AN/C', 'M') ,
# (181, 'G', 'australis', 'austral bugle', '0.3', '0.5-1', '400', 'Groundcover', 'Ajuga', 'ANC', 'R') ,
# (182, 'B', 'semibaccata', 'berry saltbush', '0.1-0.3', '1-3', '300', 'Groundcover', 'Atriplex', 'ANC', 'R') ,
# (183, 'B', 'suberecta', 'lagoon saltbush', '0.1-0.6', '1-2', '300', 'Groundcover', 'Atriplex', 'ANC', 'R') ,
# (184, 'G', 'multifida var. dilatata', 'cut-leaf daisy', '0.3', '0.5-1', '400', 'Groundcover', 'Brachyscome ', 'AN/C', 'R') ,
# (185, 'B', 'rossii', 'karkalla', '0.1', '2-3', '300', 'Groundcover', 'Carpobrotus', 'ANC', 'R') ,
# (186, 'G', 'baxteri', 'fringed everlasting', '0.2-0.4', '0.3-0.6', '450', 'Groundcover', 'Chrysocephalum ', 'ANC', 'M') ,
# (187, 'G', 'blackiana', 'goodenia', '0.1-0.2', '0.2-0.5', '500', 'Groundcover', 'Goodenia', 'ANC', 'M') ,
# (188, 'G', 'varia', 'sticky goodenia', '0.1-0.6', '0.5-1.5', '350', 'Groundcover', 'Goodenia', 'ANC', 'M') ,
# (189, 'G', 'scorpioides', 'button everlasting', '0.2-0.5', '0.2-0.3', '400', 'Groundcover', 'Helichrysum', 'AN/C', 'R') ,
# (190, 'G', 'obtusifolia', 'showy guinea flower', '0.1', '0.2-1', '500', 'Groundcover', 'Hibbertia', 'AN', 'M') ,
# (191, 'G', 'riparia', 'erect guinea flower', '0.1-0.5', '0.3-0.8', '400', 'Groundcover', 'Hibbertia', 'AN', 'M') ,
# (192, 'B', 'prostrata', 'running postman', '0.1', '1.5-4', '450', 'Groundcover', 'Kennedia', 'ANC', 'M') ,
# (193, 'G', 'pomifera', 'muntries', '0.2', '2-4', '500', 'Groundcover', 'Kunzea', 'ANC', 'M') ,
# (194, 'G', 'australe Low Form', 'austral storksbill', '0.3-0.7', '0.5-1.5', '400', 'Groundcover', 'Pelargonium', 'AN/C', 'M') ,
# (195, 'G', 'pedunculata', 'trailing pratia', '0.1', '0.4-2', '500', 'Groundcover', 'Pratia', 'ANC', 'M') ,
# (196, 'G', 'pedunculata', 'matted bush-pea', '0.1', '1-3', '500', 'Groundcover', 'Pultenaea', 'AN/C', 'M') ,
# (197, 'G', 'albida', 'small fruited fan flower', '0.3-0.6', '0.6-1', '500', 'Groundcover', 'Scaevola', 'AN/C', 'R') ,
# (198, 'G', 'calendulacea', 'dune fan flower', '0.4', '1', '500', 'Groundcover', 'Scaevola', 'ANC', 'M') ,
# (199, 'G', 'hookeri', 'alpine fan flower', '0.1-0.2', '1-1.5', '500', 'Groundcover', 'Scaevola', 'AN', 'M') ,
# (200, 'G', 'hederacea', 'native violet', '0.2', '1-4', '600', 'Groundcover', 'Viola', 'ANC', 'R') ,
# (201, 'B', 'violacea Climbing form', 'native lilac', '1.5-2', '2-3', '500', 'Climbers', 'Hardenbergia', 'ANC', 'M') ,
# (202, 'B', 'adpressa', 'climbing lignum', '3-4', '3-4', '500', 'Climbers', 'Muehlenbeckia', 'ANC', 'M') ,
# (203, 'B', 'behriana', 'brush wiregrass', '0.15-.3', '0.2-0.3', '300', 'Grasses', 'Aristida ', 'ANC', 'R') ,
# (204, 'B', 'caespitosa', 'common wallaby-grass', '0.2-0.8', '0.1-0.3', '300', 'Grasses', 'Austrodanthonia  syn. Danthonia', 'ANC', 'R') ,
# (205, 'B', 'eriantha', 'hill wallaby-grass', '0.2-0.7', '0.4', '300', 'Grasses', 'Austrodanthonia  syn. Danthonia', 'ANC', 'R') ,
# (206, 'B', 'fulva syn. A. linkii', 'wallaby-grass', '0.4-0.7', '0.5', '500', 'Grasses', 'Austrodanthonia  syn. Danthonia', 'ANC', 'R') ,
# (207, 'B', 'geniculata', 'kneed wallaby-grass', '0.1-0.5', '0.1-0.3', '400', 'Grasses', 'Austrodanthonia  syn. Danthonia', 'ANC', 'R') ,
# (208, 'B', 'pilosa', 'velvet wallaby-grass', '0.2-0.9', '0.4', '400', 'Grasses', 'Austrodanthonia  syn. Danthonia', 'ANC', 'R') ,
# (209, 'B', 'elegantissima', 'elegant spear-grass', '1', '1', '350', 'Grasses', 'Austrostipa  syn. Stipa', 'ANC', 'R') ,
# (210, 'B', 'nodosa', 'spear-grass', '0.5-1', '0.5-1', '350', 'Grasses', 'Austrostipa  syn. Stipa', 'ANC', 'R') ,
# (211, 'B', 'macra', 'red-leg grass', '0.4-0.8', '0.4-0.8', '300', 'Grasses', 'Bothriochloa', 'ANC', 'R') ,
# (212, 'B', 'distichophylla', 'emu-grass', '0.4', '1-2', '350', 'Grasses', 'Distichlis', 'ANC', 'R') ,
# (213, 'B', 'scaber var scaber', 'common wheat-grass', '0.2-1', '0.3-0.5', '300', 'Grasses', 'Elymus', 'ANC', 'R') ,
# (214, 'B', 'nigricans', 'bottle washers', '0.2-0.5', '0.5', '350', 'Grasses', 'Enneapogon', 'ANC', 'R') ,
# (215, 'B', 'labillardieri ', 'tussock grass ', '0.3-1', '0.3-0.7', '400', 'Grasses', 'Poa', 'ANC', 'R') ,
# (216, 'B', 'poiformis', 'blue tussock grass', '0.6-1.2', '0.5-1.5', '350', 'Grasses', 'Poa', 'ANC', 'R') ,
# (217, 'B', 'sieberiana', 'grey tussock grass', '0.3-0.8', '0.3-0.8', '500', 'Grasses', 'Poa', 'ANC', 'M') ,
# (218, 'B', 'scariosa', 'porcupine grass', '0.6', '1', '300', 'Grasses', 'Triodia', 'ANC', 'M') ,
# (219, 'B', 'tasmanica', 'Tasman flax-lily', '0.6-1.7', '0.5-2', '650', 'Other Strap-leaved Plants', 'Dianella', 'AN', 'M') ,
# (220, 'B', 'moraea', 'butterfly flag', '0.3-0.6', '0.5-1', '550', 'Other Strap-leaved Plants', 'Diplarrena', 'ANC', 'R') ,
# (221, 'B', 'effusa', 'scented mat-rush', '0.2-0.5', '0.2-0.5', '400', 'Other Strap-leaved Plants', 'Lomandra', 'ANC', 'M') ,
# (222, 'B', 'longifolia', 'spiny headed mat-rush', '0.5-1', '0.5-1', '500', 'Other Strap-leaved Plants', 'Lomandra', 'ANC', 'R') ,
# (223, 'B', 'micrantha ssp micrantha', 'small-flowered mat-rush', '0.2-0.8', '0.2-0.8', '500', 'Other Strap-leaved Plants', 'Lomandra', 'ANC', 'R') ,
# (224, 'B', 'multiflorus', 'morning iris', '0.3-0.6', '0.4-1', '450', 'Other Strap-leaved Plants', 'Orthrosanthus', 'ANC', 'M') ,
# (225, 'B', 'occidentalis', 'long purple flag', '0.5', '0.5', '500', 'Other Strap-leaved Plants', 'Patersonia', 'AN', 'M') ,
# (226, 'B', 'australis', 'Austral grass tree', '0.5-2', '0.6-1', '500', 'Other Strap-leaved Plants', 'Xanthorrhoea', 'ANC', 'R') ,
# (227, 'B', 'strictum', 'vanilla lily', '0.4', '0.4', '400', 'Bulbs and Lilies', 'Arthropodium ', 'ANC', 'M') ,
# (228, 'B', 'bulbosa', 'native leek', '0.3', '0.3', '500', 'Bulbs and Lilies', 'Bulbine ', 'ANC', 'M') ,
# (229, 'B', 'umbellata', 'milkmaids', '0.3', '0.2', '500', 'Bulbs and Lilies', 'Burchardia', 'ANC', 'M') ,
# (230, 'B', 'purpureum', 'purple bells', '0.2-0.5', '0.2', '400', 'Bulbs and Lilies', 'Calostemma', 'ANC', 'M') ,
# (231, 'G', 'asiatica', 'pennywort', '0.1-0.4', '0.5-1', '500', 'Aquatic and Riparian Zone Plants', 'Centella', 'ANC', 'S') ,
# (232, 'G', 'anceps  syn: alata', 'angled lobelia', '0.1-0.3', '0.3-2', '500', 'Aquatic and Riparian Zone Plants', 'Lobelia ', 'AN/C', 'M') ,
# (233, 'G', 'pumilio', 'swamp mazus', '0.1', '1', '600', 'Aquatic and Riparian Zone Plants', 'Mazus ', 'ANC', 'M') ,
# (234, 'G', 'australis', 'river mint', '0.3-0.8', '0.3-1.5', '600', 'Aquatic and Riparian Zone Plants', 'Mentha ', 'AN', 'M') ,
# (235, 'G', 'repens', 'creeping monkey flower', '0.2', '1-2', '500', 'Aquatic and Riparian Zone Plants', 'Mimulus ', 'ANC', 'M') ,
# (236, 'B', 'fascicularis', 'tassel sedge', '1', '1', 'AQU', 'Rushes and Sedges', 'Carex', 'ANC', 'R') ,
# (237, 'B', 'gunniana', 'mountain sedge', '0.2-0.7', '0.5-1', 'AQU', 'Rushes and Sedges', 'Carex', 'ANC', 'M') ,
# (238, 'B', 'acuta', 'common spike rush', '0.3-0.9', '2-3', 'AQU', 'Rushes and Sedges', 'Eleocharis', 'AN/C', 'M') ,
# (239, 'B', 'filum', 'chaffy saw sedge', '1-1.5', '1-1.5', '550', 'Rushes and Sedges', 'Gahnia', 'AN/C', 'R') ,
# (240, 'B', 'inundata', 'swamp club rush', '0.5', '0.5-1', 'AQU', 'Rushes and Sedges', 'Isolepis ', 'ANC', 'R') ,
# (241, 'B', 'validus', 'river club-rush', '1.5-2.5', '1.5-3', 'AQU', 'Rushes and Sedges', 'Schoenoplectus ', 'ANC', 'R') ,

# %% [markdown]
# ### df_so_tex

# %%
df_so_tex = df[['plantid', 'Soil texture']]

# %%
new_df = pd.DataFrame(columns=['plantid', 'Soil texture'])

for index, row in df_so_tex.iterrows():
    new_list = row['Soil texture'].replace('/',',').replace(' ',',').split(',')
    new_list = [i for i in new_list if i != '']
    for each in new_list:
        tmp = pd.DataFrame({'plantid': [index], 'Soil texture': [each]})
        new_df = new_df.append(tmp, ignore_index = True)

# %%
new_df
# Out:
#     plantid Soil texture
# 0         0           Sa
# 1         0           Lo
# 2         0           Cl
# 3         1           Sa
# 4         1           Lo
# 5         1           Li
# 6         2           Sa
# 7         2           Lo
# 8         2           Cl
# 9         2           Li
# 10        3           Sa
# 11        3           Lo
# 12        3           Cl
# 13        3           Li
# 14        4           Sa
# 15        4           Lo
# 16        4           Li
# 17        5           Lo
# 18        5           Cl
# 19        6           Sa
# 20        6           Lo
# 21        7           Sa
# 22        7           Lo
# 23        7           Cl
# 24        8           Sa
# 25        8           Lo
# 26        9           Lo
# 27        9           Cl
# 28       10           Sa
# 29       10           Lo
# ..      ...          ...
# 682     231           Lo
# 683     231           Cl
# 684     232           Lo
# 685     232           Cl
# 686     233           Sa
# 687     233           Lo
# 688     233           Cl
# 689     234           Sa
# 690     234           Lo
# 691     234           Cl
# 692     235           Sa
# 693     235           Lo
# 694     235           Cl
# 695     236           Sa
# 696     236           Lo
# 697     236           Cl
# 698     237           Sa
# 699     237           Lo
# 700     237           Cl
# 701     238           Sa
# 702     238           Lo
# 703     238           Cl
# 704     239           Sa
# 705     239           Lo
# 706     240           Sa
# 707     240           Lo
# 708     240           Cl
# 709     241           Sa
# 710     241           Lo
# 711     241           Cl
#
# [712 rows x 2 columns]

# %%
new_list = []
for index, row in new_df.iterrows():
    new_list.append((row['plantid'], row['Soil texture']))

# %% [markdown]
# ### df_fl

# %%
df_fl = df[['plantid','Flower (time)']]

# %%
df_fl['Flower (time)'].unique()
# Out:
# array(['W,Sp', 'W, Sp', 'Sp', 'A,W,Sp', 'Sp,S', 'W,Sp,S', 'A,W', 'F',
#        'Sp,S,A', 'A, W', 'Sp, S', 'S, A', 'S', 'S,W,Sp', 'S,W', 'S,A',
#        'S, W', 'Sp, S,A', 'All year', '`W,Sp', 'Sp,A', 'Sp,Su', 'A'],
#       dtype=object)

# %%
new_df
# Out:
#   plantid Flower (time)
# 0       0             W
# 1       0            Sp
# 2       1             W
# 3       1            Sp
# 4       2             W
# 5       2            Sp
# 6       3             W
# 7       3            Sp
# 8       4             W
# 9       4            Sp

# %%
new_df = pd.DataFrame(columns=['plantid', 'Flower (time)'])
new_list = []
for index, row in df_fl.iterrows():
    if row['Flower (time)'] == 'All year':
        tmp = pd.DataFrame({'plantid': [index], 'Flower (time)': ['All year']})
        new_df = new_df.append(tmp, ignore_index = True)
        continue
    
    new_list = row['Flower (time)'].replace(' ',',').split(',')
    new_list = [i for i in new_list if i != '']
    for each in new_list:
        if each == 'Su':
            each = 'S'
        tmp = pd.DataFrame({'plantid': [index], 'Flower (time)': [each]})
        new_df = new_df.append(tmp, ignore_index = True)

# %%
new_list = []
for index, row in new_df.iterrows():
    new_list.append((row['plantid'], row['Flower (time)']))

# %%
new_df['Flower (time)'].unique()
# Out:
# array(['W', 'Sp', 'A', 'S', 'F', 'All year', '`W'], dtype=object)

# %%
new_df[new_df['Flower (time)'] ==  '`W']
# Out:
#     plantid Flower (time)
# 335     187            `W

# %%
new_list
# Out:
# [(0, 'W'),
#  (0, 'Sp'),
#  (1, 'W'),
#  (1, 'Sp'),
#  (2, 'W'),
#  (2, 'Sp'),
#  (3, 'W'),
#  (3, 'Sp'),
#  (4, 'W'),
#  (4, 'Sp'),
#  (5, 'W'),
#  (5, 'Sp'),
#  (6, 'W'),
#  (6, 'Sp'),
#  (7, 'W'),
#  (7, 'Sp'),
#  (8, 'W'),
#  (8, 'Sp'),
#  (9, 'Sp'),
#  (10, 'Sp'),
#  (11, 'Sp'),
#  (12, 'W'),
#  (12, 'Sp'),
#  (13, 'W'),
#  (13, 'Sp'),
#  (14, 'W'),
#  (14, 'Sp'),
#  (15, 'Sp'),
#  (16, 'Sp'),
#  (17, 'W'),
#  (17, 'Sp'),
#  (18, 'Sp'),
#  (19, 'A'),
#  (19, 'W'),
#  (19, 'Sp'),
#  (20, 'W'),
#  (20, 'Sp'),
#  (21, 'W'),
#  (21, 'Sp'),
#  (22, 'W'),
#  (22, 'Sp'),
#  (23, 'W'),
#  (23, 'Sp'),
#  (24, 'Sp'),
#  (24, 'S'),
#  (25, 'W'),
#  (25, 'Sp'),
#  (26, 'Sp'),
#  (27, 'W'),
#  (27, 'Sp'),
#  (27, 'S'),
#  (28, 'W'),
#  (28, 'Sp'),
#  (28, 'S'),
#  (29, 'W'),
#  (29, 'Sp'),
#  (30, 'Sp'),
#  (30, 'S'),
#  (31, 'Sp'),
#  (32, 'Sp'),
#  (32, 'S'),
#  (33, 'A'),
#  (33, 'W'),
#  (33, 'Sp'),
#  (34, 'A'),
#  (34, 'W'),
#  (35, 'A'),
#  (35, 'W'),
#  (36, 'A'),
#  (36, 'W'),
#  (37, 'F'),
#  (38, 'F'),
#  (39, 'F'),
#  (40, 'F'),
#  (41, 'Sp'),
#  (41, 'S'),
#  (42, 'F'),
#  (43, 'Sp'),
#  (43, 'S'),
#  (43, 'A'),
#  (44, 'A'),
#  (44, 'W'),
#  (45, 'Sp'),
#  (46, 'A'),
#  (46, 'W'),
#  (47, 'F'),
#  (48, 'A'),
#  (48, 'W'),
#  (48, 'Sp'),
#  (49, 'Sp'),
#  (49, 'S'),
#  (50, 'Sp'),
#  (50, 'S'),
#  (51, 'S'),
#  (51, 'A'),
#  (52, 'Sp'),
#  (52, 'S'),
#  (53, 'Sp'),
#  (53, 'S'),
#  (54, 'Sp'),
#  (55, 'W'),
#  (55, 'Sp'),
#  (56, 'S'),
#  (57, 'Sp'),
#  (58, 'S'),
#  (58, 'A'),
#  (59, 'A'),
#  (59, 'W'),
#  (59, 'Sp'),
#  (60, 'A'),
#  (60, 'W'),
#  (61, 'S'),
#  (61, 'W'),
#  (61, 'Sp'),
#  (62, 'S'),
#  (62, 'A'),
#  (63, 'Sp'),
#  (64, 'Sp'),
#  (65, 'Sp'),
#  (65, 'S'),
#  (66, 'Sp'),
#  (66, 'S'),
#  (67, 'Sp'),
#  (67, 'S'),
#  (68, 'Sp'),
#  (68, 'S'),
#  (69, 'W'),
#  (69, 'Sp'),
#  (69, 'S'),
#  (70, 'Sp'),
#  (70, 'S'),
#  (71, 'W'),
#  (71, 'Sp'),
#  (72, 'S'),
#  (72, 'W'),
#  (73, 'S'),
#  (73, 'A'),
#  (74, 'S'),
#  (74, 'A'),
#  (75, 'S'),
#  (75, 'A'),
#  (76, 'Sp'),
#  (76, 'S'),
#  (77, 'S'),
#  (77, 'A'),
#  (78, 'S'),
#  (79, 'Sp'),
#  (80, 'Sp'),
#  (80, 'S'),
#  (81, 'W'),
#  (81, 'Sp'),
#  (82, 'W'),
#  (82, 'Sp'),
#  (82, 'S'),
#  (83, 'S'),
#  (83, 'A'),
#  (84, 'W'),
#  (84, 'Sp'),
#  (85, 'S'),
#  (86, 'A'),
#  (86, 'W'),
#  (86, 'Sp'),
#  (87, 'Sp'),
#  (87, 'S'),
#  (88, 'Sp'),
#  (88, 'S'),
#  (89, 'A'),
#  (89, 'W'),
#  (89, 'Sp'),
#  (90, 'A'),
#  (90, 'W'),
#  (91, 'A'),
#  (91, 'W'),
#  (91, 'Sp'),
#  (92, 'S'),
#  (93, 'A'),
#  (93, 'W'),
#  (93, 'Sp'),
#  (94, 'Sp'),
#  (94, 'S'),
#  (94, 'A'),
#  (95, 'S'),
#  (95, 'W'),
#  (96, 'S'),
#  (97, 'F'),
#  (98, 'W'),
#  (98, 'Sp'),
#  (99, 'A'),
#  (99, 'W'),
#  (100, 'S'),
#  (101, 'S'),
#  (101, 'A'),
#  (102, 'Sp'),
#  (102, 'S'),
#  (103, 'Sp'),
#  (104, 'Sp'),
#  (105, 'A'),
#  (105, 'W'),
#  (106, 'Sp'),
#  (106, 'S'),
#  (107, 'S'),
#  (107, 'A'),
#  (108, 'Sp'),
#  (108, 'S'),
#  (108, 'A'),
#  (109, 'S'),
#  (110, 'Sp'),
#  (110, 'S'),
#  (111, 'Sp'),
#  (111, 'S'),
#  (112, 'Sp'),
#  (112, 'S'),
#  (113, 'Sp'),
#  (114, 'W'),
#  (114, 'Sp'),
#  (114, 'S'),
#  (115, 'Sp'),
#  (115, 'S'),
#  (116, 'S'),
#  (117, 'A'),
#  (117, 'W'),
#  (118, 'W'),
#  (118, 'Sp'),
#  (119, 'W'),
#  (119, 'Sp'),
#  (120, 'W'),
#  (120, 'Sp'),
#  (121, 'W'),
#  (121, 'Sp'),
#  (122, 'W'),
#  (122, 'Sp'),
#  (123, 'Sp'),
#  (124, 'Sp'),
#  (125, 'A'),
#  (125, 'W'),
#  (125, 'Sp'),
#  (126, 'Sp'),
#  (127, 'Sp'),
#  (127, 'S'),
#  (128, 'W'),
#  (128, 'Sp'),
#  (129, 'Sp'),
#  (129, 'S'),
#  (130, 'Sp'),
#  (130, 'S'),
#  (131, 'W'),
#  (131, 'Sp'),
#  (132, 'Sp'),
#  (132, 'S'),
#  (133, 'Sp'),
#  (134, 'Sp'),
#  (134, 'S'),
#  (135, 'Sp'),
#  (136, 'W'),
#  (136, 'Sp'),
#  (137, 'F'),
#  (138, 'W'),
#  (138, 'Sp'),
#  (139, 'Sp'),
#  (140, 'Sp'),
#  (141, 'Sp'),
#  (141, 'S'),
#  (142, 'Sp'),
#  (142, 'S'),
#  (143, 'S'),
#  (144, 'Sp'),
#  (144, 'S'),
#  (145, 'Sp'),
#  (145, 'S'),
#  (146, 'Sp'),
#  (147, 'Sp'),
#  (147, 'S'),
#  (148, 'Sp'),
#  (149, 'Sp'),
#  (149, 'S'),
#  (150, 'Sp'),
#  (150, 'S'),
#  (151, 'Sp'),
#  (152, 'W'),
#  (152, 'Sp'),
#  (152, 'S'),
#  (153, 'Sp'),
#  (154, 'Sp'),
#  (155, 'Sp'),
#  (156, 'Sp'),
#  (157, 'W'),
#  (157, 'Sp'),
#  (158, 'Sp'),
#  (158, 'S'),
#  (159, 'Sp'),
#  (160, 'W'),
#  (160, 'Sp'),
#  (161, 'W'),
#  (161, 'Sp'),
#  (161, 'S'),
#  (162, 'Sp'),
#  (162, 'S'),
#  (163, 'Sp'),
#  (163, 'S'),
#  (164, 'W'),
#  (164, 'Sp'),
#  (165, 'Sp'),
#  (166, 'W'),
#  (166, 'Sp'),
#  (167, 'W'),
#  (167, 'Sp'),
#  (168, 'Sp'),
#  (169, 'W'),
#  (169, 'Sp'),
#  (170, 'F'),
#  (171, 'Sp'),
#  (171, 'S'),
#  (172, 'Sp'),
#  (173, 'Sp'),
#  (174, 'Sp'),
#  (174, 'S'),
#  (175, 'W'),
#  (175, 'Sp'),
#  (176, 'Sp'),
#  (176, 'S'),
#  (177, 'W'),
#  (177, 'Sp'),
#  (178, 'S'),
#  (178, 'A'),
#  (179, 'F'),
#  (180, 'Sp'),
#  (181, 'Sp'),
#  (181, 'S'),
#  (182, 'F'),
#  (183, 'F'),
#  (184, 'All year'),
#  (185, 'W'),
#  (185, 'Sp'),
#  (185, 'S'),
#  (186, 'F'),
#  (187, '`W'),
#  (187, 'Sp'),
#  (188, 'W'),
#  (188, 'Sp'),
#  (189, 'W'),
#  (189, 'Sp'),
#  (190, 'Sp'),
#  (190, 'S'),
#  (191, 'Sp'),
#  (192, 'W'),
#  (192, 'Sp'),
#  (193, 'W'),
#  (193, 'Sp'),
#  (194, 'Sp'),
#  (194, 'S'),
#  (194, 'A'),
#  (195, 'Sp'),
#  (195, 'S'),
#  (196, 'W'),
#  (196, 'Sp'),
#  (197, 'F'),
#  (198, 'F'),
#  (199, 'F'),
#  (200, 'F'),
#  (201, 'W'),
#  (201, 'Sp'),
#  (202, 'Sp'),
#  (203, 'Sp'),
#  (203, 'A'),
#  (204, 'Sp'),
#  (204, 'S'),
#  (205, 'W'),
#  (205, 'Sp'),
#  (205, 'S'),
#  (206, 'Sp'),
#  (206, 'S'),
#  (207, 'Sp'),
#  (207, 'S'),
#  (207, 'A'),
#  (208, 'Sp'),
#  (208, 'S'),
#  (209, 'W'),
#  (209, 'Sp'),
#  (210, 'W'),
#  (210, 'Sp'),
#  (211, 'F'),
#  (212, 'Sp'),
#  (212, 'S'),
#  (213, 'W'),
#  (213, 'Sp'),
#  (214, 'Sp'),
#  (214, 'S'),
#  (215, 'Sp'),
#  (215, 'S'),
#  (216, 'Sp'),
#  (216, 'S'),
#  (217, 'Sp'),
#  (217, 'S'),
#  (218, 'W'),
#  (218, 'Sp'),
#  (219, 'Sp'),
#  (219, 'S'),
#  (220, 'Sp'),
#  (220, 'S'),
#  (221, 'W'),
#  (221, 'Sp'),
#  (222, 'Sp'),
#  (222, 'S'),
#  (223, 'A'),
#  (223, 'W'),
#  (223, 'Sp'),
#  (224, 'Sp'),
#  (225, 'Sp'),
#  (226, 'W'),
#  (226, 'Sp'),
#  (226, 'S'),
#  (227, 'Sp'),
#  (228, 'Sp'),
#  (229, 'Sp'),
#  (230, 'A'),
#  (231, 'Sp'),
#  (232, 'Sp'),
#  (232, 'S'),
#  (233, 'Sp'),
#  (233, 'S'),
#  (234, 'Sp'),
#  (235, 'Sp'),
#  (235, 'S'),
#  (236, 'Sp'),
#  (236, 'S'),
#  (237, 'Sp'),
#  (237, 'S'),
#  (238, 'Sp'),
#  (238, 'S'),
#  (239, 'F'),
#  (240, 'Sp'),
#  (241, 'S'),
#  (241, 'A')]

# %% [markdown]
# ### df_fc

# %%
df_fc = df[['plantid', 'Flower colour']]

# %%
df_fc['Flower colour'].unique()
# Out:
# array(['Y', 'R/Br', 'I', 'R,Br', 'W', 'Y/B', 'W, Pk', 'B,W', 'Pk',
#        'Cr/Pk', 'R', 'Cr', 'B', 'G,Cr', 'G/R', 'Y/R', 'O/R', 'Pu',
#        'Cr, Pk', 'Cr,Pk,R', 'R,Pk,Cr', 'Pk,Cr', 'Cr,Pk', 'Bu/R', 'R, G',
#        'Pk,W', 'Y,Br', 'Y/Pk', 'Pk,Pu', 'Pk/Pu', 'W/Pk', 'W,Pk,Pu',
#        'W,Pk', 'O&R', 'R,Y', 'B/Pu', 'Pk, W', 'Pu/Pk', 'B, W', 'O,Y',
#        'W&Pu', 'G', 'G/Br', 'Br', 'Br/Bl', 'G/Cr', 'Cr/Y', 'P', 'Pk, P'],
#       dtype=object)

# %%
df_fc
# Out:
#      plantid Flower colour
# 0          0             Y
# 1          1             Y
# 2          2             Y
# 3          3             Y
# 4          4             Y
# 5          5             Y
# 6          6             Y
# 7          7             Y
# 8          8             Y
# 9          9             Y
# 10        10             Y
# 11        11             Y
# 12        12             Y
# 13        13             Y
# 14        14             Y
# 15        15             Y
# 16        16             Y
# 17        17             Y
# 18        18             Y
# 19        19             Y
# 20        20             Y
# 21        21             Y
# 22        22             Y
# 23        23             Y
# 24        24             Y
# 25        25             Y
# 26        26             Y
# 27        27             Y
# 28        28             Y
# 29        29             Y
# ..       ...           ...
# 212      212            Br
# 213      213            Cr
# 214      214         Br/Bl
# 215      215          G/Cr
# 216      216            Cr
# 217      217          G/Cr
# 218      218          G/Cr
# 219      219             B
# 220      220             W
# 221      221          Cr/Y
# 222      222          Cr/Y
# 223      223             W
# 224      224             B
# 225      225            Pu
# 226      226             W
# 227      227             P
# 228      228             Y
# 229      229             W
# 230      230         Pk, P
# 231      231             I
# 232      232             P
# 233      233             P
# 234      234             W
# 235      235             P
# 236      236             G
# 237      237            Br
# 238      238            Br
# 239      239             B
# 240      240            Br
# 241      241             B
#
# [242 rows x 2 columns]

# %%
new_df = pd.DataFrame(columns=['plantid', 'Flower colour'])
new_list = []
for index, row in df_fc.iterrows():
    new_list = row['Flower colour'].replace(' ',',').replace('/',',').replace('&',",").split(',')
    new_list = [i for i in new_list if i != '']
    for each in new_list:
        if each == 'P':
            each = 'Pk'
        tmp = pd.DataFrame({'plantid': [index], 'Flower colour': [each]})
        new_df = new_df.append(tmp, ignore_index = True)

# %%
new_df
# Out:
#     plantid Flower colour
# 0         0             Y
# 1         1             Y
# 2         2             Y
# 3         3             Y
# 4         4             Y
# 5         5             Y
# 6         6             Y
# 7         7             Y
# 8         8             Y
# 9         9             Y
# 10       10             Y
# 11       11             Y
# 12       12             Y
# 13       13             Y
# 14       14             Y
# 15       15             Y
# 16       16             Y
# 17       17             Y
# 18       18             Y
# 19       19             Y
# 20       20             Y
# 21       21             Y
# 22       22             Y
# 23       23             Y
# 24       24             Y
# 25       25             Y
# 26       26             Y
# 27       27             Y
# 28       28             Y
# 29       29             Y
# ..      ...           ...
# 267     217             G
# 268     217            Cr
# 269     218             G
# 270     218            Cr
# 271     219             B
# 272     220             W
# 273     221            Cr
# 274     221             Y
# 275     222            Cr
# 276     222             Y
# 277     223             W
# 278     224             B
# 279     225            Pu
# 280     226             W
# 281     227            Pk
# 282     228             Y
# 283     229             W
# 284     230            Pk
# 285     230            Pk
# 286     231             I
# 287     232            Pk
# 288     233            Pk
# 289     234             W
# 290     235            Pk
# 291     236             G
# 292     237            Br
# 293     238            Br
# 294     239             B
# 295     240            Br
# 296     241             B
#
# [297 rows x 2 columns]

# %%
new_df['Flower colour'].unique()
# Out:
# array(['Y', 'R', 'Br', 'I', 'W', 'B', 'Pk', 'Cr', 'G', 'O', 'Pu', 'Bu',
#        'Bl'], dtype=object)

# %%
new_list = []
for index, row in new_df.iterrows():
    new_list.append((row['plantid'], row['Flower colour']))

# %%
new_list
# Out:
# [(0, 'Y'),
#  (1, 'Y'),
#  (2, 'Y'),
#  (3, 'Y'),
#  (4, 'Y'),
#  (5, 'Y'),
#  (6, 'Y'),
#  (7, 'Y'),
#  (8, 'Y'),
#  (9, 'Y'),
#  (10, 'Y'),
#  (11, 'Y'),
#  (12, 'Y'),
#  (13, 'Y'),
#  (14, 'Y'),
#  (15, 'Y'),
#  (16, 'Y'),
#  (17, 'Y'),
#  (18, 'Y'),
#  (19, 'Y'),
#  (20, 'Y'),
#  (21, 'Y'),
#  (22, 'Y'),
#  (23, 'Y'),
#  (24, 'Y'),
#  (25, 'Y'),
#  (26, 'Y'),
#  (27, 'Y'),
#  (28, 'Y'),
#  (29, 'Y'),
#  (30, 'R'),
#  (30, 'Br'),
#  (31, 'I'),
#  (32, 'I'),
#  (33, 'I'),
#  (34, 'R'),
#  (34, 'Br'),
#  (35, 'R'),
#  (35, 'Br'),
#  (36, 'R'),
#  (36, 'Br'),
#  (37, 'I'),
#  (38, 'I'),
#  (39, 'I'),
#  (40, 'I'),
#  (41, 'W'),
#  (42, 'Y'),
#  (43, 'Y'),
#  (44, 'Y'),
#  (44, 'B'),
#  (45, 'Y'),
#  (46, 'Y'),
#  (47, 'W'),
#  (47, 'Pk'),
#  (48, 'B'),
#  (48, 'W'),
#  (49, 'Pk'),
#  (50, 'Cr'),
#  (50, 'Pk'),
#  (51, 'R'),
#  (52, 'R'),
#  (53, 'Y'),
#  (54, 'Cr'),
#  (55, 'I'),
#  (56, 'R'),
#  (57, 'B'),
#  (58, 'W'),
#  (59, 'G'),
#  (59, 'Cr'),
#  (60, 'G'),
#  (60, 'R'),
#  (61, 'Cr'),
#  (62, 'Pk'),
#  (63, 'Y'),
#  (63, 'R'),
#  (64, 'O'),
#  (64, 'R'),
#  (65, 'I'),
#  (66, 'I'),
#  (67, 'B'),
#  (68, 'Pu'),
#  (69, 'Cr'),
#  (69, 'Pk'),
#  (70, 'W'),
#  (71, 'Pu'),
#  (72, 'W'),
#  (73, 'W'),
#  (74, 'W'),
#  (75, 'W'),
#  (76, 'Cr'),
#  (76, 'Pk'),
#  (77, 'W'),
#  (78, 'W'),
#  (79, 'Cr'),
#  (80, 'W'),
#  (81, 'Cr'),
#  (82, 'Cr'),
#  (83, 'Cr'),
#  (84, 'W'),
#  (85, 'W'),
#  (86, 'W'),
#  (87, 'Cr'),
#  (88, 'W'),
#  (89, 'W'),
#  (90, 'Cr'),
#  (90, 'Pk'),
#  (90, 'R'),
#  (91, 'R'),
#  (91, 'Pk'),
#  (91, 'Cr'),
#  (92, 'W'),
#  (93, 'Pk'),
#  (93, 'Cr'),
#  (94, 'Cr'),
#  (95, 'Cr'),
#  (96, 'W'),
#  (97, 'Cr'),
#  (98, 'W'),
#  (99, 'W'),
#  (100, 'W'),
#  (101, 'Cr'),
#  (102, 'Cr'),
#  (103, 'Cr'),
#  (104, 'W'),
#  (105, 'Cr'),
#  (105, 'Pk'),
#  (106, 'Cr'),
#  (107, 'W'),
#  (108, 'W'),
#  (109, 'W'),
#  (110, 'Y'),
#  (111, 'Y'),
#  (112, 'Y'),
#  (113, 'Bu'),
#  (113, 'R'),
#  (114, 'R'),
#  (114, 'G'),
#  (115, 'Cr'),
#  (116, 'W'),
#  (117, 'Y'),
#  (118, 'W'),
#  (119, 'W'),
#  (120, 'Pu'),
#  (121, 'W'),
#  (122, 'Pk'),
#  (123, 'Y'),
#  (124, 'Y'),
#  (125, 'Pu'),
#  (126, 'Y'),
#  (127, 'Pk'),
#  (127, 'W'),
#  (128, 'Pk'),
#  (128, 'W'),
#  (129, 'W'),
#  (130, 'W'),
#  (131, 'W'),
#  (132, 'Cr'),
#  (133, 'W'),
#  (134, 'Y'),
#  (134, 'Br'),
#  (135, 'W'),
#  (136, 'B'),
#  (137, 'I'),
#  (138, 'Y'),
#  (138, 'Pk'),
#  (139, 'Cr'),
#  (140, 'Cr'),
#  (141, 'W'),
#  (142, 'Pu'),
#  (143, 'Pu'),
#  (144, 'W'),
#  (145, 'Cr'),
#  (146, 'Pk'),
#  (146, 'Pu'),
#  (147, 'Cr'),
#  (148, 'Pk'),
#  (148, 'Pu'),
#  (149, 'W'),
#  (149, 'Pk'),
#  (150, 'W'),
#  (151, 'W'),
#  (152, 'W'),
#  (153, 'W'),
#  (154, 'W'),
#  (155, 'W'),
#  (156, 'W'),
#  (156, 'Pk'),
#  (156, 'Pu'),
#  (157, 'W'),
#  (158, 'W'),
#  (158, 'Pk'),
#  (159, 'W'),
#  (160, 'W'),
#  (161, 'W'),
#  (162, 'O'),
#  (162, 'R'),
#  (163, 'R'),
#  (163, 'Y'),
#  (164, 'R'),
#  (165, 'Y'),
#  (165, 'R'),
#  (166, 'Y'),
#  (166, 'R'),
#  (167, 'I'),
#  (168, 'I'),
#  (169, 'I'),
#  (170, 'Y'),
#  (171, 'B'),
#  (171, 'Pu'),
#  (172, 'W'),
#  (173, 'Pk'),
#  (173, 'W'),
#  (174, 'Pk'),
#  (175, 'Pk'),
#  (176, 'Pu'),
#  (176, 'Pk'),
#  (177, 'W'),
#  (177, 'Pk'),
#  (178, 'Y'),
#  (179, 'Pu'),
#  (180, 'B'),
#  (180, 'Pu'),
#  (181, 'Pk'),
#  (181, 'Pu'),
#  (182, 'I'),
#  (183, 'I'),
#  (184, 'Pu'),
#  (185, 'Pk'),
#  (186, 'W'),
#  (187, 'Y'),
#  (188, 'Y'),
#  (189, 'Y'),
#  (190, 'Y'),
#  (191, 'Y'),
#  (192, 'R'),
#  (192, 'Y'),
#  (193, 'Cr'),
#  (194, 'Pk'),
#  (195, 'B'),
#  (195, 'W'),
#  (196, 'O'),
#  (196, 'Y'),
#  (197, 'W'),
#  (198, 'B'),
#  (199, 'W'),
#  (200, 'W'),
#  (200, 'Pu'),
#  (201, 'Pu'),
#  (202, 'G'),
#  (203, 'Cr'),
#  (204, 'Cr'),
#  (205, 'Cr'),
#  (206, 'Cr'),
#  (207, 'Cr'),
#  (208, 'Cr'),
#  (209, 'G'),
#  (209, 'Br'),
#  (210, 'G'),
#  (210, 'Br'),
#  (211, 'Br'),
#  (212, 'Br'),
#  (213, 'Cr'),
#  (214, 'Br'),
#  (214, 'Bl'),
#  (215, 'G'),
#  (215, 'Cr'),
#  (216, 'Cr'),
#  (217, 'G'),
#  (217, 'Cr'),
#  (218, 'G'),
#  (218, 'Cr'),
#  (219, 'B'),
#  (220, 'W'),
#  (221, 'Cr'),
#  (221, 'Y'),
#  (222, 'Cr'),
#  (222, 'Y'),
#  (223, 'W'),
#  (224, 'B'),
#  (225, 'Pu'),
#  (226, 'W'),
#  (227, 'Pk'),
#  (228, 'Y'),
#  (229, 'W'),
#  (230, 'Pk'),
#  (230, 'Pk'),
#  (231, 'I'),
#  (232, 'Pk'),
#  (233, 'Pk'),
#  (234, 'W'),
#  (235, 'Pk'),
#  (236, 'G'),
#  (237, 'Br'),
#  (238, 'Br'),
#  (239, 'B'),
#  (240, 'Br'),
#  (241, 'B')]

# %% [markdown]
# ## API

# %%
import requests
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('http://httpbin.org/get', params=payload)

# %%
import requests
import json
api_url_base = 'https://trefle.io/api/plants'
api_token = 'NDdUcFg4SnVNbXlXcHFXTGZweUVJdz09'
headers = {'Content-Type': 'application/json',
           'Authorization': 'NDdUcFg4SnVNbXlXcHFXTGZweUVJdz09'}
response = requests.get(api_url_base, headers = headers)

print(response.status_code)
# Out:
# 200

# %%
import requests
payload = {'id': 123}
headers = {'content-type': 'application/json',
            'Authorization': 'NDdUcFg4SnVNbXlXcHFXTGZweUVJdz09'}
r = requests.get('https://trefle.io/api/kingdoms', headers = headers, params=payload)
json.loads(r.text)
# Out:
# [{'subkingdoms': [{'slug': 'tracheobionta',
#     'name': 'Tracheobionta',
#     'link': 'http://trefle.io/api/subkingdoms/1',
#     'id': 1}],
#   'slug': None,
#   'name': 'Plantae',
#   'id': 1}]

# %%
df['Soil pH'].unique()
# Out:
# array(['ANC', 'AN/C', 'AN'], dtype=object)

# %%
import requests
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('http://httpbin.org/get', params=payload)
print(r)
# Out:
# <Response [200]>

# %%
df
# Out:
#                                  Type            Genus Tube colour  \
# 0                    Trees and Shrubs          Acacia            B
# 1                    Trees and Shrubs          Acacia            B
# 2                    Trees and Shrubs          Acacia            B
# 3                    Trees and Shrubs          Acacia            B
# 4                    Trees and Shrubs          Acacia            B
# 5                    Trees and Shrubs          Acacia            B
# 6                    Trees and Shrubs          Acacia            B
# 7                    Trees and Shrubs          Acacia            B
# 8                    Trees and Shrubs          Acacia            B
# 9                    Trees and Shrubs          Acacia            B
# 10                   Trees and Shrubs          Acacia            B
# 11                   Trees and Shrubs          Acacia            B
# 12                   Trees and Shrubs          Acacia            B
# 13                   Trees and Shrubs          Acacia            B
# 14                   Trees and Shrubs          Acacia            B
# 15                   Trees and Shrubs          Acacia            B
# 16                   Trees and Shrubs          Acacia            B
# 17                   Trees and Shrubs          Acacia            B
# 18                   Trees and Shrubs          Acacia            B
# 19                   Trees and Shrubs          Acacia            B
# 20                   Trees and Shrubs          Acacia            B
# 21                   Trees and Shrubs          Acacia            B
# 22                   Trees and Shrubs          Acacia            B
# 23                   Trees and Shrubs          Acacia            B
# 24                   Trees and Shrubs          Acacia            B
# 25                   Trees and Shrubs          Acacia            B
# 26                   Trees and Shrubs          Acacia            B
# 27                   Trees and Shrubs          Acacia            B
# 28                   Trees and Shrubs          Acacia            B
# 29                   Trees and Shrubs          Acacia            B
# ..                                ...              ...         ...
# 212                           Grasses       Distichlis           B
# 213                           Grasses           Elymus           B
# 214                           Grasses       Enneapogon           B
# 215                           Grasses              Poa           B
# 216                           Grasses              Poa           B
# 217                           Grasses              Poa           B
# 218                           Grasses          Triodia           B
# 219         Other Strap-leaved Plants         Dianella           B
# 220         Other Strap-leaved Plants       Diplarrena           B
# 221         Other Strap-leaved Plants         Lomandra           B
# 222         Other Strap-leaved Plants         Lomandra           B
# 223         Other Strap-leaved Plants         Lomandra           B
# 224         Other Strap-leaved Plants    Orthrosanthus           B
# 225         Other Strap-leaved Plants       Patersonia           B
# 226         Other Strap-leaved Plants     Xanthorrhoea           B
# 227                  Bulbs and Lilies    Arthropodium            B
# 228                  Bulbs and Lilies         Bulbine            B
# 229                  Bulbs and Lilies       Burchardia           B
# 230                  Bulbs and Lilies       Calostemma           B
# 231  Aquatic and Riparian Zone Plants         Centella           G
# 232  Aquatic and Riparian Zone Plants         Lobelia            G
# 233  Aquatic and Riparian Zone Plants           Mazus            G
# 234  Aquatic and Riparian Zone Plants          Mentha            G
# 235  Aquatic and Riparian Zone Plants         Mimulus            G
# 236                 Rushes and Sedges            Carex           B
# 237                 Rushes and Sedges            Carex           B
# 238                 Rushes and Sedges       Eleocharis           B
# 239                 Rushes and Sedges           Gahnia           B
# 240                 Rushes and Sedges        Isolepis            B
# 241                 Rushes and Sedges  Schoenoplectus            B
#
#                      Botanical name              Common name Height (m)  \
# 0                         acinacea       round-leaved wattle        1-2
# 1                      argyrophylla        golden-grey mulga        1-5
# 2                      brachybotrya               grey mulga        2-4
# 3                       calamifolia                 wallowa         2-5
# 4                          farinosa             mealy wattle        1-2
# 5                        floribunda          gossamer wattle        4-7
# 6                     glandulicarpa         hairy-pod wattle        1-3
# 7                            gunnii       ploughshare wattle    0.2-0.8
# 8                         hakeoides             hakea wattle      2.5-4
# 9                          howittii            sticky wattle        4-8
# 10                         ligulata          umbrella wattle        2-4
# 11                          lineata          streaked wattle      0.5-3
# 12         longifolia var. sophorae           coastal wattle        2-5
# 13             melanoxylon SA forms                blackwood       7-20
# 14                       microcarpa             manna wattle        1-3
# 15                          montana            mallee wattle        2-4
# 16                       myrtifolia            myrtle wattle        1-2
# 17                        notabilis           notable wattle        3-6
# 18                        paradoxa            kangaroo thorn        2-4
# 19                          pendula            weeping myall       6-10
# 20                       pravissima            Oven’s wattle        4-8
# 21                        pycnantha            golden wattle        4-6
# 22                       retinodes                   wirilda        5-8
# 23                           rigens                   nealie        2-4
# 24                         rupicola              rock wattle      1-2.5
# 25                         salicina        Broughton willow        4-10
# 26   sclerophylla var. sclerophylla         hard-leaf wattle        1-2
# 27                      verniciflua           varnish wattle        3-5
# 28         verticillata ssp ovoidea            prickly moses        2-4
# 29                      wilhelmiana             dwarf nealie        1-3
# ..                              ...                      ...        ...
# 212                  distichophylla                emu-grass        0.4
# 213               scaber var scaber       common wheat-grass      0.2-1
# 214                       nigricans           bottle washers    0.2-0.5
# 215                  labillardieri            tussock grass       0.3-1
# 216                       poiformis       blue tussock grass    0.6-1.2
# 217                      sieberiana       grey tussock grass    0.3-0.8
# 218                        scariosa          porcupine grass        0.6
# 219                       tasmanica         Tasman flax-lily    0.6-1.7
# 220                          moraea           butterfly flag    0.3-0.6
# 221                          effusa         scented mat-rush    0.2-0.5
# 222                      longifolia    spiny headed mat-rush      0.5-1
# 223         micrantha ssp micrantha  small-flowered mat-rush    0.2-0.8
# 224                     multiflorus             morning iris    0.3-0.6
# 225                    occidentalis         long purple flag        0.5
# 226                       australis       Austral grass tree      0.5-2
# 227                        strictum             vanilla lily        0.4
# 228                         bulbosa              native leek        0.3
# 229                       umbellata                milkmaids        0.3
# 230                       purpureum             purple bells    0.2-0.5
# 231                        asiatica                pennywort    0.1-0.4
# 232              anceps  syn: alata           angled lobelia    0.1-0.3
# 233                         pumilio              swamp mazus        0.1
# 234                       australis               river mint    0.3-0.8
# 235                          repens   creeping monkey flower        0.2
# 236                    fascicularis             tassel sedge          1
# 237                        gunniana           mountain sedge    0.2-0.7
# 238                           acuta        common spike rush    0.3-0.9
# 239                           filum         chaffy saw sedge      1-1.5
# 240                        inundata          swamp club rush        0.5
# 241                         validus          river club-rush    1.5-2.5
#
#     Spread (m) Rain (mm) Soil texture Soil pH Frost Flower colour  \
# 0          1-2       300     Sa,Lo,Cl     ANC     R             Y
# 1          2-6       350     Sa,Lo,Li     ANC     R             Y
# 2        1.5-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 3          2-4       200  Sa,Lo,Cl,Li     ANC     M             Y
# 4          2-4       350   Sa, Lo, Li     ANC     M             Y
# 5          4-6       550        Lo,Cl    AN/C     M             Y
# 6          1-3       350        Sa,Lo     ANC     R             Y
# 7          1-2       500     Sa,Lo,Cl      AN     R             Y
# 8          3-5       250        Sa,Lo     ANC     R             Y
# 9          3-6       450        Lo,Cl     ANC     R             Y
# 10         4-6       150  Sa,Lo,Cl Li     ANC     R             Y
# 11         1-3       500     Sa,Lo,Cl     ANC     M             Y
# 12         4-8       450        Sa,Lo     ANC     M             Y
# 13        4-10       500        Lo,Cl    AN/C     R             Y
# 14         2-4       300  Sa,Cl,Lo,Li     ANC     R             Y
# 15         2-5       325  Sa,Cl,Lo,Li     ANC     R             Y
# 16         1-2       500        Lo,Cl    AN/C     M             Y
# 17         3-4       250     Lo,Li,Cl     ANC     R             Y
# 18         3-4       300  Sa,Lo,Cl,Li     ANC     M             Y
# 19         6-8       250        Lo,Cl     ANC     M             Y
# 20         4-8       500     Sa,Lo,Cl    AN/C     M             Y
# 21         2-6       450     Sa,Lo,Cl     ANC     M             Y
# 22         3-7       500        Lo,Cl     ANC     M             Y
# 23         2-4       200  Sa,Lo,Cl,Li     ANC     R             Y
# 24       1-2.5       350  Sa,Lo,Cl,Li     ANC     R             Y
# 25         3-5       300        Lo,Cl     ANC     R             Y
# 26         2-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 27         3-5       450     Sa,Lo,Cl    AN/C     M             Y
# 28         1-3       600        Lo,Cl    AN/C     M             Y
# 29         2-3       250     Cl,Lo,Li     ANC     R             Y
# ..         ...       ...          ...     ...   ...           ...
# 212        1-2       350     Sa,Lo,Cl     ANC     R            Br
# 213    0.3-0.5       300     Sa,Lo,Cl     ANC     R            Cr
# 214        0.5       350    Sa, Lo,Cl     ANC     R         Br/Bl
# 215    0.3-0.7       400   Sa, Lo, Cl     ANC     R          G/Cr
# 216    0.5-1.5       350     Sa,Lo,Cl     ANC     R            Cr
# 217    0.3-0.8       500   Sa, Lo, Cl     ANC     M          G/Cr
# 218          1       300        Sa,Lo     ANC     M          G/Cr
# 219      0.5-2       650     Sa,Lo,Cl      AN     M             B
# 220      0.5-1       550     Sa,Lo,Cl     ANC     R             W
# 221    0.2-0.5       400       Sa, Lo     ANC     M          Cr/Y
# 222      0.5-1       500   Sa, Lo, Cl     ANC     R          Cr/Y
# 223    0.2-0.8       500   Sa, Lo, Cl     ANC     R             W
# 224      0.4-1       450     Sa,Lo,Cl     ANC     M             B
# 225        0.5       500       Lo, Cl      AN     M            Pu
# 226      0.6-1       500    Sa, Lo,Cl     ANC     R             W
# 227        0.4       400     Sa,Lo,Cl     ANC     M             P
# 228        0.3       500     Sa,Lo,Cl     ANC     M             Y
# 229        0.2       500     Sa,Lo,Cl     ANC     M             W
# 230        0.2       400     Sa,Lo,Cl     ANC     M         Pk, P
# 231      0.5-1       500     Sa,Lo,Cl     ANC     S             I
# 232      0.3-2       500        Lo,Cl    AN/C     M             P
# 233          1       600     Sa,Lo,Cl     ANC     M             P
# 234    0.3-1.5       600     Sa,Lo,Cl      AN     M             W
# 235        1-2       500     Sa,Lo,Cl     ANC     M             P
# 236          1       AQU     Sa,Lo,Cl     ANC     R             G
# 237      0.5-1       AQU     Sa,Lo,Cl     ANC     M            Br
# 238        2-3       AQU     Sa,Lo,Cl    AN/C     M            Br
# 239      1-1.5       550        Sa,Lo    AN/C     R             B
# 240      0.5-1       AQU     Sa,Lo,Cl     ANC     R            Br
# 241      1.5-3       AQU     Sa,Lo,Cl     ANC     R             B
#
#     Flower (time)
# 0            W,Sp
# 1            W,Sp
# 2            W,Sp
# 3            W,Sp
# 4           W, Sp
# 5            W,Sp
# 6            W,Sp
# 7            W,Sp
# 8            W,Sp
# 9              Sp
# 10             Sp
# 11             Sp
# 12           W,Sp
# 13           W,Sp
# 14           W,Sp
# 15             Sp
# 16             Sp
# 17           W,Sp
# 18             Sp
# 19         A,W,Sp
# 20           W,Sp
# 21           W,Sp
# 22           W,Sp
# 23           W,Sp
# 24           Sp,S
# 25           W,Sp
# 26             Sp
# 27         W,Sp,S
# 28         W,Sp,S
# 29           W,Sp
# ..            ...
# 212          Sp,S
# 213          W,Sp
# 214          Sp,S
# 215         Sp, S
# 216         Sp,Su
# 217         Sp, S
# 218          W,Sp
# 219          Sp,S
# 220          Sp,S
# 221          W,Sp
# 222         Sp, S
# 223        A,W,Sp
# 224            Sp
# 225            Sp
# 226        W,Sp,S
# 227            Sp
# 228            Sp
# 229            Sp
# 230             A
# 231            Sp
# 232          Sp,S
# 233          Sp,S
# 234            Sp
# 235          Sp,S
# 236          Sp,S
# 237          Sp,S
# 238          Sp,S
# 239             F
# 240            Sp
# 241           S,A
#
# [242 rows x 13 columns]

# %%
import requests
payload = {'common_name':'blackwood'}
headers = {'content-type': 'application/json',
            'Authorization': 'NDdUcFg4SnVNbXlXcHFXTGZweUVJdz09'}
r = requests.get('https://trefle.io/api/plants', headers = headers, params=payload)
json.loads(r.text)
# Out:
# [{'slug': 'acacia-penninervis',
#   'scientific_name': 'Acacia penninervis',
#   'link': 'http://trefle.io/api/plants/101452',
#   'id': 101452,
#   'complete_data': False,
#   'common_name': 'blackwood'},
#  {'slug': 'acacia-melanoxylon',
#   'scientific_name': 'Acacia melanoxylon',
#   'link': 'http://trefle.io/api/plants/101419',
#   'id': 101419,
#   'complete_data': True,
#   'common_name': 'blackwood'}]

# %%
headers = {'content-type': 'application/json',
            'Authorization': 'NDdUcFg4SnVNbXlXcHFXTGZweUVJdz09'}
r = requests.get('https://trefle.io/api/plants/101452', headers = headers)
json.loads(r.text)
# Out:
# {'varieties': [],
#  'sub_species': [],
#  'scientific_name': 'Acacia penninervis',
#  'order': {'slug': 'fabales',
#   'name': 'Fabales',
#   'link': 'http://trefle.io/api/division_orders/8',
#   'id': 8},
#  'native_status': None,
#  'main_species': {'year': None,
#   'type': 'species',
#   'synonym': False,
#   'status': 'Unknown',
#   'specifications': {'toxicity': None,
#    'shape_and_orientation': None,
#    'regrowth_rate': None,
#    'nitrogen_fixation': None,
#    'max_height_at_base_age': {'ft': None, 'cm': None},
#    'mature_height': {'ft': None, 'cm': None},
#    'low_growing_grass': None,
#    'lifespan': None,
#    'leaf_retention': None,
#    'known_allelopath': None,
#    'growth_rate': None,
#    'growth_period': None,
#    'growth_habit': None,
#    'growth_form': None,
#    'fire_resistance': None,
#    'fall_conspicuous': None,
#    'coppice_potential': None,
#    'c_n_ratio': None,
#    'bloat': None},
#   'sources': [{'species_id': 101452,
#     'source_url': 'https://plants.usda.gov',
#     'name': 'USDA',
#     'last_update': '2019-01-11T09:40:21.316368'}],
#   'soils_adaptation': {'medium': None, 'fine': None, 'coarse': None},
#   'slug': 'acacia-penninervis',
#   'seed': {'vegetative_spread_rate': None,
#    'small_grain': None,
#    'seeds_per_pound': None,
#    'seedling_vigor': None,
#    'seed_spread_rate': None,
#    'commercial_availability': None,
#    'bloom_period': None},
#   'scientific_name': 'Acacia penninervis',
#   'propagation': {'tubers': None,
#    'sprigs': None,
#    'sod': None,
#    'seed': None,
#    'cuttings': None,
#    'corms': None,
#    'container': None,
#    'bulbs': None,
#    'bare_root': None},
#   'products': {'veneer': None,
#    'pulpwood': None,
#    'protein_potential': None,
#    'post': None,
#    'palatable_human': None,
#    'palatable_graze_animal': None,
#    'palatable_browse_animal': None,
#    'nursery_stock': None,
#    'naval_store': None,
#    'lumber': None,
#    'fuelwood': None,
#    'fodder': None,
#    'christmas_tree': None,
#    'berry_nut_seed': None},
#   'native_status': None,
#   'main_species_id': None,
#   'is_main_species': True,
#   'images': [{'url': 'https://upload.wikimedia.org/wikipedia/commons/3/3e/Acacia-tree.jpg'},
#    {'url': 'https://upload.wikimedia.org/wikipedia/commons/5/5c/Acacia_constricta_flower.jpg'},
#    {'url': 'https://upload.wikimedia.org/wikipedia/commons/d/d9/Acacia_penninervis_1.jpg'},
#    {'url': 'https://upload.wikimedia.org/wikipedia/commons/9/96/Australian_Capital_Territory_locator-MJC.png'},
#    {'url': 'https://upload.wikimedia.org/wikipedia/commons/9/98/Tree_template.svg'},
#    {'url': 'https://upload.wikimedia.org/wikipedia/commons/4/4f/Verticordia_plumosa_1.jpg'}],
#   'id': 101452,
#   'growth': {'temperature_minimum': {'deg_f': None, 'deg_c': None},
#    'shade_tolerance': None,
#    'salinity_tolerance': None,
#    'root_depth_minimum': {'inches': None, 'cm': None},
#    'resprout_ability': None,
#    'precipitation_minimum': {'inches': None, 'cm': None},
#    'precipitation_maximum': {'inches': None, 'cm': None},
#    'planting_density_minimum': {'sqm': None, 'acre': None},
#    'planting_density_maximum': {'sqm': None, 'acre': None},
#    'ph_minimum': None,
#    'ph_maximum': None,
#    'moisture_use': None,
#    'hedge_tolerance': None,
#    'frost_free_days_minimum': None,
#    'fire_tolerance': None,
#    'fertility_requirement': None,
#    'drought_tolerance': None,
#    'cold_stratification_required': None,
#    'caco_3_tolerance': None,
#    'anaerobic_tolerance': None},
#   'fruit_or_seed': {'seed_persistence': None,
#    'seed_period_end': None,
#    'seed_period_begin': None,
#    'seed_abundance': None,
#    'conspicuous': None,
#    'color': None},
#   'foliage': {'texture': None,
#    'porosity_winter': None,
#    'porosity_summer': None,
#    'color': None},
#   'flower': {'conspicuous': None, 'color': None},
#   'family_common_name': 'Pea family',
#   'duration': None,
#   'complete_data': False,
#   'common_name': 'blackwood',
#   'bibliography': None,
#   'author': None},
#  'images': [{'url': 'https://upload.wikimedia.org/wikipedia/commons/3/3e/Acacia-tree.jpg'},
#   {'url': 'https://upload.wikimedia.org/wikipedia/commons/5/5c/Acacia_constricta_flower.jpg'},
#   {'url': 'https://upload.wikimedia.org/wikipedia/commons/d/d9/Acacia_penninervis_1.jpg'},
#   {'url': 'https://upload.wikimedia.org/wikipedia/commons/9/96/Australian_Capital_Territory_locator-MJC.png'},
#   {'url': 'https://upload.wikimedia.org/wikipedia/commons/9/98/Tree_template.svg'},
#   {'url': 'https://upload.wikimedia.org/wikipedia/commons/4/4f/Verticordia_plumosa_1.jpg'}],
#  'id': 101452,
#  'hybrids': [],
#  'genus': {'slug': 'acacia',
#   'name': 'Acacia',
#   'link': 'http://trefle.io/api/genuses/21',
#   'id': 21},
#  'forms': [],
#  'family_common_name': 'Pea family',
#  'family': {'slug': 'fabaceae',
#   'name': 'Fabaceae',
#   'link': 'http://trefle.io/api/families/9',
#   'id': 9,
#   'common_name': 'Pea family'},
#  'duration': None,
#  'division': {'slug': 'magnoliophyta',
#   'name': 'Magnoliophyta',
#   'link': 'http://trefle.io/api/divisions/1',
#   'id': 1},
#  'cultivars': [],
#  'common_name': 'blackwood',
#  'class': {'slug': 'magnoliopsida',
#   'name': 'Magnoliopsida',
#   'link': 'http://trefle.io/api/division_classes/1',
#   'id': 1}}

# %%
import requests
payload = {'page_size': 100000000}
headers = {'content-type': 'application/json',
            'Authorization': 'NDdUcFg4SnVNbXlXcHFXTGZweUVJdz09'}
r = requests.get('https://trefle.io/api/plants', headers = headers, params=payload)
total = json.loads(r.text)

# %%
outF = open('myOutFile.txt','w')
for line in total:
    outF.write(str(line))
    outF.write('\n')
outF.close()
# Out:
# <function TextIOWrapper.close()>

# %%
total
# Out:
# [{'slug': 'centaurea-trichocephala',
#   'scientific_name': 'Centaurea trichocephala',
#   'link': 'http://trefle.io/api/plants/118318',
#   'id': 118318,
#   'complete_data': False,
#   'common_name': 'feather-head knapweed'},
#  {'slug': 'cerastium-strictum',
#   'scientific_name': 'Cerastium strictum',
#   'link': 'http://trefle.io/api/plants/118581',
#   'id': 118581,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'ceratopteris-deltoidea',
#   'scientific_name': 'Ceratopteris deltoidea',
#   'link': 'http://trefle.io/api/plants/118723',
#   'id': 118723,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cichorium',
#   'scientific_name': 'Cichorium',
#   'link': 'http://trefle.io/api/plants/120544',
#   'id': 120544,
#   'complete_data': False,
#   'common_name': 'chicory'},
#  {'slug': 'chamaesyce-cowellii',
#   'scientific_name': 'Chamaesyce cowellii',
#   'link': 'http://trefle.io/api/plants/119382',
#   'id': 119382,
#   'complete_data': False,
#   'common_name': "Cowell's sandmat"},
#  {'slug': 'chamaecrista-serpens',
#   'scientific_name': 'Chamaecrista serpens',
#   'link': 'http://trefle.io/api/plants/119158',
#   'id': 119158,
#   'complete_data': False,
#   'common_name': 'slender sensitive pea'},
#  {'slug': 'chamaesyce-deppeana',
#   'scientific_name': 'Chamaesyce deppeana',
#   'link': 'http://trefle.io/api/plants/119406',
#   'id': 119406,
#   'complete_data': False,
#   'common_name': 'Oahu sandmat'},
#  {'slug': 'euphorbia-melanadenia',
#   'scientific_name': 'Euphorbia melanadenia',
#   'link': 'http://trefle.io/api/plants/119485',
#   'id': 119485,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'zeltnera-nudicaulis',
#   'scientific_name': 'Zeltnera nudicaulis',
#   'link': 'http://trefle.io/api/plants/118367',
#   'id': 118367,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cephalozia-macrostachya',
#   'scientific_name': 'Cephalozia macrostachya',
#   'link': 'http://trefle.io/api/plants/118484',
#   'id': 118484,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'centaurea-variegata',
#   'scientific_name': 'Centaurea variegata',
#   'link': 'http://trefle.io/api/plants/118326',
#   'id': 118326,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'centaurium-arizonicum',
#   'scientific_name': 'Centaurium arizonicum',
#   'link': 'http://trefle.io/api/plants/118329',
#   'id': 118329,
#   'complete_data': False,
#   'common_name': 'Arizona centaury'},
#  {'slug': 'cephaloziella-spinicaulis',
#   'scientific_name': 'Cephaloziella spinicaulis',
#   'link': 'http://trefle.io/api/plants/118527',
#   'id': 118527,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chaenactis-macrantha',
#   'scientific_name': 'Chaenactis macrantha',
#   'link': 'http://trefle.io/api/plants/118913',
#   'id': 118913,
#   'complete_data': False,
#   'common_name': 'bighead dustymaiden'},
#  {'slug': 'centrosema-arenicola',
#   'scientific_name': 'Centrosema arenicola',
#   'link': 'http://trefle.io/api/plants/118427',
#   'id': 118427,
#   'complete_data': False,
#   'common_name': 'pineland butterfly pea'},
#  {'slug': 'chrysothamnus-humilis',
#   'scientific_name': 'Chrysothamnus humilis',
#   'link': 'http://trefle.io/api/plants/120463',
#   'id': 120463,
#   'complete_data': False,
#   'common_name': 'Truckee rabbitbrush'},
#  {'slug': 'viola-aduncoides',
#   'scientific_name': 'Viola aduncoides',
#   'link': 'http://trefle.io/api/plants/192110',
#   'id': 192110,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chaenothecopsis-nana',
#   'scientific_name': 'Chaenothecopsis nana',
#   'link': 'http://trefle.io/api/plants/118970',
#   'id': 118970,
#   'complete_data': False,
#   'common_name': 'chaenothecopsis lichen'},
#  {'slug': 'ceratopteris-pteridoides',
#   'scientific_name': 'Ceratopteris pteridoides',
#   'link': 'http://trefle.io/api/plants/118720',
#   'id': 118720,
#   'complete_data': False,
#   'common_name': 'floating antlerfern'},
#  {'slug': 'chaetopappa-bellidifolia',
#   'scientific_name': 'Chaetopappa bellidifolia',
#   'link': 'http://trefle.io/api/plants/119012',
#   'id': 119012,
#   'complete_data': False,
#   'common_name': 'whiteray leastdaisy'},
#  {'slug': 'cetraria-laevigata',
#   'scientific_name': 'Cetraria laevigata',
#   'link': 'http://trefle.io/api/plants/118833',
#   'id': 118833,
#   'complete_data': False,
#   'common_name': 'cetraria lichen'},
#  {'slug': 'cereus-uruguayanus',
#   'scientific_name': 'Cereus uruguayanus',
#   'link': 'http://trefle.io/api/plants/118792',
#   'id': 118792,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chamaesyce-adenoptera',
#   'scientific_name': 'Chamaesyce adenoptera',
#   'link': 'http://trefle.io/api/plants/119242',
#   'id': 119242,
#   'complete_data': False,
#   'common_name': 'southern Florida sandmat'},
#  {'slug': 'chamaesyce-halemanui',
#   'scientific_name': 'Chamaesyce halemanui',
#   'link': 'http://trefle.io/api/plants/119437',
#   'id': 119437,
#   'complete_data': False,
#   'common_name': 'Kauai sandmat'},
#  {'slug': 'cheilanthes-newberryi',
#   'scientific_name': 'Cheilanthes newberryi',
#   'link': 'http://trefle.io/api/plants/119767',
#   'id': 119767,
#   'complete_data': False,
#   'common_name': "Newberry's lipfern"},
#  {'slug': 'cercis',
#   'scientific_name': 'Cercis',
#   'link': 'http://trefle.io/api/plants/118743',
#   'id': 118743,
#   'complete_data': False,
#   'common_name': 'redbud'},
#  {'slug': 'cercis-siliquastrum',
#   'scientific_name': 'Cercis siliquastrum',
#   'link': 'http://trefle.io/api/plants/118754',
#   'id': 118754,
#   'complete_data': False,
#   'common_name': 'Judas-tree'},
#  {'slug': 'cevallia-sinuata',
#   'scientific_name': 'Cevallia sinuata',
#   'link': 'http://trefle.io/api/plants/118859',
#   'id': 118859,
#   'complete_data': False,
#   'common_name': 'stinging serpent'},
#  {'slug': 'chaenotheca-xyloxena',
#   'scientific_name': 'Chaenotheca xyloxena',
#   'link': 'http://trefle.io/api/plants/118964',
#   'id': 118964,
#   'complete_data': False,
#   'common_name': 'needle lichen'},
#  {'slug': 'chamaesyce-porteriana',
#   'scientific_name': 'Chamaesyce porteriana',
#   'link': 'http://trefle.io/api/plants/119568',
#   'id': 119568,
#   'complete_data': False,
#   'common_name': "Porter's sandmat"},
#  {'slug': 'chenopodium-berlandieri',
#   'scientific_name': 'Chenopodium berlandieri',
#   'link': 'http://trefle.io/api/plants/119888',
#   'id': 119888,
#   'complete_data': False,
#   'common_name': 'pitseed goosefoot'},
#  {'slug': 'chandonanthus-hirtellus',
#   'scientific_name': 'Chandonanthus hirtellus',
#   'link': 'http://trefle.io/api/plants/119702',
#   'id': 119702,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chasmanthium-nitidum',
#   'scientific_name': 'Chasmanthium nitidum',
#   'link': 'http://trefle.io/api/plants/119733',
#   'id': 119733,
#   'complete_data': False,
#   'common_name': 'shiny woodoats'},
#  {'slug': 'eupatorium-sinuatum',
#   'scientific_name': 'Eupatorium sinuatum',
#   'link': 'http://trefle.io/api/plants/120303',
#   'id': 120303,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chiloscyphus-pallescens',
#   'scientific_name': 'Chiloscyphus pallescens',
#   'link': 'http://trefle.io/api/plants/120024',
#   'id': 120024,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'lepraria-candelaris',
#   'scientific_name': 'Lepraria candelaris',
#   'link': 'http://trefle.io/api/plants/120516',
#   'id': 120516,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cicendia-quadrangularis',
#   'scientific_name': 'Cicendia quadrangularis',
#   'link': 'http://trefle.io/api/plants/120537',
#   'id': 120537,
#   'complete_data': False,
#   'common_name': 'Oregon timwort'},
#  {'slug': 'cephalotaxus-harringtonia',
#   'scientific_name': 'Cephalotaxus harringtonia',
#   'link': 'http://trefle.io/api/plants/118466',
#   'id': 118466,
#   'complete_data': False,
#   'common_name': "Harrington's cephalotaxus"},
#  {'slug': 'centaurium-nudicaule',
#   'scientific_name': 'Centaurium nudicaule',
#   'link': 'http://trefle.io/api/plants/118366',
#   'id': 118366,
#   'complete_data': False,
#   'common_name': 'Santa Catalina Mountain centaury'},
#  {'slug': 'ceratotheca-sesamoides',
#   'scientific_name': 'Ceratotheca sesamoides',
#   'link': 'http://trefle.io/api/plants/118730',
#   'id': 118730,
#   'complete_data': False,
#   'common_name': 'false sesame'},
#  {'slug': 'ceroxylon-alpinum',
#   'scientific_name': 'Ceroxylon alpinum',
#   'link': 'http://trefle.io/api/plants/118802',
#   'id': 118802,
#   'complete_data': False,
#   'common_name': 'wax palm'},
#  {'slug': 'chaenotheca-hispidula',
#   'scientific_name': 'Chaenotheca hispidula',
#   'link': 'http://trefle.io/api/plants/118958',
#   'id': 118958,
#   'complete_data': False,
#   'common_name': 'hispid needle lichen'},
#  {'slug': 'chaerophyllum-temulum',
#   'scientific_name': 'Chaerophyllum temulum',
#   'link': 'http://trefle.io/api/plants/119005',
#   'id': 119005,
#   'complete_data': False,
#   'common_name': 'rough chervil'},
#  {'slug': 'chamaecrista-chamaecristoides',
#   'scientific_name': 'Chamaecrista chamaecristoides',
#   'link': 'http://trefle.io/api/plants/119052',
#   'id': 119052,
#   'complete_data': False,
#   'common_name': 'beach sensitive pea'},
#  {'slug': 'chamaecytisus-mollis',
#   'scientific_name': 'Chamaecytisus mollis',
#   'link': 'http://trefle.io/api/plants/119182',
#   'id': 119182,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cheilanthes-wootonii',
#   'scientific_name': 'Cheilanthes wootonii',
#   'link': 'http://trefle.io/api/plants/119783',
#   'id': 119783,
#   'complete_data': False,
#   'common_name': 'beaded lipfern'},
#  {'slug': 'chelone-glabra',
#   'scientific_name': 'Chelone glabra',
#   'link': 'http://trefle.io/api/plants/119842',
#   'id': 119842,
#   'complete_data': False,
#   'common_name': 'white turtlehead'},
#  {'slug': 'cirsium-muticum',
#   'scientific_name': 'Cirsium muticum',
#   'link': 'http://trefle.io/api/plants/120775',
#   'id': 120775,
#   'complete_data': False,
#   'common_name': 'swamp thistle'},
#  {'slug': 'viola-hastata',
#   'scientific_name': 'Viola hastata',
#   'link': 'http://trefle.io/api/plants/192206',
#   'id': 192206,
#   'complete_data': False,
#   'common_name': 'halberdleaf yellow violet'},
#  {'slug': 'viburnum-recognitum',
#   'scientific_name': 'Viburnum recognitum',
#   'link': 'http://trefle.io/api/plants/191728',
#   'id': 191728,
#   'complete_data': False,
#   'common_name': 'southern arrowwood'},
#  {'slug': 'vicia-calcarata',
#   'scientific_name': 'Vicia calcarata',
#   'link': 'http://trefle.io/api/plants/191858',
#   'id': 191858,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'vicia-incana',
#   'scientific_name': 'Vicia incana',
#   'link': 'http://trefle.io/api/plants/191792',
#   'id': 191792,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'vicia-disperma',
#   'scientific_name': 'Vicia disperma',
#   'link': 'http://trefle.io/api/plants/191800',
#   'id': 191800,
#   'complete_data': False,
#   'common_name': 'European vetch'},
#  {'slug': 'chasmanthium-ornithorhynchum',
#   'scientific_name': 'Chasmanthium ornithorhynchum',
#   'link': 'http://trefle.io/api/plants/119735',
#   'id': 119735,
#   'complete_data': False,
#   'common_name': 'birdbill woodoats'},
#  {'slug': 'chenopodium-hians',
#   'scientific_name': 'Chenopodium hians',
#   'link': 'http://trefle.io/api/plants/119943',
#   'id': 119943,
#   'complete_data': False,
#   'common_name': 'hians goosefoot'},
#  {'slug': 'chamaesyce-clusiifolia',
#   'scientific_name': 'Chamaesyce clusiifolia',
#   'link': 'http://trefle.io/api/plants/119373',
#   'id': 119373,
#   'complete_data': False,
#   'common_name': 'forest sandmat'},
#  {'slug': 'cetraria-muricata',
#   'scientific_name': 'Cetraria muricata',
#   'link': 'http://trefle.io/api/plants/118834',
#   'id': 118834,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chaenothecopsis-viridialba',
#   'scientific_name': 'Chaenothecopsis viridialba',
#   'link': 'http://trefle.io/api/plants/118988',
#   'id': 118988,
#   'complete_data': False,
#   'common_name': 'chaenothecopsis lichen'},
#  {'slug': 'chamaecrista-deeringiana',
#   'scientific_name': 'Chamaecrista deeringiana',
#   'link': 'http://trefle.io/api/plants/119055',
#   'id': 119055,
#   'complete_data': False,
#   'common_name': 'Florida Keys sensitive pea'},
#  {'slug': 'chaenothecopsis-viridireagens',
#   'scientific_name': 'Chaenothecopsis viridireagens',
#   'link': 'http://trefle.io/api/plants/118989',
#   'id': 118989,
#   'complete_data': False,
#   'common_name': 'chaenothecopsis lichen'},
#  {'slug': 'cassia-mississippiensis',
#   'scientific_name': 'Cassia mississippiensis',
#   'link': 'http://trefle.io/api/plants/119076',
#   'id': 119076,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chamaesyce-hepatica',
#   'scientific_name': 'Chamaesyce hepatica',
#   'link': 'http://trefle.io/api/plants/119445',
#   'id': 119445,
#   'complete_data': False,
#   'common_name': 'West Indies sandmat'},
#  {'slug': 'chamaesaracha-pallida',
#   'scientific_name': 'Chamaesaracha pallida',
#   'link': 'http://trefle.io/api/plants/119230',
#   'id': 119230,
#   'complete_data': False,
#   'common_name': 'pale five eyes'},
#  {'slug': 'chamaesyce-velleriflora',
#   'scientific_name': 'Chamaesyce velleriflora',
#   'link': 'http://trefle.io/api/plants/119664',
#   'id': 119664,
#   'complete_data': False,
#   'common_name': 'Caliche sandmat'},
#  {'slug': 'acanthocereus',
#   'scientific_name': 'Acanthocereus',
#   'link': 'http://trefle.io/api/plants/101614',
#   'id': 101614,
#   'complete_data': False,
#   'common_name': 'triangle trefle'},
#  {'slug': 'chamaesyce-nutans',
#   'scientific_name': 'Chamaesyce nutans',
#   'link': 'http://trefle.io/api/plants/119523',
#   'id': 119523,
#   'complete_data': False,
#   'common_name': 'eyebane'},
#  {'slug': 'chamaesaracha-coronopus',
#   'scientific_name': 'Chamaesaracha coronopus',
#   'link': 'http://trefle.io/api/plants/119227',
#   'id': 119227,
#   'complete_data': False,
#   'common_name': 'greenleaf five eyes'},
#  {'slug': 'chamaesyce-garberi',
#   'scientific_name': 'Chamaesyce garberi',
#   'link': 'http://trefle.io/api/plants/119421',
#   'id': 119421,
#   'complete_data': False,
#   'common_name': "Garber's sandmat"},
#  {'slug': 'chamaecrista-mimosoides',
#   'scientific_name': 'Chamaecrista mimosoides',
#   'link': 'http://trefle.io/api/plants/119113',
#   'id': 119113,
#   'complete_data': False,
#   'common_name': 'chamaecrista'},
#  {'slug': 'chaenactis-xantiana',
#   'scientific_name': 'Chaenactis xantiana',
#   'link': 'http://trefle.io/api/plants/118928',
#   'id': 118928,
#   'complete_data': False,
#   'common_name': 'fleshcolor pincushion'},
#  {'slug': 'chamaesyce-glyptosperma',
#   'scientific_name': 'Chamaesyce glyptosperma',
#   'link': 'http://trefle.io/api/plants/119431',
#   'id': 119431,
#   'complete_data': False,
#   'common_name': 'ribseed sandmat'},
#  {'slug': 'cytisus-proliferus',
#   'scientific_name': 'Cytisus proliferus',
#   'link': 'http://trefle.io/api/plants/119189',
#   'id': 119189,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cereus-pentagonus',
#   'scientific_name': 'Cereus pentagonus',
#   'link': 'http://trefle.io/api/plants/101619',
#   'id': 101619,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chamaesaracha-crenata',
#   'scientific_name': 'Chamaesaracha crenata',
#   'link': 'http://trefle.io/api/plants/119228',
#   'id': 119228,
#   'complete_data': False,
#   'common_name': 'toothed five eyes'},
#  {'slug': 'cheilanthes-microphylla',
#   'scientific_name': 'Cheilanthes microphylla',
#   'link': 'http://trefle.io/api/plants/119766',
#   'id': 119766,
#   'complete_data': False,
#   'common_name': 'southern lipfern'},
#  {'slug': 'chamaesyce-missurica',
#   'scientific_name': 'Chamaesyce missurica',
#   'link': 'http://trefle.io/api/plants/119494',
#   'id': 119494,
#   'complete_data': False,
#   'common_name': 'prairie sandmat'},
#  {'slug': 'acarospora-rimulosa',
#   'scientific_name': 'Acarospora rimulosa',
#   'link': 'http://trefle.io/api/plants/101725',
#   'id': 101725,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chamaesyce-berteriana',
#   'scientific_name': 'Chamaesyce berteriana',
#   'link': 'http://trefle.io/api/plants/119279',
#   'id': 119279,
#   'complete_data': False,
#   'common_name': "Berteron's sandmat"},
#  {'slug': 'chamaesyce-mesembrianthemifolia',
#   'scientific_name': 'Chamaesyce mesembrianthemifolia',
#   'link': 'http://trefle.io/api/plants/119488',
#   'id': 119488,
#   'complete_data': False,
#   'common_name': 'coastal beach sandmat'},
#  {'slug': 'cheilanthes-intertexta',
#   'scientific_name': 'Cheilanthes intertexta',
#   'link': 'http://trefle.io/api/plants/119760',
#   'id': 119760,
#   'complete_data': False,
#   'common_name': 'coastal lipfern'},
#  {'slug': 'cheilanthes-yavapensis',
#   'scientific_name': 'Cheilanthes yavapensis',
#   'link': 'http://trefle.io/api/plants/119785',
#   'id': 119785,
#   'complete_data': False,
#   'common_name': 'graceful lipfern'},
#  {'slug': 'chorizanthe-angustifolia',
#   'scientific_name': 'Chorizanthe angustifolia',
#   'link': 'http://trefle.io/api/plants/120184',
#   'id': 120184,
#   'complete_data': False,
#   'common_name': 'narrowleaf spineflower'},
#  {'slug': 'chamaesyce-hypericifolia',
#   'scientific_name': 'Chamaesyce hypericifolia',
#   'link': 'http://trefle.io/api/plants/119459',
#   'id': 119459,
#   'complete_data': False,
#   'common_name': 'graceful sandmat'},
#  {'slug': 'acer-torreyi',
#   'scientific_name': 'Acer torreyi',
#   'link': 'http://trefle.io/api/plants/101798',
#   'id': 101798,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chamaesyce-villifera',
#   'scientific_name': 'Chamaesyce villifera',
#   'link': 'http://trefle.io/api/plants/119668',
#   'id': 119668,
#   'complete_data': False,
#   'common_name': 'hairy sandmat'},
#  {'slug': 'acer-drummondii',
#   'scientific_name': 'Acer drummondii',
#   'link': 'http://trefle.io/api/plants/101854',
#   'id': 101854,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'euphorbia-petaloidea',
#   'scientific_name': 'Euphorbia petaloidea',
#   'link': 'http://trefle.io/api/plants/119504',
#   'id': 119504,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cirsium-clokeyi',
#   'scientific_name': 'Cirsium clokeyi',
#   'link': 'http://trefle.io/api/plants/120695',
#   'id': 120695,
#   'complete_data': False,
#   'common_name': 'whitespine thistle'},
#  {'slug': 'vicia-ocalensis',
#   'scientific_name': 'Vicia ocalensis',
#   'link': 'http://trefle.io/api/plants/191871',
#   'id': 191871,
#   'complete_data': False,
#   'common_name': 'Ocala vetch'},
#  {'slug': 'vicia-peregrina',
#   'scientific_name': 'Vicia peregrina',
#   'link': 'http://trefle.io/api/plants/191875',
#   'id': 191875,
#   'complete_data': False,
#   'common_name': 'wandering vetch'},
#  {'slug': 'cheiroglossa-palmata',
#   'scientific_name': 'Cheiroglossa palmata',
#   'link': 'http://trefle.io/api/plants/119830',
#   'id': 119830,
#   'complete_data': False,
#   'common_name': 'hand fern'},
#  {'slug': 'chamaesyce-polygonifolia',
#   'scientific_name': 'Chamaesyce polygonifolia',
#   'link': 'http://trefle.io/api/plants/119566',
#   'id': 119566,
#   'complete_data': False,
#   'common_name': 'seaside sandmat'},
#  {'slug': 'vicia-angustifolia',
#   'scientific_name': 'Vicia angustifolia',
#   'link': 'http://trefle.io/api/plants/191888',
#   'id': 191888,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cheilanthes-covillei',
#   'scientific_name': 'Cheilanthes covillei',
#   'link': 'http://trefle.io/api/plants/119752',
#   'id': 119752,
#   'complete_data': False,
#   'common_name': "Coville's lipfern"},
#  {'slug': 'chenopodium-pratericola',
#   'scientific_name': 'Chenopodium pratericola',
#   'link': 'http://trefle.io/api/plants/119980',
#   'id': 119980,
#   'complete_data': False,
#   'common_name': 'desert goosefoot'},
#  {'slug': 'chaptalia-albicans',
#   'scientific_name': 'Chaptalia albicans',
#   'link': 'http://trefle.io/api/plants/119708',
#   'id': 119708,
#   'complete_data': False,
#   'common_name': 'white sunbonnets'},
#  {'slug': 'chenopodium-opulifolium',
#   'scientific_name': 'Chenopodium opulifolium',
#   'link': 'http://trefle.io/api/plants/119969',
#   'id': 119969,
#   'complete_data': False,
#   'common_name': 'seaport goosefoot'},
#  {'slug': 'chamerion-angustifolium',
#   'scientific_name': 'Chamerion angustifolium',
#   'link': 'http://trefle.io/api/plants/119674',
#   'id': 119674,
#   'complete_data': False,
#   'common_name': 'fireweed'},
#  {'slug': 'cheilanthes-notholaenoides',
#   'scientific_name': 'Cheilanthes notholaenoides',
#   'link': 'http://trefle.io/api/plants/119769',
#   'id': 119769,
#   'complete_data': False,
#   'common_name': 'royal lipfern'},
#  {'slug': 'vigna-heterophylla',
#   'scientific_name': 'Vigna heterophylla',
#   'link': 'http://trefle.io/api/plants/191943',
#   'id': 191943,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chromolaena-borinquensis',
#   'scientific_name': 'Chromolaena borinquensis',
#   'link': 'http://trefle.io/api/plants/120282',
#   'id': 120282,
#   'complete_data': False,
#   'common_name': 'limestone thoroughwort'},
#  {'slug': 'chorizanthe-brevicornu',
#   'scientific_name': 'Chorizanthe brevicornu',
#   'link': 'http://trefle.io/api/plants/120191',
#   'id': 120191,
#   'complete_data': False,
#   'common_name': 'brittle spineflower'},
#  {'slug': 'vigna-hosei',
#   'scientific_name': 'Vigna hosei',
#   'link': 'http://trefle.io/api/plants/191944',
#   'id': 191944,
#   'complete_data': False,
#   'common_name': 'Sarawak bean'},
#  {'slug': 'chenopodium-rubrum',
#   'scientific_name': 'Chenopodium rubrum',
#   'link': 'http://trefle.io/api/plants/119986',
#   'id': 119986,
#   'complete_data': False,
#   'common_name': 'red goosefoot'},
#  {'slug': 'chrysosplenium-tetrandrum',
#   'scientific_name': 'Chrysosplenium tetrandrum',
#   'link': 'http://trefle.io/api/plants/120438',
#   'id': 120438,
#   'complete_data': False,
#   'common_name': 'northern golden saxifrage'},
#  {'slug': 'chloris-texensis',
#   'scientific_name': 'Chloris texensis',
#   'link': 'http://trefle.io/api/plants/120130',
#   'id': 120130,
#   'complete_data': False,
#   'common_name': 'Texas windmill grass'},
#  {'slug': 'chorizanthe-howellii',
#   'scientific_name': 'Chorizanthe howellii',
#   'link': 'http://trefle.io/api/plants/120214',
#   'id': 120214,
#   'complete_data': False,
#   'common_name': 'Mendocino spineflower'},
#  {'slug': 'chorizanthe-polygonoides',
#   'scientific_name': 'Chorizanthe polygonoides',
#   'link': 'http://trefle.io/api/plants/120225',
#   'id': 120225,
#   'complete_data': False,
#   'common_name': 'knotweed spineflower'},
#  {'slug': 'chloris-elata',
#   'scientific_name': 'Chloris elata',
#   'link': 'http://trefle.io/api/plants/120116',
#   'id': 120116,
#   'complete_data': False,
#   'common_name': 'tall windmill grass'},
#  {'slug': 'chorizanthe-watsonii',
#   'scientific_name': 'Chorizanthe watsonii',
#   'link': 'http://trefle.io/api/plants/120261',
#   'id': 120261,
#   'complete_data': False,
#   'common_name': 'fivetooth spineflower'},
#  {'slug': 'ericameria-depressa',
#   'scientific_name': 'Ericameria depressa',
#   'link': 'http://trefle.io/api/plants/120453',
#   'id': 120453,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'vigna-ambacensis',
#   'scientific_name': 'Vigna ambacensis',
#   'link': 'http://trefle.io/api/plants/191933',
#   'id': 191933,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chenopodium-desiccatum',
#   'scientific_name': 'Chenopodium desiccatum',
#   'link': 'http://trefle.io/api/plants/119923',
#   'id': 119923,
#   'complete_data': False,
#   'common_name': 'aridland goosefoot'},
#  {'slug': 'chenopodium-vulvaria',
#   'scientific_name': 'Chenopodium vulvaria',
#   'link': 'http://trefle.io/api/plants/120007',
#   'id': 120007,
#   'complete_data': False,
#   'common_name': 'stinking goosefoot'},
#  {'slug': 'chiranthodendron-pentadactylon',
#   'scientific_name': 'Chiranthodendron pentadactylon',
#   'link': 'http://trefle.io/api/plants/120089',
#   'id': 120089,
#   'complete_data': False,
#   'common_name': 'Mexican-hat-plant'},
#  {'slug': 'chimaphila-corymbosa',
#   'scientific_name': 'Chimaphila corymbosa',
#   'link': 'http://trefle.io/api/plants/120038',
#   'id': 120038,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chloris-barbata',
#   'scientific_name': 'Chloris barbata',
#   'link': 'http://trefle.io/api/plants/120102',
#   'id': 120102,
#   'complete_data': False,
#   'common_name': 'swollen fingergrass'},
#  {'slug': 'chrysopsis-arenicola',
#   'scientific_name': 'Chrysopsis arenicola',
#   'link': 'http://trefle.io/api/plants/120394',
#   'id': 120394,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cibotium-nealiae',
#   'scientific_name': 'Cibotium nealiae',
#   'link': 'http://trefle.io/api/plants/120535',
#   'id': 120535,
#   'complete_data': False,
#   'common_name': "Neal's manfern"},
#  {'slug': 'chrysosplenium-rosendahlii',
#   'scientific_name': 'Chrysosplenium rosendahlii',
#   'link': 'http://trefle.io/api/plants/120437',
#   'id': 120437,
#   'complete_data': False,
#   'common_name': "Rosendahl's golden saxifrage"},
#  {'slug': 'cistanthe-monandra',
#   'scientific_name': 'Cistanthe monandra',
#   'link': 'http://trefle.io/api/plants/120957',
#   'id': 120957,
#   'complete_data': False,
#   'common_name': 'common pussypaws'},
#  {'slug': 'lecanora-bolanderi',
#   'scientific_name': 'Lecanora bolanderi',
#   'link': 'http://trefle.io/api/plants/121082',
#   'id': 121082,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chloris-sagraeana',
#   'scientific_name': 'Chloris sagraeana',
#   'link': 'http://trefle.io/api/plants/120128',
#   'id': 120128,
#   'complete_data': False,
#   'common_name': 'roadside windmill grass'},
#  {'slug': 'chiodecton-subochroleucum',
#   'scientific_name': 'Chiodecton subochroleucum',
#   'link': 'http://trefle.io/api/plants/120054',
#   'id': 120054,
#   'complete_data': False,
#   'common_name': 'chiodecton lichen'},
#  {'slug': 'chorizanthe-spathulata',
#   'scientific_name': 'Chorizanthe spathulata',
#   'link': 'http://trefle.io/api/plants/120195',
#   'id': 120195,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cirsium-scabrum',
#   'scientific_name': 'Cirsium scabrum',
#   'link': 'http://trefle.io/api/plants/120854',
#   'id': 120854,
#   'complete_data': False,
#   'common_name': 'rough thistle'},
#  {'slug': 'cladina-ciliata',
#   'scientific_name': 'Cladina ciliata',
#   'link': 'http://trefle.io/api/plants/121090',
#   'id': 121090,
#   'complete_data': False,
#   'common_name': 'ciliate reindeer lichen'},
#  {'slug': 'cirsium-discolor',
#   'scientific_name': 'Cirsium discolor',
#   'link': 'http://trefle.io/api/plants/120699',
#   'id': 120699,
#   'complete_data': False,
#   'common_name': 'field thistle'},
#  {'slug': 'chrysopsis-gigantea',
#   'scientific_name': 'Chrysopsis gigantea',
#   'link': 'http://trefle.io/api/plants/120403',
#   'id': 120403,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cirsium-lecontei',
#   'scientific_name': 'Cirsium lecontei',
#   'link': 'http://trefle.io/api/plants/120766',
#   'id': 120766,
#   'complete_data': False,
#   'common_name': "Le Conte's thistle"},
#  {'slug': 'cirsium-wrightii',
#   'scientific_name': 'Cirsium wrightii',
#   'link': 'http://trefle.io/api/plants/120932',
#   'id': 120932,
#   'complete_data': False,
#   'common_name': "Wright's thistle"},
#  {'slug': 'citharexylum-brachyanthum',
#   'scientific_name': 'Citharexylum brachyanthum',
#   'link': 'http://trefle.io/api/plants/121012',
#   'id': 121012,
#   'complete_data': False,
#   'common_name': 'boxthorn fiddlewood'},
#  {'slug': 'cladium-mariscus',
#   'scientific_name': 'Cladium mariscus',
#   'link': 'http://trefle.io/api/plants/121138',
#   'id': 121138,
#   'complete_data': False,
#   'common_name': 'swamp sawgrass'},
#  {'slug': 'cladonia-transcendens',
#   'scientific_name': 'Cladonia transcendens',
#   'link': 'http://trefle.io/api/plants/121323',
#   'id': 121323,
#   'complete_data': False,
#   'common_name': 'transcend cup lichen'},
#  {'slug': 'chrysobalanus-icaco',
#   'scientific_name': 'Chrysobalanus icaco',
#   'link': 'http://trefle.io/api/plants/120337',
#   'id': 120337,
#   'complete_data': False,
#   'common_name': 'coco plum'},
#  {'slug': 'chrysopsis-lanuginosa',
#   'scientific_name': 'Chrysopsis lanuginosa',
#   'link': 'http://trefle.io/api/plants/120408',
#   'id': 120408,
#   'complete_data': False,
#   'common_name': 'Lynn Haven goldenaster'},
#  {'slug': 'citrus-limetta',
#   'scientific_name': 'Citrus limetta',
#   'link': 'http://trefle.io/api/plants/121069',
#   'id': 121069,
#   'complete_data': False,
#   'common_name': 'bitter orange'},
#  {'slug': 'cistus-ladanifer',
#   'scientific_name': 'Cistus ladanifer',
#   'link': 'http://trefle.io/api/plants/121004',
#   'id': 121004,
#   'complete_data': False,
#   'common_name': 'common gum cistus'},
#  {'slug': 'citrus-reticulata',
#   'scientific_name': 'Citrus reticulata',
#   'link': 'http://trefle.io/api/plants/121076',
#   'id': 121076,
#   'complete_data': False,
#   'common_name': 'tangerine'},
#  {'slug': 'cladonia-thomsonii',
#   'scientific_name': 'Cladonia thomsonii',
#   'link': 'http://trefle.io/api/plants/121322',
#   'id': 121322,
#   'complete_data': False,
#   'common_name': "Thomson's cup lichen"},
#  {'slug': 'cladonia-acuminata',
#   'scientific_name': 'Cladonia acuminata',
#   'link': 'http://trefle.io/api/plants/121145',
#   'id': 121145,
#   'complete_data': False,
#   'common_name': 'acutetip cup lichen'},
#  {'slug': 'cladonia-prostrata',
#   'scientific_name': 'Cladonia prostrata',
#   'link': 'http://trefle.io/api/plants/121282',
#   'id': 121282,
#   'complete_data': False,
#   'common_name': 'prostrate cup lichen'},
#  {'slug': 'cladopodiella-fluitans',
#   'scientific_name': 'Cladopodiella fluitans',
#   'link': 'http://trefle.io/api/plants/121333',
#   'id': 121333,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'acarospora-contigua',
#   'scientific_name': 'Acarospora contigua',
#   'link': 'http://trefle.io/api/plants/101718',
#   'id': 101718,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cleomella-brevipes',
#   'scientific_name': 'Cleomella brevipes',
#   'link': 'http://trefle.io/api/plants/121849',
#   'id': 121849,
#   'complete_data': False,
#   'common_name': 'shortstalk stinkweed'},
#  {'slug': 'clermontia-pyrularia',
#   'scientific_name': 'Clermontia pyrularia',
#   'link': 'http://trefle.io/api/plants/121952',
#   'id': 121952,
#   'complete_data': False,
#   'common_name': 'Hamakua clermontia'},
#  {'slug': 'clematis-coactilis',
#   'scientific_name': 'Clematis coactilis',
#   'link': 'http://trefle.io/api/plants/121667',
#   'id': 121667,
#   'complete_data': False,
#   'common_name': 'Virginia whitehair leather flower'},
#  {'slug': 'calamintha-dentata',
#   'scientific_name': 'Calamintha dentata',
#   'link': 'http://trefle.io/api/plants/122061',
#   'id': 122061,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'clinopodium-ascendens',
#   'scientific_name': 'Clinopodium ascendens',
#   'link': 'http://trefle.io/api/plants/122041',
#   'id': 122041,
#   'complete_data': False,
#   'common_name': 'ascending wild basil'},
#  {'slug': 'vigna-stuhlmannii',
#   'scientific_name': 'Vigna stuhlmannii',
#   'link': 'http://trefle.io/api/plants/191934',
#   'id': 191934,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chenopodium-leptophyllum',
#   'scientific_name': 'Chenopodium leptophyllum',
#   'link': 'http://trefle.io/api/plants/119951',
#   'id': 119951,
#   'complete_data': False,
#   'common_name': 'narrowleaf goosefoot'},
#  {'slug': 'chorispora-tenella',
#   'scientific_name': 'Chorispora tenella',
#   'link': 'http://trefle.io/api/plants/120182',
#   'id': 120182,
#   'complete_data': False,
#   'common_name': 'crossflower'},
#  {'slug': 'chrysanthemum-arcticum',
#   'scientific_name': 'Chrysanthemum arcticum',
#   'link': 'http://trefle.io/api/plants/120318',
#   'id': 120318,
#   'complete_data': False,
#   'common_name': 'arctic daisy'},
#  {'slug': 'chrysactinia-mexicana',
#   'scientific_name': 'Chrysactinia mexicana',
#   'link': 'http://trefle.io/api/plants/120309',
#   'id': 120309,
#   'complete_data': False,
#   'common_name': 'damianita'},
#  {'slug': 'chrozophora-tinctoria',
#   'scientific_name': 'Chrozophora tinctoria',
#   'link': 'http://trefle.io/api/plants/120306',
#   'id': 120306,
#   'complete_data': False,
#   'common_name': 'giradol'},
#  {'slug': 'chrysopogon-aciculatus',
#   'scientific_name': 'Chrysopogon aciculatus',
#   'link': 'http://trefle.io/api/plants/120376',
#   'id': 120376,
#   'complete_data': False,
#   'common_name': 'golden false beardgrass'},
#  {'slug': 'cladina-stellaris',
#   'scientific_name': 'Cladina stellaris',
#   'link': 'http://trefle.io/api/plants/121116',
#   'id': 121116,
#   'complete_data': False,
#   'common_name': 'star reindeer lichen'},
#  {'slug': 'cirsium-mohavense',
#   'scientific_name': 'Cirsium mohavense',
#   'link': 'http://trefle.io/api/plants/120772',
#   'id': 120772,
#   'complete_data': False,
#   'common_name': 'Mojave thistle'},
#  {'slug': 'cirriphyllum-piliferum',
#   'scientific_name': 'Cirriphyllum piliferum',
#   'link': 'http://trefle.io/api/plants/120631',
#   'id': 120631,
#   'complete_data': False,
#   'common_name': 'cirriphyllum moss'},
#  {'slug': 'cirsium-murdockii',
#   'scientific_name': 'Cirsium murdockii',
#   'link': 'http://trefle.io/api/plants/120773',
#   'id': 120773,
#   'complete_data': False,
#   'common_name': "Murdock's thistle"},
#  {'slug': 'cladonia-brevis',
#   'scientific_name': 'Cladonia brevis',
#   'link': 'http://trefle.io/api/plants/121166',
#   'id': 121166,
#   'complete_data': False,
#   'common_name': 'cup lichen'},
#  {'slug': 'cirsium-wheeleri',
#   'scientific_name': 'Cirsium wheeleri',
#   'link': 'http://trefle.io/api/plants/120928',
#   'id': 120928,
#   'complete_data': False,
#   'common_name': "Wheeler's thistle"},
#  {'slug': 'cladonia-pleurota',
#   'scientific_name': 'Cladonia pleurota',
#   'link': 'http://trefle.io/api/plants/121275',
#   'id': 121275,
#   'complete_data': False,
#   'common_name': 'cup lichen'},
#  {'slug': 'claytonia-nevadensis',
#   'scientific_name': 'Claytonia nevadensis',
#   'link': 'http://trefle.io/api/plants/121562',
#   'id': 121562,
#   'complete_data': False,
#   'common_name': 'Sierra springbeauty'},
#  {'slug': 'vigna-mungo',
#   'scientific_name': 'Vigna mungo',
#   'link': 'http://trefle.io/api/plants/191958',
#   'id': 191958,
#   'complete_data': False,
#   'common_name': 'black gram'},
#  {'slug': 'chloris-andropogonoides',
#   'scientific_name': 'Chloris andropogonoides',
#   'link': 'http://trefle.io/api/plants/120101',
#   'id': 120101,
#   'complete_data': False,
#   'common_name': 'slimspike windmill grass'},
#  {'slug': 'phaseolus-mungo',
#   'scientific_name': 'Phaseolus mungo',
#   'link': 'http://trefle.io/api/plants/191959',
#   'id': 191959,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chorisia-speciosa',
#   'scientific_name': 'Chorisia speciosa',
#   'link': 'http://trefle.io/api/plants/120176',
#   'id': 120176,
#   'complete_data': False,
#   'common_name': 'silk-floss tree'},
#  {'slug': 'chrysanthemum-cinerariifolium',
#   'scientific_name': 'Chrysanthemum cinerariifolium',
#   'link': 'http://trefle.io/api/plants/120329',
#   'id': 120329,
#   'complete_data': False,
#   'common_name': 'pyrethrum'},
#  {'slug': 'chloris-truncata',
#   'scientific_name': 'Chloris truncata',
#   'link': 'http://trefle.io/api/plants/120131',
#   'id': 120131,
#   'complete_data': False,
#   'common_name': 'Australian fingergrass'},
#  {'slug': 'chloris-cucullata',
#   'scientific_name': 'Chloris cucullata',
#   'link': 'http://trefle.io/api/plants/120112',
#   'id': 120112,
#   'complete_data': False,
#   'common_name': 'hooded windmill grass'},
#  {'slug': 'vigna-schimperi',
#   'scientific_name': 'Vigna schimperi',
#   'link': 'http://trefle.io/api/plants/191976',
#   'id': 191976,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'vigna-speciosa',
#   'scientific_name': 'Vigna speciosa',
#   'link': 'http://trefle.io/api/plants/191977',
#   'id': 191977,
#   'complete_data': False,
#   'common_name': 'wondering cowpea'},
#  {'slug': 'viguiera-stenoloba',
#   'scientific_name': 'Viguiera stenoloba',
#   'link': 'http://trefle.io/api/plants/192015',
#   'id': 192015,
#   'complete_data': False,
#   'common_name': 'resinbush'},
#  {'slug': 'halesia-diptera',
#   'scientific_name': 'Halesia diptera',
#   'link': 'http://trefle.io/api/plants/140842',
#   'id': 140842,
#   'complete_data': False,
#   'common_name': 'two-wing silverbell'},
#  {'slug': 'gymnostomum-aeruginosum',
#   'scientific_name': 'Gymnostomum aeruginosum',
#   'link': 'http://trefle.io/api/plants/140643',
#   'id': 140643,
#   'complete_data': False,
#   'common_name': 'gymnostomum moss'},
#  {'slug': 'hamamelis-vernalis',
#   'scientific_name': 'Hamamelis vernalis',
#   'link': 'http://trefle.io/api/plants/140899',
#   'id': 140899,
#   'complete_data': False,
#   'common_name': 'Ozark witchhazel'},
#  {'slug': 'chromolaena-oteroi',
#   'scientific_name': 'Chromolaena oteroi',
#   'link': 'http://trefle.io/api/plants/120300',
#   'id': 120300,
#   'complete_data': False,
#   'common_name': 'Mona Island thoroughwort'},
#  {'slug': 'chrysopogon-pauciflorus',
#   'scientific_name': 'Chrysopogon pauciflorus',
#   'link': 'http://trefle.io/api/plants/120381',
#   'id': 120381,
#   'complete_data': False,
#   'common_name': 'Florida false beardgrass'},
#  {'slug': 'chrysopsis-latisquamea',
#   'scientific_name': 'Chrysopsis latisquamea',
#   'link': 'http://trefle.io/api/plants/120409',
#   'id': 120409,
#   'complete_data': False,
#   'common_name': 'pineland goldenaster'},
#  {'slug': 'cirsium-montigenum',
#   'scientific_name': 'Cirsium montigenum',
#   'link': 'http://trefle.io/api/plants/120759',
#   'id': 120759,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chionanthus-domingensis',
#   'scientific_name': 'Chionanthus domingensis',
#   'link': 'http://trefle.io/api/plants/120063',
#   'id': 120063,
#   'complete_data': False,
#   'common_name': 'white rosewood'},
#  {'slug': 'chrysopsis-decumbens',
#   'scientific_name': 'Chrysopsis decumbens',
#   'link': 'http://trefle.io/api/plants/120395',
#   'id': 120395,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'lepraria-citrina',
#   'scientific_name': 'Lepraria citrina',
#   'link': 'http://trefle.io/api/plants/120517',
#   'id': 120517,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'chrysosplenium-glechomifolium',
#   'scientific_name': 'Chrysosplenium glechomifolium',
#   'link': 'http://trefle.io/api/plants/120436',
#   'id': 120436,
#   'complete_data': False,
#   'common_name': 'Pacific golden saxifrage'},
#  {'slug': 'cirsium-hesperium',
#   'scientific_name': 'Cirsium hesperium',
#   'link': 'http://trefle.io/api/plants/120893',
#   'id': 120893,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cirsium-gilense',
#   'scientific_name': 'Cirsium gilense',
#   'link': 'http://trefle.io/api/plants/120735',
#   'id': 120735,
#   'complete_data': False,
#   'common_name': 'Gila thistle'},
#  {'slug': 'citharexylum-fruticosum',
#   'scientific_name': 'Citharexylum fruticosum',
#   'link': 'http://trefle.io/api/plants/121016',
#   'id': 121016,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'clarkia-epilobioides',
#   'scientific_name': 'Clarkia epilobioides',
#   'link': 'http://trefle.io/api/plants/121414',
#   'id': 121414,
#   'complete_data': False,
#   'common_name': 'canyon clarkia'},
#  {'slug': 'cladonia-botryocarpa',
#   'scientific_name': 'Cladonia botryocarpa',
#   'link': 'http://trefle.io/api/plants/121164',
#   'id': 121164,
#   'complete_data': False,
#   'common_name': 'cup lichen'},
#  {'slug': 'cladonia-bacilliformis',
#   'scientific_name': 'Cladonia bacilliformis',
#   'link': 'http://trefle.io/api/plants/121158',
#   'id': 121158,
#   'complete_data': False,
#   'common_name': 'cup lichen'},
#  {'slug': 'citharexylum-pentandrum',
#   'scientific_name': 'Citharexylum pentandrum',
#   'link': 'http://trefle.io/api/plants/121021',
#   'id': 121021,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cacalia-suaveolens',
#   'scientific_name': 'Cacalia suaveolens',
#   'link': 'http://trefle.io/api/plants/141020',
#   'id': 141020,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cirsium-brevifolium',
#   'scientific_name': 'Cirsium brevifolium',
#   'link': 'http://trefle.io/api/plants/120665',
#   'id': 120665,
#   'complete_data': False,
#   'common_name': 'Palouse thistle'},
#  {'slug': 'cissus-verticillata',
#   'scientific_name': 'Cissus verticillata',
#   'link': 'http://trefle.io/api/plants/120950',
#   'id': 120950,
#   'complete_data': False,
#   'common_name': 'seasonvine'},
#  {'slug': 'cladonia-metacorallifera',
#   'scientific_name': 'Cladonia metacorallifera',
#   'link': 'http://trefle.io/api/plants/121254',
#   'id': 121254,
#   'complete_data': False,
#   'common_name': 'cup lichen'},
#  {'slug': 'clarkia-franciscana',
#   'scientific_name': 'Clarkia franciscana',
#   'link': 'http://trefle.io/api/plants/121417',
#   'id': 121417,
#   'complete_data': False,
#   'common_name': 'Presidio clarkia'},
#  {'slug': 'chrysopsis-scabrella',
#   'scientific_name': 'Chrysopsis scabrella',
#   'link': 'http://trefle.io/api/plants/120422',
#   'id': 120422,
#   'complete_data': False,
#   'common_name': 'coastal plain goldenaster'},
#  {'slug': 'cirsium-flodmanii',
#   'scientific_name': 'Cirsium flodmanii',
#   'link': 'http://trefle.io/api/plants/120725',
#   'id': 120725,
#   'complete_data': False,
#   'common_name': "Flodman's thistle"},
#  {'slug': 'heterotheca-hyssopifolia',
#   'scientific_name': 'Heterotheca hyssopifolia',
#   'link': 'http://trefle.io/api/plants/120406',
#   'id': 120406,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cladonia-floerkeana',
#   'scientific_name': 'Cladonia floerkeana',
#   'link': 'http://trefle.io/api/plants/121214',
#   'id': 121214,
#   'complete_data': False,
#   'common_name': "Florke's cup lichen"},
#  {'slug': 'cladonia-piedmontensis',
#   'scientific_name': 'Cladonia piedmontensis',
#   'link': 'http://trefle.io/api/plants/121274',
#   'id': 121274,
#   'complete_data': False,
#   'common_name': 'piedmont cup lichen'},
#  {'slug': 'cicuta-maculata',
#   'scientific_name': 'Cicuta maculata',
#   'link': 'http://trefle.io/api/plants/120553',
#   'id': 120553,
#   'complete_data': False,
#   'common_name': 'spotted water hemlock'},
#  {'slug': 'cinnamomum-verum',
#   'scientific_name': 'Cinnamomum verum',
#   'link': 'http://trefle.io/api/plants/120606',
#   'id': 120606,
#   'complete_data': False,
#   'common_name': 'cinnamon'},
#  {'slug': 'cissus-tuberculata',
#   'scientific_name': 'Cissus tuberculata',
#   'link': 'http://trefle.io/api/plants/120949',
#   'id': 120949,
#   'complete_data': False,
#   'common_name': 'West Indian treebine'},
#  {'slug': 'cladonia-merochlorophaea',
#   'scientific_name': 'Cladonia merochlorophaea',
#   'link': 'http://trefle.io/api/plants/121253',
#   'id': 121253,
#   'complete_data': False,
#   'common_name': 'cup lichen'},
#  {'slug': 'cistanthe-ambigua',
#   'scientific_name': 'Cistanthe ambigua',
#   'link': 'http://trefle.io/api/plants/120953',
#   'id': 120953,
#   'complete_data': False,
#   'common_name': 'desert pussypaws'},
#  {'slug': 'cladina-pacifica',
#   'scientific_name': 'Cladina pacifica',
#   'link': 'http://trefle.io/api/plants/121107',
#   'id': 121107,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cistanthe-pygmaea',
#   'scientific_name': 'Cistanthe pygmaea',
#   'link': 'http://trefle.io/api/plants/120975',
#   'id': 120975,
#   'complete_data': False,
#   'common_name': 'pygmy pussypaws'},
#  {'slug': 'cladina-subtenuis',
#   'scientific_name': 'Cladina subtenuis',
#   'link': 'http://trefle.io/api/plants/121127',
#   'id': 121127,
#   'complete_data': False,
#   'common_name': 'reindeer lichen'},
#  {'slug': 'cirsium-perplexans',
#   'scientific_name': 'Cirsium perplexans',
#   'link': 'http://trefle.io/api/plants/120816',
#   'id': 120816,
#   'complete_data': False,
#   'common_name': 'Rocky Mountain thistle'},
#  {'slug': 'cirsium-undulatum',
#   'scientific_name': 'Cirsium undulatum',
#   'link': 'http://trefle.io/api/plants/120902',
#   'id': 120902,
#   'complete_data': False,
#   'common_name': 'wavyleaf thistle'},
#  {'slug': 'carduus-virginianus',
#   'scientific_name': 'Carduus virginianus',
#   'link': 'http://trefle.io/api/plants/120921',
#   'id': 120921,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cladonia-thiersii',
#   'scientific_name': 'Cladonia thiersii',
#   'link': 'http://trefle.io/api/plants/121321',
#   'id': 121321,
#   'complete_data': False,
#   'common_name': "Thiers' cup lichen"},
#  {'slug': 'clarkia-arcuata',
#   'scientific_name': 'Clarkia arcuata',
#   'link': 'http://trefle.io/api/plants/121384',
#   'id': 121384,
#   'complete_data': False,
#   'common_name': 'glandular clarkia'},
#  {'slug': 'cladonia-boryi',
#   'scientific_name': 'Cladonia boryi',
#   'link': 'http://trefle.io/api/plants/121163',
#   'id': 121163,
#   'complete_data': False,
#   'common_name': "Bory's cup lichen"},
#  {'slug': 'cladonia-coniocraea',
#   'scientific_name': 'Cladonia coniocraea',
#   'link': 'http://trefle.io/api/plants/121181',
#   'id': 121181,
#   'complete_data': False,
#   'common_name': 'cup lichen'},
#  {'slug': 'cladonia-denergans',
#   'scientific_name': 'Cladonia denergans',
#   'link': 'http://trefle.io/api/plants/121273',
#   'id': 121273,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'claoxylon-helleri',
#   'scientific_name': 'Claoxylon helleri',
#   'link': 'http://trefle.io/api/plants/121358',
#   'id': 121358,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'gyminda-latifolia',
#   'scientific_name': 'Gyminda latifolia',
#   'link': 'http://trefle.io/api/plants/140560',
#   'id': 140560,
#   'complete_data': False,
#   'common_name': 'West Indian false box'},
#  {'slug': 'haplocarpha-lyrata',
#   'scientific_name': 'Haplocarpha lyrata',
#   'link': 'http://trefle.io/api/plants/140930',
#   'id': 140930,
#   'complete_data': False,
#   'common_name': 'harp onefruit'},
#  {'slug': 'harpagonella-palmeri',
#   'scientific_name': 'Harpagonella palmeri',
#   'link': 'http://trefle.io/api/plants/140971',
#   'id': 140971,
#   'complete_data': False,
#   'common_name': "Palmer's grapplinghook"},
#  {'slug': 'ateramnus-lucidus',
#   'scientific_name': 'Ateramnus lucidus',
#   'link': 'http://trefle.io/api/plants/140568',
#   'id': 140568,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'gutierrezia-microcephala',
#   'scientific_name': 'Gutierrezia microcephala',
#   'link': 'http://trefle.io/api/plants/140484',
#   'id': 140484,
#   'complete_data': False,
#   'common_name': 'threadleaf snakeweed'},
#  {'slug': 'gymnocarpium-dryopteris',
#   'scientific_name': 'Gymnocarpium dryopteris',
#   'link': 'http://trefle.io/api/plants/140582',
#   'id': 140582,
#   'complete_data': False,
#   'common_name': 'western oakfern'},
#  {'slug': 'gypsoplaca-macrophylla',
#   'scientific_name': 'Gypsoplaca macrophylla',
#   'link': 'http://trefle.io/api/plants/140686',
#   'id': 140686,
#   'complete_data': False,
#   'common_name': 'largeleaf gypsoplaca lichen'},
#  {'slug': 'gutierrezia',
#   'scientific_name': 'Gutierrezia',
#   'link': 'http://trefle.io/api/plants/140477',
#   'id': 140477,
#   'complete_data': False,
#   'common_name': 'snakeweed'},
#  {'slug': 'gyalecta-flotowii',
#   'scientific_name': 'Gyalecta flotowii',
#   'link': 'http://trefle.io/api/plants/140533',
#   'id': 140533,
#   'complete_data': False,
#   'common_name': "Flotow's dimple lichen"},
#  {'slug': 'gymnocarpium',
#   'scientific_name': 'Gymnocarpium',
#   'link': 'http://trefle.io/api/plants/140571',
#   'id': 140571,
#   'complete_data': False,
#   'common_name': 'oakfern'},
#  {'slug': 'claoxylon-sandwicense',
#   'scientific_name': 'Claoxylon sandwicense',
#   'link': 'http://trefle.io/api/plants/121357',
#   'id': 121357,
#   'complete_data': False,
#   'common_name': "po'ola"},
#  {'slug': 'cladonia-subsetacea',
#   'scientific_name': 'Cladonia subsetacea',
#   'link': 'http://trefle.io/api/plants/121315',
#   'id': 121315,
#   'complete_data': False,
#   'common_name': 'cup lichen'},
#  {'slug': 'cladina-conspicua',
#   'scientific_name': 'Cladina conspicua',
#   'link': 'http://trefle.io/api/plants/121097',
#   'id': 121097,
#   'complete_data': False,
#   'common_name': 'conspicuous reindeer lichen'},
#  {'slug': 'hackelia-virginiana',
#   'scientific_name': 'Hackelia virginiana',
#   'link': 'http://trefle.io/api/plants/140778',
#   'id': 140778,
#   'complete_data': False,
#   'common_name': 'beggarslice'},
#  {'slug': 'achillea-pyrenaica',
#   'scientific_name': 'Achillea pyrenaica',
#   'link': 'http://trefle.io/api/plants/101975',
#   'id': 101975,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'gymnostomum-tenue',
#   'scientific_name': 'Gymnostomum tenue',
#   'link': 'http://trefle.io/api/plants/140694',
#   'id': 140694,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'halecania-alpivaga',
#   'scientific_name': 'Halecania alpivaga',
#   'link': 'http://trefle.io/api/plants/140829',
#   'id': 140829,
#   'complete_data': False,
#   'common_name': 'halecania lichen'},
#  {'slug': 'hackelia-hirsuta',
#   'scientific_name': 'Hackelia hirsuta',
# ...
#  {'slug': 'dodonaea-eriocarpa',
#   'scientific_name': 'Dodonaea eriocarpa',
#   'link': 'http://trefle.io/api/plants/129837',
#   'id': 129837,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'hygroamblystegium-macroneuron',
#   'scientific_name': 'Hygroamblystegium macroneuron',
#   'link': 'http://trefle.io/api/plants/129924',
#   'id': 129924,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'dopatrium-junceum',
#   'scientific_name': 'Dopatrium junceum',
#   'link': 'http://trefle.io/api/plants/129929',
#   'id': 129929,
#   'complete_data': False,
#   'common_name': "horsefly's eye"},
#  {'slug': 'draba-arabisans',
#   'scientific_name': 'Draba arabisans',
#   'link': 'http://trefle.io/api/plants/130035',
#   'id': 130035,
#   'complete_data': False,
#   'common_name': 'rock draba'},
#  {'slug': 'dodecatheon-hansenii',
#   'scientific_name': 'Dodecatheon hansenii',
#   'link': 'http://trefle.io/api/plants/129779',
#   'id': 129779,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'doodia',
#   'scientific_name': 'Doodia',
#   'link': 'http://trefle.io/api/plants/129925',
#   'id': 129925,
#   'complete_data': False,
#   'common_name': 'hacksaw fern'},
#  {'slug': 'dodecatheon-cusickii',
#   'scientific_name': 'Dodecatheon cusickii',
#   'link': 'http://trefle.io/api/plants/129798',
#   'id': 129798,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'dorema',
#   'scientific_name': 'Dorema',
#   'link': 'http://trefle.io/api/plants/129930',
#   'id': 129930,
#   'complete_data': False,
#   'common_name': 'dorema'},
#  {'slug': 'draba-eschscholtzii',
#   'scientific_name': 'Draba eschscholtzii',
#   'link': 'http://trefle.io/api/plants/130031',
#   'id': 130031,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'dipsacus',
#   'scientific_name': 'Dipsacus',
#   'link': 'http://trefle.io/api/plants/129616',
#   'id': 129616,
#   'complete_data': False,
#   'common_name': 'teasel'},
#  {'slug': 'dodonaea-elaeagnoides',
#   'scientific_name': 'Dodonaea elaeagnoides',
#   'link': 'http://trefle.io/api/plants/129836',
#   'id': 129836,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'doronicum-austriacum',
#   'scientific_name': 'Doronicum austriacum',
#   'link': 'http://trefle.io/api/plants/129933',
#   'id': 129933,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'dodonaea-microcarya',
#   'scientific_name': 'Dodonaea microcarya',
#   'link': 'http://trefle.io/api/plants/129857',
#   'id': 129857,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'draba-graminea',
#   'scientific_name': 'Draba graminea',
#   'link': 'http://trefle.io/api/plants/130136',
#   'id': 130136,
#   'complete_data': False,
#   'common_name': 'Rocky Mountain draba'},
#  {'slug': 'dodecatheon-redolens',
#   'scientific_name': 'Dodecatheon redolens',
#   'link': 'http://trefle.io/api/plants/129825',
#   'id': 129825,
#   'complete_data': False,
#   'common_name': 'scented shootingstar'},
#  {'slug': 'dodonaea',
#   'scientific_name': 'Dodonaea',
#   'link': 'http://trefle.io/api/plants/129829',
#   'id': 129829,
#   'complete_data': False,
#   'common_name': 'dodonaea'},
#  {'slug': 'doodia-kunthiana',
#   'scientific_name': 'Doodia kunthiana',
#   'link': 'http://trefle.io/api/plants/129926',
#   'id': 129926,
#   'complete_data': False,
#   'common_name': "Kunth's hacksaw fern"},
#  {'slug': 'dorema-ammoniacum',
#   'scientific_name': 'Dorema ammoniacum',
#   'link': 'http://trefle.io/api/plants/129931',
#   'id': 129931,
#   'complete_data': False,
#   'common_name': 'ammoniakum'},
#  {'slug': 'draba-cana',
#   'scientific_name': 'Draba cana',
#   'link': 'http://trefle.io/api/plants/130069',
#   'id': 130069,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'adiantum-shastense',
#   'scientific_name': 'Adiantum shastense',
#   'link': 'http://trefle.io/api/plants/102441',
#   'id': 102441,
#   'complete_data': False,
#   'common_name': 'Shasta maidenhair'},
#  {'slug': 'draba-cinerea',
#   'scientific_name': 'Draba cinerea',
#   'link': 'http://trefle.io/api/plants/130082',
#   'id': 130082,
#   'complete_data': False,
#   'common_name': 'grayleaf draba'},
#  {'slug': 'ditrichum-pallidum',
#   'scientific_name': 'Ditrichum pallidum',
#   'link': 'http://trefle.io/api/plants/129717',
#   'id': 129717,
#   'complete_data': False,
#   'common_name': 'pale ditrichum moss'},
#  {'slug': 'ditrichum-schimperi',
#   'scientific_name': 'Ditrichum schimperi',
#   'link': 'http://trefle.io/api/plants/129722',
#   'id': 129722,
#   'complete_data': False,
#   'common_name': "Schimper's ditrichum moss"},
#  {'slug': 'dodecatheon-radicatum',
#   'scientific_name': 'Dodecatheon radicatum',
#   'link': 'http://trefle.io/api/plants/129821',
#   'id': 129821,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'dodonaea-thunbergiana',
#   'scientific_name': 'Dodonaea thunbergiana',
#   'link': 'http://trefle.io/api/plants/129864',
#   'id': 129864,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'draba-albertina',
#   'scientific_name': 'Draba albertina',
#   'link': 'http://trefle.io/api/plants/130024',
#   'id': 130024,
#   'complete_data': False,
#   'common_name': 'slender draba'},
#  {'slug': 'draba-aleutica',
#   'scientific_name': 'Draba aleutica',
#   'link': 'http://trefle.io/api/plants/130028',
#   'id': 130028,
#   'complete_data': False,
#   'common_name': 'Aleutian draba'},
#  {'slug': 'distichlis',
#   'scientific_name': 'Distichlis',
#   'link': 'http://trefle.io/api/plants/129682',
#   'id': 129682,
#   'complete_data': False,
#   'common_name': 'saltgrass'},
#  {'slug': 'achillea-setacea',
#   'scientific_name': 'Achillea setacea',
#   'link': 'http://trefle.io/api/plants/101976',
#   'id': 101976,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'ditrichum-ambiguum',
#   'scientific_name': 'Ditrichum ambiguum',
#   'link': 'http://trefle.io/api/plants/129708',
#   'id': 129708,
#   'complete_data': False,
#   'common_name': 'ambiguous ditrichum moss'},
#  {'slug': 'dodecatheon-hugeri',
#   'scientific_name': 'Dodecatheon hugeri',
#   'link': 'http://trefle.io/api/plants/129792',
#   'id': 129792,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'gregoria-montana',
#   'scientific_name': 'Gregoria montana',
#   'link': 'http://trefle.io/api/plants/129977',
#   'id': 129977,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'dovyalis-abyssinica',
#   'scientific_name': 'Dovyalis abyssinica',
#   'link': 'http://trefle.io/api/plants/129986',
#   'id': 129986,
#   'complete_data': False,
#   'common_name': 'koshum'},
#  {'slug': 'dodecatheon-amethystinum',
#   'scientific_name': 'Dodecatheon amethystinum',
#   'link': 'http://trefle.io/api/plants/129748',
#   'id': 129748,
#   'complete_data': False,
#   'common_name': 'jeweled shootingstar'},
#  {'slug': 'aberia-caffra',
#   'scientific_name': 'Aberia caffra',
#   'link': 'http://trefle.io/api/plants/129988',
#   'id': 129988,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'aster-scaber',
#   'scientific_name': 'Aster scaber',
#   'link': 'http://trefle.io/api/plants/129882',
#   'id': 129882,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'doyerea-emetocathartica',
#   'scientific_name': 'Doyerea emetocathartica',
#   'link': 'http://trefle.io/api/plants/130021',
#   'id': 130021,
#   'complete_data': False,
#   'common_name': 'coralfruit'},
#  {'slug': 'draba-reptans',
#   'scientific_name': 'Draba reptans',
#   'link': 'http://trefle.io/api/plants/130248',
#   'id': 130248,
#   'complete_data': False,
#   'common_name': 'Carolina draba'},
#  {'slug': 'draba-peasei',
#   'scientific_name': 'Draba peasei',
#   'link': 'http://trefle.io/api/plants/130155',
#   'id': 130155,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'drosera-intermedia',
#   'scientific_name': 'Drosera intermedia',
#   'link': 'http://trefle.io/api/plants/130380',
#   'id': 130380,
#   'complete_data': False,
#   'common_name': 'spoonleaf sundew'},
#  {'slug': 'draba-barbata',
#   'scientific_name': 'Draba barbata',
#   'link': 'http://trefle.io/api/plants/130092',
#   'id': 130092,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cylindropyrum-cylindricum',
#   'scientific_name': 'Cylindropyrum cylindricum',
#   'link': 'http://trefle.io/api/plants/102476',
#   'id': 102476,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'draba-trichocarpa',
#   'scientific_name': 'Draba trichocarpa',
#   'link': 'http://trefle.io/api/plants/130286',
#   'id': 130286,
#   'complete_data': False,
#   'common_name': 'Stanley Creek draba'},
#  {'slug': 'railliardia-waianapanapaenis',
#   'scientific_name': 'Railliardia waianapanapaenis',
#   'link': 'http://trefle.io/api/plants/130594',
#   'id': 130594,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'draba-palanderiana',
#   'scientific_name': 'Draba palanderiana',
#   'link': 'http://trefle.io/api/plants/130215',
#   'id': 130215,
#   'complete_data': False,
#   'common_name': "Palander's draba"},
#  {'slug': 'moldavica-parviflora',
#   'scientific_name': 'Moldavica parviflora',
#   'link': 'http://trefle.io/api/plants/130314',
#   'id': 130314,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'draba-streptocarpa',
#   'scientific_name': 'Draba streptocarpa',
#   'link': 'http://trefle.io/api/plants/130280',
#   'id': 130280,
#   'complete_data': False,
#   'common_name': 'pretty draba'},
#  {'slug': 'dracaena-concinna',
#   'scientific_name': 'Dracaena concinna',
#   'link': 'http://trefle.io/api/plants/130301',
#   'id': 130301,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'drymaria-laxiflora',
#   'scientific_name': 'Drymaria laxiflora',
#   'link': 'http://trefle.io/api/plants/130445',
#   'id': 130445,
#   'complete_data': False,
#   'common_name': 'Trans-Pecos drymary'},
#  {'slug': 'draba-globosa',
#   'scientific_name': 'Draba globosa',
#   'link': 'http://trefle.io/api/plants/130133',
#   'id': 130133,
#   'complete_data': False,
#   'common_name': 'beavertip draba'},
#  {'slug': 'dyschoriste-angusta',
#   'scientific_name': 'Dyschoriste angusta',
#   'link': 'http://trefle.io/api/plants/130833',
#   'id': 130833,
#   'complete_data': False,
#   'common_name': 'pineland snakeherb'},
#  {'slug': 'aeginetia-indica',
#   'scientific_name': 'Aeginetia indica',
#   'link': 'http://trefle.io/api/plants/102494',
#   'id': 102494,
#   'complete_data': False,
#   'common_name': 'ye gu'},
#  {'slug': 'dysphania-plantaginella',
#   'scientific_name': 'Dysphania plantaginella',
#   'link': 'http://trefle.io/api/plants/130901',
#   'id': 130901,
#   'complete_data': False,
#   'common_name': 'dwarf-flower'},
#  {'slug': 'echinotrefle-texensis',
#   'scientific_name': 'Echinotrefle texensis',
#   'link': 'http://trefle.io/api/plants/130978',
#   'id': 130978,
#   'complete_data': False,
#   'common_name': 'horse crippler'},
#  {'slug': 'dudleya-blochmaniae',
#   'scientific_name': 'Dudleya blochmaniae',
#   'link': 'http://trefle.io/api/plants/130711',
#   'id': 130711,
#   'complete_data': False,
#   'common_name': "Blochman's liveforever"},
#  {'slug': 'dudleya-lanceolata',
#   'scientific_name': 'Dudleya lanceolata',
#   'link': 'http://trefle.io/api/plants/130754',
#   'id': 130754,
#   'complete_data': False,
#   'common_name': 'lanceleaf liveforever'},
#  {'slug': 'eastwoodia-elegans',
#   'scientific_name': 'Eastwoodia elegans',
#   'link': 'http://trefle.io/api/plants/130910',
#   'id': 130910,
#   'complete_data': False,
#   'common_name': 'yellow aster'},
#  {'slug': 'dysphania-ambrosioides',
#   'scientific_name': 'Dysphania ambrosioides',
#   'link': 'http://trefle.io/api/plants/130860',
#   'id': 130860,
#   'complete_data': False,
#   'common_name': 'Mexican tea'},
#  {'slug': 'dyschoriste-schiedeana',
#   'scientific_name': 'Dyschoriste schiedeana',
#   'link': 'http://trefle.io/api/plants/130848',
#   'id': 130848,
#   'complete_data': False,
#   'common_name': "Schied's snakeherb"},
#  {'slug': 'echeandia-chandleri',
#   'scientific_name': 'Echeandia chandleri',
#   'link': 'http://trefle.io/api/plants/130931',
#   'id': 130931,
#   'complete_data': False,
#   'common_name': "Chandler's craglily"},
#  {'slug': 'echinocereus-polyacanthus',
#   'scientific_name': 'Echinocereus polyacanthus',
#   'link': 'http://trefle.io/api/plants/131081',
#   'id': 131081,
#   'complete_data': False,
#   'common_name': 'Mojave mound trefle'},
#  {'slug': 'ecballium',
#   'scientific_name': 'Ecballium',
#   'link': 'http://trefle.io/api/plants/130923',
#   'id': 130923,
#   'complete_data': False,
#   'common_name': 'squirting cucumber'},
#  {'slug': 'petalostemon-flavescens',
#   'scientific_name': 'Petalostemon flavescens',
#   'link': 'http://trefle.io/api/plants/127120',
#   'id': 127120,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'echeandia-texensis',
#   'scientific_name': 'Echeandia texensis',
#   'link': 'http://trefle.io/api/plants/130938',
#   'id': 130938,
#   'complete_data': False,
#   'common_name': 'Texas craglily'},
#  {'slug': 'cereus-atacamensis',
#   'scientific_name': 'Cereus atacamensis',
#   'link': 'http://trefle.io/api/plants/131277',
#   'id': 131277,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'echinopogon-nutans',
#   'scientific_name': 'Echinopogon nutans',
#   'link': 'http://trefle.io/api/plants/131266',
#   'id': 131266,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'cyrtandra-hobdyi',
#   'scientific_name': 'Cyrtandra hobdyi',
#   'link': 'http://trefle.io/api/plants/126762',
#   'id': 126762,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'echium-candicans',
#   'scientific_name': 'Echium candicans',
#   'link': 'http://trefle.io/api/plants/131291',
#   'id': 131291,
#   'complete_data': False,
#   'common_name': 'pride of Madeira'},
#  {'slug': 'elatine-heterandra',
#   'scientific_name': 'Elatine heterandra',
#   'link': 'http://trefle.io/api/plants/131445',
#   'id': 131445,
#   'complete_data': False,
#   'common_name': 'mosquito waterwort'},
#  {'slug': 'eleocharis-congesta',
#   'scientific_name': 'Eleocharis congesta',
#   'link': 'http://trefle.io/api/plants/131497',
#   'id': 131497,
#   'complete_data': False,
#   'common_name': 'spikerush'},
#  {'slug': 'echinocereus-enneacanthus',
#   'scientific_name': 'Echinocereus enneacanthus',
#   'link': 'http://trefle.io/api/plants/131038',
#   'id': 131038,
#   'complete_data': False,
#   'common_name': 'pitaya'},
#  {'slug': 'sclerotrefle-mariposensis',
#   'scientific_name': 'Sclerotrefle mariposensis',
#   'link': 'http://trefle.io/api/plants/131252',
#   'id': 131252,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'luziola-peruviana',
#   'scientific_name': 'Luziola peruviana',
#   'link': 'http://trefle.io/api/plants/152968',
#   'id': 152968,
#   'complete_data': False,
#   'common_name': 'Peruvian watergrass'},
#  {'slug': 'egeria',
#   'scientific_name': 'Egeria',
#   'link': 'http://trefle.io/api/plants/131322',
#   'id': 131322,
#   'complete_data': False,
#   'common_name': 'egeria'},
#  {'slug': 'eichhornia-diversifolia',
#   'scientific_name': 'Eichhornia diversifolia',
#   'link': 'http://trefle.io/api/plants/131352',
#   'id': 131352,
#   'complete_data': False,
#   'common_name': 'variableleaf water hyacinth'},
#  {'slug': 'xyris-isoetifolia',
#   'scientific_name': 'Xyris isoetifolia',
#   'link': 'http://trefle.io/api/plants/193285',
#   'id': 193285,
#   'complete_data': False,
#   'common_name': 'quillwort yelloweyed grass'},
#  {'slug': 'echium-creticum',
#   'scientific_name': 'Echium creticum',
#   'link': 'http://trefle.io/api/plants/131294',
#   'id': 131294,
#   'complete_data': False,
#   'common_name': "Cretan viper's bugloss"},
#  {'slug': 'xanthium-strumarium',
#   'scientific_name': 'Xanthium strumarium',
#   'link': 'http://trefle.io/api/plants/192961',
#   'id': 192961,
#   'complete_data': False,
#   'common_name': 'rough cocklebur'},
#  {'slug': 'xanthoparmelia-camtschadalis',
#   'scientific_name': 'Xanthoparmelia camtschadalis',
#   'link': 'http://trefle.io/api/plants/193017',
#   'id': 193017,
#   'complete_data': False,
#   'common_name': 'Kamchatka xanthoparmelia lichen'},
#  {'slug': 'parmelia-neoconspersa',
#   'scientific_name': 'Parmelia neoconspersa',
#   'link': 'http://trefle.io/api/plants/193057',
#   'id': 193057,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'xanthoparmelia-dierythra',
#   'scientific_name': 'Xanthoparmelia dierythra',
#   'link': 'http://trefle.io/api/plants/193028',
#   'id': 193028,
#   'complete_data': False,
#   'common_name': 'xanthoparmelia lichen'},
#  ...]

# %%
payload = {'q': 'acinacea'}
headers = {'content-type': 'application/json',
            'Authorization': 'NDdUcFg4SnVNbXlXcHFXTGZweUVJdz09'}
r = requests.get('https://trefle.io/api/plants', headers = headers)
json.loads(r.text)
# Out:
# [{'slug': 'dyckia-macracantha',
#   'scientific_name': 'Dyckia macracantha',
#   'link': 'http://trefle.io/api/plants/294231',
#   'id': 294231,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'dyckia-goiana',
#   'scientific_name': 'Dyckia goiana',
#   'link': 'http://trefle.io/api/plants/294252',
#   'id': 294252,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'dyckia-lagoensis',
#   'scientific_name': 'Dyckia lagoensis',
#   'link': 'http://trefle.io/api/plants/294267',
#   'id': 294267,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'dyckia-pseudococcinea',
#   'scientific_name': 'Dyckia pseudococcinea',
#   'link': 'http://trefle.io/api/plants/294275',
#   'id': 294275,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'puya-lehmanniana',
#   'scientific_name': 'Puya lehmanniana',
#   'link': 'http://trefle.io/api/plants/293882',
#   'id': 293882,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'pitcairnia-furfuracea',
#   'scientific_name': 'Pitcairnia furfuracea',
#   'link': 'http://trefle.io/api/plants/293888',
#   'id': 293888,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'puya-santanderensis',
#   'scientific_name': 'Puya santanderensis',
#   'link': 'http://trefle.io/api/plants/293897',
#   'id': 293897,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'pitcairnia-killipiana',
#   'scientific_name': 'Pitcairnia killipiana',
#   'link': 'http://trefle.io/api/plants/293907',
#   'id': 293907,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'pitcairnia-adscendens',
#   'scientific_name': 'Pitcairnia adscendens',
#   'link': 'http://trefle.io/api/plants/293917',
#   'id': 293917,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'navia-bicolor',
#   'scientific_name': 'Navia bicolor',
#   'link': 'http://trefle.io/api/plants/293935',
#   'id': 293935,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'tillandsia-engleriana',
#   'scientific_name': 'Tillandsia engleriana',
#   'link': 'http://trefle.io/api/plants/293944',
#   'id': 293944,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'anoplophytum-stramineum',
#   'scientific_name': 'Anoplophytum stramineum',
#   'link': 'http://trefle.io/api/plants/293960',
#   'id': 293960,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'greigia-racinae',
#   'scientific_name': 'Greigia racinae',
#   'link': 'http://trefle.io/api/plants/293967',
#   'id': 293967,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'puya-hortensis',
#   'scientific_name': 'Puya hortensis',
#   'link': 'http://trefle.io/api/plants/293996',
#   'id': 293996,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'hechtia-mooreana',
#   'scientific_name': 'Hechtia mooreana',
#   'link': 'http://trefle.io/api/plants/294005',
#   'id': 294005,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'hechtia-lindmanioides',
#   'scientific_name': 'Hechtia lindmanioides',
#   'link': 'http://trefle.io/api/plants/294021',
#   'id': 294021,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'ananas-muricatus',
#   'scientific_name': 'Ananas muricatus',
#   'link': 'http://trefle.io/api/plants/294029',
#   'id': 294029,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'pitcairnia-affinis',
#   'scientific_name': 'Pitcairnia affinis',
#   'link': 'http://trefle.io/api/plants/294048',
#   'id': 294048,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'hohenbergia-pabstii',
#   'scientific_name': 'Hohenbergia pabstii',
#   'link': 'http://trefle.io/api/plants/294084',
#   'id': 294084,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'aechmea-ridleyi',
#   'scientific_name': 'Aechmea ridleyi',
#   'link': 'http://trefle.io/api/plants/294097',
#   'id': 294097,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'quesnelia-seideliana',
#   'scientific_name': 'Quesnelia seideliana',
#   'link': 'http://trefle.io/api/plants/294106',
#   'id': 294106,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'pitcairnia-domingensis',
#   'scientific_name': 'Pitcairnia domingensis',
#   'link': 'http://trefle.io/api/plants/294113',
#   'id': 294113,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'billbergia-chlorosticta',
#   'scientific_name': 'Billbergia chlorosticta',
#   'link': 'http://trefle.io/api/plants/294121',
#   'id': 294121,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'pitcairnia-abundans',
#   'scientific_name': 'Pitcairnia abundans',
#   'link': 'http://trefle.io/api/plants/294128',
#   'id': 294128,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'pitcairnia-racemosa',
#   'scientific_name': 'Pitcairnia racemosa',
#   'link': 'http://trefle.io/api/plants/294152',
#   'id': 294152,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'hepetis-flammea',
#   'scientific_name': 'Hepetis flammea',
#   'link': 'http://trefle.io/api/plants/294160',
#   'id': 294160,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'hepetis-dietrichiana',
#   'scientific_name': 'Hepetis dietrichiana',
#   'link': 'http://trefle.io/api/plants/294172',
#   'id': 294172,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'pitcairnia-dietrichiana',
#   'scientific_name': 'Pitcairnia dietrichiana',
#   'link': 'http://trefle.io/api/plants/294177',
#   'id': 294177,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'pitcairnia-odorata',
#   'scientific_name': 'Pitcairnia odorata',
#   'link': 'http://trefle.io/api/plants/294190',
#   'id': 294190,
#   'complete_data': False,
#   'common_name': None},
#  {'slug': 'lamproconus-giganteus',
#   'scientific_name': 'Lamproconus giganteus',
#   'link': 'http://trefle.io/api/plants/294201',
#   'id': 294201,
#   'complete_data': False,
#   'common_name': None}]

# %%
df
# Out:
#                                  Type            Genus Tube colour  \
# 0                    Trees and Shrubs          Acacia            B
# 1                    Trees and Shrubs          Acacia            B
# 2                    Trees and Shrubs          Acacia            B
# 3                    Trees and Shrubs          Acacia            B
# 4                    Trees and Shrubs          Acacia            B
# 5                    Trees and Shrubs          Acacia            B
# 6                    Trees and Shrubs          Acacia            B
# 7                    Trees and Shrubs          Acacia            B
# 8                    Trees and Shrubs          Acacia            B
# 9                    Trees and Shrubs          Acacia            B
# 10                   Trees and Shrubs          Acacia            B
# 11                   Trees and Shrubs          Acacia            B
# 12                   Trees and Shrubs          Acacia            B
# 13                   Trees and Shrubs          Acacia            B
# 14                   Trees and Shrubs          Acacia            B
# 15                   Trees and Shrubs          Acacia            B
# 16                   Trees and Shrubs          Acacia            B
# 17                   Trees and Shrubs          Acacia            B
# 18                   Trees and Shrubs          Acacia            B
# 19                   Trees and Shrubs          Acacia            B
# 20                   Trees and Shrubs          Acacia            B
# 21                   Trees and Shrubs          Acacia            B
# 22                   Trees and Shrubs          Acacia            B
# 23                   Trees and Shrubs          Acacia            B
# 24                   Trees and Shrubs          Acacia            B
# 25                   Trees and Shrubs          Acacia            B
# 26                   Trees and Shrubs          Acacia            B
# 27                   Trees and Shrubs          Acacia            B
# 28                   Trees and Shrubs          Acacia            B
# 29                   Trees and Shrubs          Acacia            B
# ..                                ...              ...         ...
# 212                           Grasses       Distichlis           B
# 213                           Grasses           Elymus           B
# 214                           Grasses       Enneapogon           B
# 215                           Grasses              Poa           B
# 216                           Grasses              Poa           B
# 217                           Grasses              Poa           B
# 218                           Grasses          Triodia           B
# 219         Other Strap-leaved Plants         Dianella           B
# 220         Other Strap-leaved Plants       Diplarrena           B
# 221         Other Strap-leaved Plants         Lomandra           B
# 222         Other Strap-leaved Plants         Lomandra           B
# 223         Other Strap-leaved Plants         Lomandra           B
# 224         Other Strap-leaved Plants    Orthrosanthus           B
# 225         Other Strap-leaved Plants       Patersonia           B
# 226         Other Strap-leaved Plants     Xanthorrhoea           B
# 227                  Bulbs and Lilies    Arthropodium            B
# 228                  Bulbs and Lilies         Bulbine            B
# 229                  Bulbs and Lilies       Burchardia           B
# 230                  Bulbs and Lilies       Calostemma           B
# 231  Aquatic and Riparian Zone Plants         Centella           G
# 232  Aquatic and Riparian Zone Plants         Lobelia            G
# 233  Aquatic and Riparian Zone Plants           Mazus            G
# 234  Aquatic and Riparian Zone Plants          Mentha            G
# 235  Aquatic and Riparian Zone Plants         Mimulus            G
# 236                 Rushes and Sedges            Carex           B
# 237                 Rushes and Sedges            Carex           B
# 238                 Rushes and Sedges       Eleocharis           B
# 239                 Rushes and Sedges           Gahnia           B
# 240                 Rushes and Sedges        Isolepis            B
# 241                 Rushes and Sedges  Schoenoplectus            B
#
#                      Botanical name              Common name Height (m)  \
# 0                         acinacea       round-leaved wattle        1-2
# 1                      argyrophylla        golden-grey mulga        1-5
# 2                      brachybotrya               grey mulga        2-4
# 3                       calamifolia                 wallowa         2-5
# 4                          farinosa             mealy wattle        1-2
# 5                        floribunda          gossamer wattle        4-7
# 6                     glandulicarpa         hairy-pod wattle        1-3
# 7                            gunnii       ploughshare wattle    0.2-0.8
# 8                         hakeoides             hakea wattle      2.5-4
# 9                          howittii            sticky wattle        4-8
# 10                         ligulata          umbrella wattle        2-4
# 11                          lineata          streaked wattle      0.5-3
# 12         longifolia var. sophorae           coastal wattle        2-5
# 13             melanoxylon SA forms                blackwood       7-20
# 14                       microcarpa             manna wattle        1-3
# 15                          montana            mallee wattle        2-4
# 16                       myrtifolia            myrtle wattle        1-2
# 17                        notabilis           notable wattle        3-6
# 18                        paradoxa            kangaroo thorn        2-4
# 19                          pendula            weeping myall       6-10
# 20                       pravissima            Oven’s wattle        4-8
# 21                        pycnantha            golden wattle        4-6
# 22                       retinodes                   wirilda        5-8
# 23                           rigens                   nealie        2-4
# 24                         rupicola              rock wattle      1-2.5
# 25                         salicina        Broughton willow        4-10
# 26   sclerophylla var. sclerophylla         hard-leaf wattle        1-2
# 27                      verniciflua           varnish wattle        3-5
# 28         verticillata ssp ovoidea            prickly moses        2-4
# 29                      wilhelmiana             dwarf nealie        1-3
# ..                              ...                      ...        ...
# 212                  distichophylla                emu-grass        0.4
# 213               scaber var scaber       common wheat-grass      0.2-1
# 214                       nigricans           bottle washers    0.2-0.5
# 215                  labillardieri            tussock grass       0.3-1
# 216                       poiformis       blue tussock grass    0.6-1.2
# 217                      sieberiana       grey tussock grass    0.3-0.8
# 218                        scariosa          porcupine grass        0.6
# 219                       tasmanica         Tasman flax-lily    0.6-1.7
# 220                          moraea           butterfly flag    0.3-0.6
# 221                          effusa         scented mat-rush    0.2-0.5
# 222                      longifolia    spiny headed mat-rush      0.5-1
# 223         micrantha ssp micrantha  small-flowered mat-rush    0.2-0.8
# 224                     multiflorus             morning iris    0.3-0.6
# 225                    occidentalis         long purple flag        0.5
# 226                       australis       Austral grass tree      0.5-2
# 227                        strictum             vanilla lily        0.4
# 228                         bulbosa              native leek        0.3
# 229                       umbellata                milkmaids        0.3
# 230                       purpureum             purple bells    0.2-0.5
# 231                        asiatica                pennywort    0.1-0.4
# 232              anceps  syn: alata           angled lobelia    0.1-0.3
# 233                         pumilio              swamp mazus        0.1
# 234                       australis               river mint    0.3-0.8
# 235                          repens   creeping monkey flower        0.2
# 236                    fascicularis             tassel sedge          1
# 237                        gunniana           mountain sedge    0.2-0.7
# 238                           acuta        common spike rush    0.3-0.9
# 239                           filum         chaffy saw sedge      1-1.5
# 240                        inundata          swamp club rush        0.5
# 241                         validus          river club-rush    1.5-2.5
#
#     Spread (m) Rain (mm) Soil texture Soil pH Frost Flower colour  \
# 0          1-2       300     Sa,Lo,Cl     ANC     R             Y
# 1          2-6       350     Sa,Lo,Li     ANC     R             Y
# 2        1.5-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 3          2-4       200  Sa,Lo,Cl,Li     ANC     M             Y
# 4          2-4       350   Sa, Lo, Li     ANC     M             Y
# 5          4-6       550        Lo,Cl    AN/C     M             Y
# 6          1-3       350        Sa,Lo     ANC     R             Y
# 7          1-2       500     Sa,Lo,Cl      AN     R             Y
# 8          3-5       250        Sa,Lo     ANC     R             Y
# 9          3-6       450        Lo,Cl     ANC     R             Y
# 10         4-6       150  Sa,Lo,Cl Li     ANC     R             Y
# 11         1-3       500     Sa,Lo,Cl     ANC     M             Y
# 12         4-8       450        Sa,Lo     ANC     M             Y
# 13        4-10       500        Lo,Cl    AN/C     R             Y
# 14         2-4       300  Sa,Cl,Lo,Li     ANC     R             Y
# 15         2-5       325  Sa,Cl,Lo,Li     ANC     R             Y
# 16         1-2       500        Lo,Cl    AN/C     M             Y
# 17         3-4       250     Lo,Li,Cl     ANC     R             Y
# 18         3-4       300  Sa,Lo,Cl,Li     ANC     M             Y
# 19         6-8       250        Lo,Cl     ANC     M             Y
# 20         4-8       500     Sa,Lo,Cl    AN/C     M             Y
# 21         2-6       450     Sa,Lo,Cl     ANC     M             Y
# 22         3-7       500        Lo,Cl     ANC     M             Y
# 23         2-4       200  Sa,Lo,Cl,Li     ANC     R             Y
# 24       1-2.5       350  Sa,Lo,Cl,Li     ANC     R             Y
# 25         3-5       300        Lo,Cl     ANC     R             Y
# 26         2-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 27         3-5       450     Sa,Lo,Cl    AN/C     M             Y
# 28         1-3       600        Lo,Cl    AN/C     M             Y
# 29         2-3       250     Cl,Lo,Li     ANC     R             Y
# ..         ...       ...          ...     ...   ...           ...
# 212        1-2       350     Sa,Lo,Cl     ANC     R            Br
# 213    0.3-0.5       300     Sa,Lo,Cl     ANC     R            Cr
# 214        0.5       350    Sa, Lo,Cl     ANC     R         Br/Bl
# 215    0.3-0.7       400   Sa, Lo, Cl     ANC     R          G/Cr
# 216    0.5-1.5       350     Sa,Lo,Cl     ANC     R            Cr
# 217    0.3-0.8       500   Sa, Lo, Cl     ANC     M          G/Cr
# 218          1       300        Sa,Lo     ANC     M          G/Cr
# 219      0.5-2       650     Sa,Lo,Cl      AN     M             B
# 220      0.5-1       550     Sa,Lo,Cl     ANC     R             W
# 221    0.2-0.5       400       Sa, Lo     ANC     M          Cr/Y
# 222      0.5-1       500   Sa, Lo, Cl     ANC     R          Cr/Y
# 223    0.2-0.8       500   Sa, Lo, Cl     ANC     R             W
# 224      0.4-1       450     Sa,Lo,Cl     ANC     M             B
# 225        0.5       500       Lo, Cl      AN     M            Pu
# 226      0.6-1       500    Sa, Lo,Cl     ANC     R             W
# 227        0.4       400     Sa,Lo,Cl     ANC     M             P
# 228        0.3       500     Sa,Lo,Cl     ANC     M             Y
# 229        0.2       500     Sa,Lo,Cl     ANC     M             W
# 230        0.2       400     Sa,Lo,Cl     ANC     M         Pk, P
# 231      0.5-1       500     Sa,Lo,Cl     ANC     S             I
# 232      0.3-2       500        Lo,Cl    AN/C     M             P
# 233          1       600     Sa,Lo,Cl     ANC     M             P
# 234    0.3-1.5       600     Sa,Lo,Cl      AN     M             W
# 235        1-2       500     Sa,Lo,Cl     ANC     M             P
# 236          1       AQU     Sa,Lo,Cl     ANC     R             G
# 237      0.5-1       AQU     Sa,Lo,Cl     ANC     M            Br
# 238        2-3       AQU     Sa,Lo,Cl    AN/C     M            Br
# 239      1-1.5       550        Sa,Lo    AN/C     R             B
# 240      0.5-1       AQU     Sa,Lo,Cl     ANC     R            Br
# 241      1.5-3       AQU     Sa,Lo,Cl     ANC     R             B
#
#     Flower (time)
# 0            W,Sp
# 1            W,Sp
# 2            W,Sp
# 3            W,Sp
# 4           W, Sp
# 5            W,Sp
# 6            W,Sp
# 7            W,Sp
# 8            W,Sp
# 9              Sp
# 10             Sp
# 11             Sp
# 12           W,Sp
# 13           W,Sp
# 14           W,Sp
# 15             Sp
# 16             Sp
# 17           W,Sp
# 18             Sp
# 19         A,W,Sp
# 20           W,Sp
# 21           W,Sp
# 22           W,Sp
# 23           W,Sp
# 24           Sp,S
# 25           W,Sp
# 26             Sp
# 27         W,Sp,S
# 28         W,Sp,S
# 29           W,Sp
# ..            ...
# 212          Sp,S
# 213          W,Sp
# 214          Sp,S
# 215         Sp, S
# 216         Sp,Su
# 217         Sp, S
# 218          W,Sp
# 219          Sp,S
# 220          Sp,S
# 221          W,Sp
# 222         Sp, S
# 223        A,W,Sp
# 224            Sp
# 225            Sp
# 226        W,Sp,S
# 227            Sp
# 228            Sp
# 229            Sp
# 230             A
# 231            Sp
# 232          Sp,S
# 233          Sp,S
# 234            Sp
# 235          Sp,S
# 236          Sp,S
# 237          Sp,S
# 238          Sp,S
# 239             F
# 240            Sp
# 241           S,A
#
# [242 rows x 13 columns]

# %%
df
# Out:
#                                  Type            Genus Tube colour  \
# 0                    Trees and Shrubs          Acacia            B
# 1                    Trees and Shrubs          Acacia            B
# 2                    Trees and Shrubs          Acacia            B
# 3                    Trees and Shrubs          Acacia            B
# 4                    Trees and Shrubs          Acacia            B
# 5                    Trees and Shrubs          Acacia            B
# 6                    Trees and Shrubs          Acacia            B
# 7                    Trees and Shrubs          Acacia            B
# 8                    Trees and Shrubs          Acacia            B
# 9                    Trees and Shrubs          Acacia            B
# 10                   Trees and Shrubs          Acacia            B
# 11                   Trees and Shrubs          Acacia            B
# 12                   Trees and Shrubs          Acacia            B
# 13                   Trees and Shrubs          Acacia            B
# 14                   Trees and Shrubs          Acacia            B
# 15                   Trees and Shrubs          Acacia            B
# 16                   Trees and Shrubs          Acacia            B
# 17                   Trees and Shrubs          Acacia            B
# 18                   Trees and Shrubs          Acacia            B
# 19                   Trees and Shrubs          Acacia            B
# 20                   Trees and Shrubs          Acacia            B
# 21                   Trees and Shrubs          Acacia            B
# 22                   Trees and Shrubs          Acacia            B
# 23                   Trees and Shrubs          Acacia            B
# 24                   Trees and Shrubs          Acacia            B
# 25                   Trees and Shrubs          Acacia            B
# 26                   Trees and Shrubs          Acacia            B
# 27                   Trees and Shrubs          Acacia            B
# 28                   Trees and Shrubs          Acacia            B
# 29                   Trees and Shrubs          Acacia            B
# ..                                ...              ...         ...
# 212                           Grasses       Distichlis           B
# 213                           Grasses           Elymus           B
# 214                           Grasses       Enneapogon           B
# 215                           Grasses              Poa           B
# 216                           Grasses              Poa           B
# 217                           Grasses              Poa           B
# 218                           Grasses          Triodia           B
# 219         Other Strap-leaved Plants         Dianella           B
# 220         Other Strap-leaved Plants       Diplarrena           B
# 221         Other Strap-leaved Plants         Lomandra           B
# 222         Other Strap-leaved Plants         Lomandra           B
# 223         Other Strap-leaved Plants         Lomandra           B
# 224         Other Strap-leaved Plants    Orthrosanthus           B
# 225         Other Strap-leaved Plants       Patersonia           B
# 226         Other Strap-leaved Plants     Xanthorrhoea           B
# 227                  Bulbs and Lilies    Arthropodium            B
# 228                  Bulbs and Lilies         Bulbine            B
# 229                  Bulbs and Lilies       Burchardia           B
# 230                  Bulbs and Lilies       Calostemma           B
# 231  Aquatic and Riparian Zone Plants         Centella           G
# 232  Aquatic and Riparian Zone Plants         Lobelia            G
# 233  Aquatic and Riparian Zone Plants           Mazus            G
# 234  Aquatic and Riparian Zone Plants          Mentha            G
# 235  Aquatic and Riparian Zone Plants         Mimulus            G
# 236                 Rushes and Sedges            Carex           B
# 237                 Rushes and Sedges            Carex           B
# 238                 Rushes and Sedges       Eleocharis           B
# 239                 Rushes and Sedges           Gahnia           B
# 240                 Rushes and Sedges        Isolepis            B
# 241                 Rushes and Sedges  Schoenoplectus            B
#
#                      Botanical name              Common name Height (m)  \
# 0                         acinacea       round-leaved wattle        1-2
# 1                      argyrophylla        golden-grey mulga        1-5
# 2                      brachybotrya               grey mulga        2-4
# 3                       calamifolia                 wallowa         2-5
# 4                          farinosa             mealy wattle        1-2
# 5                        floribunda          gossamer wattle        4-7
# 6                     glandulicarpa         hairy-pod wattle        1-3
# 7                            gunnii       ploughshare wattle    0.2-0.8
# 8                         hakeoides             hakea wattle      2.5-4
# 9                          howittii            sticky wattle        4-8
# 10                         ligulata          umbrella wattle        2-4
# 11                          lineata          streaked wattle      0.5-3
# 12         longifolia var. sophorae           coastal wattle        2-5
# 13             melanoxylon SA forms                blackwood       7-20
# 14                       microcarpa             manna wattle        1-3
# 15                          montana            mallee wattle        2-4
# 16                       myrtifolia            myrtle wattle        1-2
# 17                        notabilis           notable wattle        3-6
# 18                        paradoxa            kangaroo thorn        2-4
# 19                          pendula            weeping myall       6-10
# 20                       pravissima            Oven’s wattle        4-8
# 21                        pycnantha            golden wattle        4-6
# 22                       retinodes                   wirilda        5-8
# 23                           rigens                   nealie        2-4
# 24                         rupicola              rock wattle      1-2.5
# 25                         salicina        Broughton willow        4-10
# 26   sclerophylla var. sclerophylla         hard-leaf wattle        1-2
# 27                      verniciflua           varnish wattle        3-5
# 28         verticillata ssp ovoidea            prickly moses        2-4
# 29                      wilhelmiana             dwarf nealie        1-3
# ..                              ...                      ...        ...
# 212                  distichophylla                emu-grass        0.4
# 213               scaber var scaber       common wheat-grass      0.2-1
# 214                       nigricans           bottle washers    0.2-0.5
# 215                  labillardieri            tussock grass       0.3-1
# 216                       poiformis       blue tussock grass    0.6-1.2
# 217                      sieberiana       grey tussock grass    0.3-0.8
# 218                        scariosa          porcupine grass        0.6
# 219                       tasmanica         Tasman flax-lily    0.6-1.7
# 220                          moraea           butterfly flag    0.3-0.6
# 221                          effusa         scented mat-rush    0.2-0.5
# 222                      longifolia    spiny headed mat-rush      0.5-1
# 223         micrantha ssp micrantha  small-flowered mat-rush    0.2-0.8
# 224                     multiflorus             morning iris    0.3-0.6
# 225                    occidentalis         long purple flag        0.5
# 226                       australis       Austral grass tree      0.5-2
# 227                        strictum             vanilla lily        0.4
# 228                         bulbosa              native leek        0.3
# 229                       umbellata                milkmaids        0.3
# 230                       purpureum             purple bells    0.2-0.5
# 231                        asiatica                pennywort    0.1-0.4
# 232              anceps  syn: alata           angled lobelia    0.1-0.3
# 233                         pumilio              swamp mazus        0.1
# 234                       australis               river mint    0.3-0.8
# 235                          repens   creeping monkey flower        0.2
# 236                    fascicularis             tassel sedge          1
# 237                        gunniana           mountain sedge    0.2-0.7
# 238                           acuta        common spike rush    0.3-0.9
# 239                           filum         chaffy saw sedge      1-1.5
# 240                        inundata          swamp club rush        0.5
# 241                         validus          river club-rush    1.5-2.5
#
#     Spread (m) Rain (mm) Soil texture Soil pH Frost Flower colour  \
# 0          1-2       300     Sa,Lo,Cl     ANC     R             Y
# 1          2-6       350     Sa,Lo,Li     ANC     R             Y
# 2        1.5-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 3          2-4       200  Sa,Lo,Cl,Li     ANC     M             Y
# 4          2-4       350   Sa, Lo, Li     ANC     M             Y
# 5          4-6       550        Lo,Cl    AN/C     M             Y
# 6          1-3       350        Sa,Lo     ANC     R             Y
# 7          1-2       500     Sa,Lo,Cl      AN     R             Y
# 8          3-5       250        Sa,Lo     ANC     R             Y
# 9          3-6       450        Lo,Cl     ANC     R             Y
# 10         4-6       150  Sa,Lo,Cl Li     ANC     R             Y
# 11         1-3       500     Sa,Lo,Cl     ANC     M             Y
# 12         4-8       450        Sa,Lo     ANC     M             Y
# 13        4-10       500        Lo,Cl    AN/C     R             Y
# 14         2-4       300  Sa,Cl,Lo,Li     ANC     R             Y
# 15         2-5       325  Sa,Cl,Lo,Li     ANC     R             Y
# 16         1-2       500        Lo,Cl    AN/C     M             Y
# 17         3-4       250     Lo,Li,Cl     ANC     R             Y
# 18         3-4       300  Sa,Lo,Cl,Li     ANC     M             Y
# 19         6-8       250        Lo,Cl     ANC     M             Y
# 20         4-8       500     Sa,Lo,Cl    AN/C     M             Y
# 21         2-6       450     Sa,Lo,Cl     ANC     M             Y
# 22         3-7       500        Lo,Cl     ANC     M             Y
# 23         2-4       200  Sa,Lo,Cl,Li     ANC     R             Y
# 24       1-2.5       350  Sa,Lo,Cl,Li     ANC     R             Y
# 25         3-5       300        Lo,Cl     ANC     R             Y
# 26         2-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 27         3-5       450     Sa,Lo,Cl    AN/C     M             Y
# 28         1-3       600        Lo,Cl    AN/C     M             Y
# 29         2-3       250     Cl,Lo,Li     ANC     R             Y
# ..         ...       ...          ...     ...   ...           ...
# 212        1-2       350     Sa,Lo,Cl     ANC     R            Br
# 213    0.3-0.5       300     Sa,Lo,Cl     ANC     R            Cr
# 214        0.5       350    Sa, Lo,Cl     ANC     R         Br/Bl
# 215    0.3-0.7       400   Sa, Lo, Cl     ANC     R          G/Cr
# 216    0.5-1.5       350     Sa,Lo,Cl     ANC     R            Cr
# 217    0.3-0.8       500   Sa, Lo, Cl     ANC     M          G/Cr
# 218          1       300        Sa,Lo     ANC     M          G/Cr
# 219      0.5-2       650     Sa,Lo,Cl      AN     M             B
# 220      0.5-1       550     Sa,Lo,Cl     ANC     R             W
# 221    0.2-0.5       400       Sa, Lo     ANC     M          Cr/Y
# 222      0.5-1       500   Sa, Lo, Cl     ANC     R          Cr/Y
# 223    0.2-0.8       500   Sa, Lo, Cl     ANC     R             W
# 224      0.4-1       450     Sa,Lo,Cl     ANC     M             B
# 225        0.5       500       Lo, Cl      AN     M            Pu
# 226      0.6-1       500    Sa, Lo,Cl     ANC     R             W
# 227        0.4       400     Sa,Lo,Cl     ANC     M             P
# 228        0.3       500     Sa,Lo,Cl     ANC     M             Y
# 229        0.2       500     Sa,Lo,Cl     ANC     M             W
# 230        0.2       400     Sa,Lo,Cl     ANC     M         Pk, P
# 231      0.5-1       500     Sa,Lo,Cl     ANC     S             I
# 232      0.3-2       500        Lo,Cl    AN/C     M             P
# 233          1       600     Sa,Lo,Cl     ANC     M             P
# 234    0.3-1.5       600     Sa,Lo,Cl      AN     M             W
# 235        1-2       500     Sa,Lo,Cl     ANC     M             P
# 236          1       AQU     Sa,Lo,Cl     ANC     R             G
# 237      0.5-1       AQU     Sa,Lo,Cl     ANC     M            Br
# 238        2-3       AQU     Sa,Lo,Cl    AN/C     M            Br
# 239      1-1.5       550        Sa,Lo    AN/C     R             B
# 240      0.5-1       AQU     Sa,Lo,Cl     ANC     R            Br
# 241      1.5-3       AQU     Sa,Lo,Cl     ANC     R             B
#
#     Flower (time)
# 0            W,Sp
# 1            W,Sp
# 2            W,Sp
# 3            W,Sp
# 4           W, Sp
# 5            W,Sp
# 6            W,Sp
# 7            W,Sp
# 8            W,Sp
# 9              Sp
# 10             Sp
# 11             Sp
# 12           W,Sp
# 13           W,Sp
# 14           W,Sp
# 15             Sp
# 16             Sp
# 17           W,Sp
# 18             Sp
# 19         A,W,Sp
# 20           W,Sp
# 21           W,Sp
# 22           W,Sp
# 23           W,Sp
# 24           Sp,S
# 25           W,Sp
# 26             Sp
# 27         W,Sp,S
# 28         W,Sp,S
# 29           W,Sp
# ..            ...
# 212          Sp,S
# 213          W,Sp
# 214          Sp,S
# 215         Sp, S
# 216         Sp,Su
# 217         Sp, S
# 218          W,Sp
# 219          Sp,S
# 220          Sp,S
# 221          W,Sp
# 222         Sp, S
# 223        A,W,Sp
# 224            Sp
# 225            Sp
# 226        W,Sp,S
# 227            Sp
# 228            Sp
# 229            Sp
# 230             A
# 231            Sp
# 232          Sp,S
# 233          Sp,S
# 234            Sp
# 235          Sp,S
# 236          Sp,S
# 237          Sp,S
# 238          Sp,S
# 239             F
# 240            Sp
# 241           S,A
#
# [242 rows x 13 columns]

# %% [markdown]
# ##### API 2

# %%
#payload = {'id': 136330}
headers = {'content-type': 'application/json',
           'Authorization': 'uL2GeF6SOtfhELcBbrzQ50pQUy4l86RyF1vwqqoGCDVbrfN72m'}
r = requests.post('https://api.plant.id/plant_info', headers = headers)
print(r)
#json.loads(r.text)
# Out:
# <Response [405]>

# %%
# ?request

# %%
# Out:
#                                  Type            Genus Tube colour  \
# 0                    Trees and Shrubs          Acacia            B
# 1                    Trees and Shrubs          Acacia            B
# 2                    Trees and Shrubs          Acacia            B
# 3                    Trees and Shrubs          Acacia            B
# 4                    Trees and Shrubs          Acacia            B
# 5                    Trees and Shrubs          Acacia            B
# 6                    Trees and Shrubs          Acacia            B
# 7                    Trees and Shrubs          Acacia            B
# 8                    Trees and Shrubs          Acacia            B
# 9                    Trees and Shrubs          Acacia            B
# 10                   Trees and Shrubs          Acacia            B
# 11                   Trees and Shrubs          Acacia            B
# 12                   Trees and Shrubs          Acacia            B
# 13                   Trees and Shrubs          Acacia            B
# 14                   Trees and Shrubs          Acacia            B
# 15                   Trees and Shrubs          Acacia            B
# 16                   Trees and Shrubs          Acacia            B
# 17                   Trees and Shrubs          Acacia            B
# 18                   Trees and Shrubs          Acacia            B
# 19                   Trees and Shrubs          Acacia            B
# 20                   Trees and Shrubs          Acacia            B
# 21                   Trees and Shrubs          Acacia            B
# 22                   Trees and Shrubs          Acacia            B
# 23                   Trees and Shrubs          Acacia            B
# 24                   Trees and Shrubs          Acacia            B
# 25                   Trees and Shrubs          Acacia            B
# 26                   Trees and Shrubs          Acacia            B
# 27                   Trees and Shrubs          Acacia            B
# 28                   Trees and Shrubs          Acacia            B
# 29                   Trees and Shrubs          Acacia            B
# ..                                ...              ...         ...
# 212                           Grasses       Distichlis           B
# 213                           Grasses           Elymus           B
# 214                           Grasses       Enneapogon           B
# 215                           Grasses              Poa           B
# 216                           Grasses              Poa           B
# 217                           Grasses              Poa           B
# 218                           Grasses          Triodia           B
# 219         Other Strap-leaved Plants         Dianella           B
# 220         Other Strap-leaved Plants       Diplarrena           B
# 221         Other Strap-leaved Plants         Lomandra           B
# 222         Other Strap-leaved Plants         Lomandra           B
# 223         Other Strap-leaved Plants         Lomandra           B
# 224         Other Strap-leaved Plants    Orthrosanthus           B
# 225         Other Strap-leaved Plants       Patersonia           B
# 226         Other Strap-leaved Plants     Xanthorrhoea           B
# 227                  Bulbs and Lilies    Arthropodium            B
# 228                  Bulbs and Lilies         Bulbine            B
# 229                  Bulbs and Lilies       Burchardia           B
# 230                  Bulbs and Lilies       Calostemma           B
# 231  Aquatic and Riparian Zone Plants         Centella           G
# 232  Aquatic and Riparian Zone Plants         Lobelia            G
# 233  Aquatic and Riparian Zone Plants           Mazus            G
# 234  Aquatic and Riparian Zone Plants          Mentha            G
# 235  Aquatic and Riparian Zone Plants         Mimulus            G
# 236                 Rushes and Sedges            Carex           B
# 237                 Rushes and Sedges            Carex           B
# 238                 Rushes and Sedges       Eleocharis           B
# 239                 Rushes and Sedges           Gahnia           B
# 240                 Rushes and Sedges        Isolepis            B
# 241                 Rushes and Sedges  Schoenoplectus            B
#
#                      Botanical name              Common name Height (m)  \
# 0                         acinacea       round-leaved wattle        1-2
# 1                      argyrophylla        golden-grey mulga        1-5
# 2                      brachybotrya               grey mulga        2-4
# 3                       calamifolia                 wallowa         2-5
# 4                          farinosa             mealy wattle        1-2
# 5                        floribunda          gossamer wattle        4-7
# 6                     glandulicarpa         hairy-pod wattle        1-3
# 7                            gunnii       ploughshare wattle    0.2-0.8
# 8                         hakeoides             hakea wattle      2.5-4
# 9                          howittii            sticky wattle        4-8
# 10                         ligulata          umbrella wattle        2-4
# 11                          lineata          streaked wattle      0.5-3
# 12         longifolia var. sophorae           coastal wattle        2-5
# 13             melanoxylon SA forms                blackwood       7-20
# 14                       microcarpa             manna wattle        1-3
# 15                          montana            mallee wattle        2-4
# 16                       myrtifolia            myrtle wattle        1-2
# 17                        notabilis           notable wattle        3-6
# 18                        paradoxa            kangaroo thorn        2-4
# 19                          pendula            weeping myall       6-10
# 20                       pravissima            Oven’s wattle        4-8
# 21                        pycnantha            golden wattle        4-6
# 22                       retinodes                   wirilda        5-8
# 23                           rigens                   nealie        2-4
# 24                         rupicola              rock wattle      1-2.5
# 25                         salicina        Broughton willow        4-10
# 26   sclerophylla var. sclerophylla         hard-leaf wattle        1-2
# 27                      verniciflua           varnish wattle        3-5
# 28         verticillata ssp ovoidea            prickly moses        2-4
# 29                      wilhelmiana             dwarf nealie        1-3
# ..                              ...                      ...        ...
# 212                  distichophylla                emu-grass        0.4
# 213               scaber var scaber       common wheat-grass      0.2-1
# 214                       nigricans           bottle washers    0.2-0.5
# 215                  labillardieri            tussock grass       0.3-1
# 216                       poiformis       blue tussock grass    0.6-1.2
# 217                      sieberiana       grey tussock grass    0.3-0.8
# 218                        scariosa          porcupine grass        0.6
# 219                       tasmanica         Tasman flax-lily    0.6-1.7
# 220                          moraea           butterfly flag    0.3-0.6
# 221                          effusa         scented mat-rush    0.2-0.5
# 222                      longifolia    spiny headed mat-rush      0.5-1
# 223         micrantha ssp micrantha  small-flowered mat-rush    0.2-0.8
# 224                     multiflorus             morning iris    0.3-0.6
# 225                    occidentalis         long purple flag        0.5
# 226                       australis       Austral grass tree      0.5-2
# 227                        strictum             vanilla lily        0.4
# 228                         bulbosa              native leek        0.3
# 229                       umbellata                milkmaids        0.3
# 230                       purpureum             purple bells    0.2-0.5
# 231                        asiatica                pennywort    0.1-0.4
# 232              anceps  syn: alata           angled lobelia    0.1-0.3
# 233                         pumilio              swamp mazus        0.1
# 234                       australis               river mint    0.3-0.8
# 235                          repens   creeping monkey flower        0.2
# 236                    fascicularis             tassel sedge          1
# 237                        gunniana           mountain sedge    0.2-0.7
# 238                           acuta        common spike rush    0.3-0.9
# 239                           filum         chaffy saw sedge      1-1.5
# 240                        inundata          swamp club rush        0.5
# 241                         validus          river club-rush    1.5-2.5
#
#     Spread (m) Rain (mm) Soil texture Soil pH Frost Flower colour  \
# 0          1-2       300     Sa,Lo,Cl     ANC     R             Y
# 1          2-6       350     Sa,Lo,Li     ANC     R             Y
# 2        1.5-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 3          2-4       200  Sa,Lo,Cl,Li     ANC     M             Y
# 4          2-4       350   Sa, Lo, Li     ANC     M             Y
# 5          4-6       550        Lo,Cl    AN/C     M             Y
# 6          1-3       350        Sa,Lo     ANC     R             Y
# 7          1-2       500     Sa,Lo,Cl      AN     R             Y
# 8          3-5       250        Sa,Lo     ANC     R             Y
# 9          3-6       450        Lo,Cl     ANC     R             Y
# 10         4-6       150  Sa,Lo,Cl Li     ANC     R             Y
# 11         1-3       500     Sa,Lo,Cl     ANC     M             Y
# 12         4-8       450        Sa,Lo     ANC     M             Y
# 13        4-10       500        Lo,Cl    AN/C     R             Y
# 14         2-4       300  Sa,Cl,Lo,Li     ANC     R             Y
# 15         2-5       325  Sa,Cl,Lo,Li     ANC     R             Y
# 16         1-2       500        Lo,Cl    AN/C     M             Y
# 17         3-4       250     Lo,Li,Cl     ANC     R             Y
# 18         3-4       300  Sa,Lo,Cl,Li     ANC     M             Y
# 19         6-8       250        Lo,Cl     ANC     M             Y
# 20         4-8       500     Sa,Lo,Cl    AN/C     M             Y
# 21         2-6       450     Sa,Lo,Cl     ANC     M             Y
# 22         3-7       500        Lo,Cl     ANC     M             Y
# 23         2-4       200  Sa,Lo,Cl,Li     ANC     R             Y
# 24       1-2.5       350  Sa,Lo,Cl,Li     ANC     R             Y
# 25         3-5       300        Lo,Cl     ANC     R             Y
# 26         2-4       250  Sa,Lo,Cl,Li     ANC     R             Y
# 27         3-5       450     Sa,Lo,Cl    AN/C     M             Y
# 28         1-3       600        Lo,Cl    AN/C     M             Y
# 29         2-3       250     Cl,Lo,Li     ANC     R             Y
# ..         ...       ...          ...     ...   ...           ...
# 212        1-2       350     Sa,Lo,Cl     ANC     R            Br
# 213    0.3-0.5       300     Sa,Lo,Cl     ANC     R            Cr
# 214        0.5       350    Sa, Lo,Cl     ANC     R         Br/Bl
# 215    0.3-0.7       400   Sa, Lo, Cl     ANC     R          G/Cr
# 216    0.5-1.5       350     Sa,Lo,Cl     ANC     R            Cr
# 217    0.3-0.8       500   Sa, Lo, Cl     ANC     M          G/Cr
# 218          1       300        Sa,Lo     ANC     M          G/Cr
# 219      0.5-2       650     Sa,Lo,Cl      AN     M             B
# 220      0.5-1       550     Sa,Lo,Cl     ANC     R             W
# 221    0.2-0.5       400       Sa, Lo     ANC     M          Cr/Y
# 222      0.5-1       500   Sa, Lo, Cl     ANC     R          Cr/Y
# 223    0.2-0.8       500   Sa, Lo, Cl     ANC     R             W
# 224      0.4-1       450     Sa,Lo,Cl     ANC     M             B
# 225        0.5       500       Lo, Cl      AN     M            Pu
# 226      0.6-1       500    Sa, Lo,Cl     ANC     R             W
# 227        0.4       400     Sa,Lo,Cl     ANC     M             P
# 228        0.3       500     Sa,Lo,Cl     ANC     M             Y
# 229        0.2       500     Sa,Lo,Cl     ANC     M             W
# 230        0.2       400     Sa,Lo,Cl     ANC     M         Pk, P
# 231      0.5-1       500     Sa,Lo,Cl     ANC     S             I
# 232      0.3-2       500        Lo,Cl    AN/C     M             P
# 233          1       600     Sa,Lo,Cl     ANC     M             P
# 234    0.3-1.5       600     Sa,Lo,Cl      AN     M             W
# 235        1-2       500     Sa,Lo,Cl     ANC     M             P
# 236          1       AQU     Sa,Lo,Cl     ANC     R             G
# 237      0.5-1       AQU     Sa,Lo,Cl     ANC     M            Br
# 238        2-3       AQU     Sa,Lo,Cl    AN/C     M            Br
# 239      1-1.5       550        Sa,Lo    AN/C     R             B
# 240      0.5-1       AQU     Sa,Lo,Cl     ANC     R            Br
# 241      1.5-3       AQU     Sa,Lo,Cl     ANC     R             B
#
#     Flower (time)
# 0            W,Sp
# 1            W,Sp
# 2            W,Sp
# 3            W,Sp
# 4           W, Sp
# 5            W,Sp
# 6            W,Sp
# 7            W,Sp
# 8            W,Sp
# 9              Sp
# 10             Sp
# 11             Sp
# 12           W,Sp
# 13           W,Sp
# 14           W,Sp
# 15             Sp
# 16             Sp
# 17           W,Sp
# 18             Sp
# 19         A,W,Sp
# 20           W,Sp
# 21           W,Sp
# 22           W,Sp
# 23           W,Sp
# 24           Sp,S
# 25           W,Sp
# 26             Sp
# 27         W,Sp,S
# 28         W,Sp,S
# 29           W,Sp
# ..            ...
# 212          Sp,S
# 213          W,Sp
# 214          Sp,S
# 215         Sp, S
# 216         Sp,Su
# 217         Sp, S
# 218          W,Sp
# 219          Sp,S
# 220          Sp,S
# 221          W,Sp
# 222         Sp, S
# 223        A,W,Sp
# 224            Sp
# 225            Sp
# 226        W,Sp,S
# 227            Sp
# 228            Sp
# 229            Sp
# 230             A
# 231            Sp
# 232          Sp,S
# 233          Sp,S
# 234            Sp
# 235          Sp,S
# 236          Sp,S
# 237          Sp,S
# 238          Sp,S
# 239             F
# 240            Sp
# 241           S,A
#
# [242 rows x 13 columns]

# %%
df['plantid'] = np.nan

# %%
df['plantid'] = df.index

# %%
df_new
# Out:
#      plantid Tube colour                  Botanical name  \
# 0          0           B                       acinacea
# 1          1           B                    argyrophylla
# 2          2           B                    brachybotrya
# 3          3           B                     calamifolia
# 4          4           B                        farinosa
# 5          5           B                      floribunda
# 6          6           B                   glandulicarpa
# 7          7           B                          gunnii
# 8          8           B                       hakeoides
# 9          9           B                        howittii
# 10        10           B                        ligulata
# 11        11           B                         lineata
# 12        12           B        longifolia var. sophorae
# 13        13           B            melanoxylon SA forms
# 14        14           B                      microcarpa
# 15        15           B                         montana
# 16        16           B                      myrtifolia
# 17        17           B                       notabilis
# 18        18           B                       paradoxa
# 19        19           B                         pendula
# 20        20           B                      pravissima
# 21        21           B                       pycnantha
# 22        22           B                      retinodes
# 23        23           B                          rigens
# 24        24           B                        rupicola
# 25        25           B                        salicina
# 26        26           B  sclerophylla var. sclerophylla
# 27        27           B                     verniciflua
# 28        28           B        verticillata ssp ovoidea
# 29        29           B                     wilhelmiana
# ..       ...         ...                             ...
# 212      212           B                  distichophylla
# 213      213           B               scaber var scaber
# 214      214           B                       nigricans
# 215      215           B                  labillardieri
# 216      216           B                       poiformis
# 217      217           B                      sieberiana
# 218      218           B                        scariosa
# 219      219           B                       tasmanica
# 220      220           B                          moraea
# 221      221           B                          effusa
# 222      222           B                      longifolia
# 223      223           B         micrantha ssp micrantha
# 224      224           B                     multiflorus
# 225      225           B                    occidentalis
# 226      226           B                       australis
# 227      227           B                        strictum
# 228      228           B                         bulbosa
# 229      229           B                       umbellata
# 230      230           B                       purpureum
# 231      231           G                        asiatica
# 232      232           G              anceps  syn: alata
# 233      233           G                         pumilio
# 234      234           G                       australis
# 235      235           G                          repens
# 236      236           B                    fascicularis
# 237      237           B                        gunniana
# 238      238           B                           acuta
# 239      239           B                           filum
# 240      240           B                        inundata
# 241      241           B                         validus
#
#                  Common name Height (m) Spread (m) Rain (mm)  \
# 0        round-leaved wattle        1-2        1-2       300
# 1          golden-grey mulga        1-5        2-6       350
# 2                 grey mulga        2-4      1.5-4       250
# 3                   wallowa         2-5        2-4       200
# 4               mealy wattle        1-2        2-4       350
# 5            gossamer wattle        4-7        4-6       550
# 6           hairy-pod wattle        1-3        1-3       350
# 7         ploughshare wattle    0.2-0.8        1-2       500
# 8               hakea wattle      2.5-4        3-5       250
# 9              sticky wattle        4-8        3-6       450
# 10           umbrella wattle        2-4        4-6       150
# 11           streaked wattle      0.5-3        1-3       500
# 12            coastal wattle        2-5        4-8       450
# 13                 blackwood       7-20       4-10       500
# 14              manna wattle        1-3        2-4       300
# 15             mallee wattle        2-4        2-5       325
# 16             myrtle wattle        1-2        1-2       500
# 17            notable wattle        3-6        3-4       250
# 18            kangaroo thorn        2-4        3-4       300
# 19             weeping myall       6-10        6-8       250
# 20             Oven’s wattle        4-8        4-8       500
# 21             golden wattle        4-6        2-6       450
# 22                   wirilda        5-8        3-7       500
# 23                    nealie        2-4        2-4       200
# 24               rock wattle      1-2.5      1-2.5       350
# 25         Broughton willow        4-10        3-5       300
# 26          hard-leaf wattle        1-2        2-4       250
# 27            varnish wattle        3-5        3-5       450
# 28             prickly moses        2-4        1-3       600
# 29              dwarf nealie        1-3        2-3       250
# ..                       ...        ...        ...       ...
# 212                emu-grass        0.4        1-2       350
# 213       common wheat-grass      0.2-1    0.3-0.5       300
# 214           bottle washers    0.2-0.5        0.5       350
# 215           tussock grass       0.3-1    0.3-0.7       400
# 216       blue tussock grass    0.6-1.2    0.5-1.5       350
# 217       grey tussock grass    0.3-0.8    0.3-0.8       500
# 218          porcupine grass        0.6          1       300
# 219         Tasman flax-lily    0.6-1.7      0.5-2       650
# 220           butterfly flag    0.3-0.6      0.5-1       550
# 221         scented mat-rush    0.2-0.5    0.2-0.5       400
# 222    spiny headed mat-rush      0.5-1      0.5-1       500
# 223  small-flowered mat-rush    0.2-0.8    0.2-0.8       500
# 224             morning iris    0.3-0.6      0.4-1       450
# 225         long purple flag        0.5        0.5       500
# 226       Austral grass tree      0.5-2      0.6-1       500
# 227             vanilla lily        0.4        0.4       400
# 228              native leek        0.3        0.3       500
# 229                milkmaids        0.3        0.2       500
# 230             purple bells    0.2-0.5        0.2       400
# 231                pennywort    0.1-0.4      0.5-1       500
# 232           angled lobelia    0.1-0.3      0.3-2       500
# 233              swamp mazus        0.1          1       600
# 234               river mint    0.3-0.8    0.3-1.5       600
# 235   creeping monkey flower        0.2        1-2       500
# 236             tassel sedge          1          1       AQU
# 237           mountain sedge    0.2-0.7      0.5-1       AQU
# 238        common spike rush    0.3-0.9        2-3       AQU
# 239         chaffy saw sedge      1-1.5      1-1.5       550
# 240          swamp club rush        0.5      0.5-1       AQU
# 241          river club-rush    1.5-2.5      1.5-3       AQU
#
#                                  Type            Genus Soil pH Frost
# 0                    Trees and Shrubs          Acacia      ANC     R
# 1                    Trees and Shrubs          Acacia      ANC     R
# 2                    Trees and Shrubs          Acacia      ANC     R
# 3                    Trees and Shrubs          Acacia      ANC     M
# 4                    Trees and Shrubs          Acacia      ANC     M
# 5                    Trees and Shrubs          Acacia     AN/C     M
# 6                    Trees and Shrubs          Acacia      ANC     R
# 7                    Trees and Shrubs          Acacia       AN     R
# 8                    Trees and Shrubs          Acacia      ANC     R
# 9                    Trees and Shrubs          Acacia      ANC     R
# 10                   Trees and Shrubs          Acacia      ANC     R
# 11                   Trees and Shrubs          Acacia      ANC     M
# 12                   Trees and Shrubs          Acacia      ANC     M
# 13                   Trees and Shrubs          Acacia     AN/C     R
# 14                   Trees and Shrubs          Acacia      ANC     R
# 15                   Trees and Shrubs          Acacia      ANC     R
# 16                   Trees and Shrubs          Acacia     AN/C     M
# 17                   Trees and Shrubs          Acacia      ANC     R
# 18                   Trees and Shrubs          Acacia      ANC     M
# 19                   Trees and Shrubs          Acacia      ANC     M
# 20                   Trees and Shrubs          Acacia     AN/C     M
# 21                   Trees and Shrubs          Acacia      ANC     M
# 22                   Trees and Shrubs          Acacia      ANC     M
# 23                   Trees and Shrubs          Acacia      ANC     R
# 24                   Trees and Shrubs          Acacia      ANC     R
# 25                   Trees and Shrubs          Acacia      ANC     R
# 26                   Trees and Shrubs          Acacia      ANC     R
# 27                   Trees and Shrubs          Acacia     AN/C     M
# 28                   Trees and Shrubs          Acacia     AN/C     M
# 29                   Trees and Shrubs          Acacia      ANC     R
# ..                                ...              ...     ...   ...
# 212                           Grasses       Distichlis     ANC     R
# 213                           Grasses           Elymus     ANC     R
# 214                           Grasses       Enneapogon     ANC     R
# 215                           Grasses              Poa     ANC     R
# 216                           Grasses              Poa     ANC     R
# 217                           Grasses              Poa     ANC     M
# 218                           Grasses          Triodia     ANC     M
# 219         Other Strap-leaved Plants         Dianella      AN     M
# 220         Other Strap-leaved Plants       Diplarrena     ANC     R
# 221         Other Strap-leaved Plants         Lomandra     ANC     M
# 222         Other Strap-leaved Plants         Lomandra     ANC     R
# 223         Other Strap-leaved Plants         Lomandra     ANC     R
# 224         Other Strap-leaved Plants    Orthrosanthus     ANC     M
# 225         Other Strap-leaved Plants       Patersonia      AN     M
# 226         Other Strap-leaved Plants     Xanthorrhoea     ANC     R
# 227                  Bulbs and Lilies    Arthropodium      ANC     M
# 228                  Bulbs and Lilies         Bulbine      ANC     M
# 229                  Bulbs and Lilies       Burchardia     ANC     M
# 230                  Bulbs and Lilies       Calostemma     ANC     M
# 231  Aquatic and Riparian Zone Plants         Centella     ANC     S
# 232  Aquatic and Riparian Zone Plants         Lobelia     AN/C     M
# 233  Aquatic and Riparian Zone Plants           Mazus      ANC     M
# 234  Aquatic and Riparian Zone Plants          Mentha       AN     M
# 235  Aquatic and Riparian Zone Plants         Mimulus      ANC     M
# 236                 Rushes and Sedges            Carex     ANC     R
# 237                 Rushes and Sedges            Carex     ANC     M
# 238                 Rushes and Sedges       Eleocharis    AN/C     M
# 239                 Rushes and Sedges           Gahnia    AN/C     R
# 240                 Rushes and Sedges        Isolepis      ANC     R
# 241                 Rushes and Sedges  Schoenoplectus      ANC     R
#
# [242 rows x 11 columns]

# %%
df =

# %% [markdown]
# ### PLANT_INFO TABLE

# %%
df_new = df[['plantid', 'Tube colour', 'Botanical name', 'Common name', 
             'Height (m)', 'Spread (m)', 'Rain (mm)', 'Type', 'Genus','Soil pH','Frost']]
df_new.to_csv('PLANT_INFO.CSV',index = False)

# %%
{
  "varieties": "list",
  "sub_species": "list",
  "scientific_name": "string",
  "order": {
    "slug": "string",
    "name": "string",
    "link": "string",
    "id": "integer"
  },
  "native_status": "string",
  "main_species": {
    "year": "string",
    "type": "string",
    "synonym": "string",
    "status": "string",
    "specifications": {
      "toxicity": "string",
      "shape_and_orientation": "string",
      "regrowth_rate": "string",
      "nitrogen_fixation": "string",
      "max_height_at_base_age": {
        "ft": "float",
        "cm": "float"
      },
      "mature_height": {
        "ft": "float",
        "cm": "float"
      },
      "low_growing_grass": "string",
      "lifespan": "string",
      "leaf_retention": "string",
      "known_allelopath": "string",
      "growth_rate": "string",
      "growth_period": "string",
      "growth_habit": "string",
      "growth_form": "string",
      "fire_resistance": "string",
      "fall_conspicuous": "string",
      "coppice_potential": "string",
      "c_n_ratio": "string",
      "bloat": "string"
    },
    "sources": [
      {
        "species_id": "integer",
        "source_url": "string",
        "name": "string",
        "last_update": "string"
      }
    ],
    "soils_adaptation": {
      "medium": "string",
      "fine": "string",
      "coarse": "string"
    },
    "slug": "string",
    "seed": {
      "vegetative_spread_rate": "string",
      "small_grain": "string",
      "seeds_per_pound": "string",
      "seedling_vigor": "string",
      "seed_spread_rate": "string",
      "commercial_availability": "string",
      "bloom_period": "string"
    },
    "scientific_name": "string",
    "propagation": {
      "tubers": "string",
      "sprigs": "string",
      "sod": "string",
      "seed": "string",
      "cuttings": "string",
      "corms": "string",
      "container": "string",
      "bulbs": "string",
      "bare_root": "string"
    },
    "products": {
      "veneer": "string",
      "pulpwood": "string",
      "protein_potential": "string",
      "post": "string",
      "palatable_human": "string",
      "palatable_graze_animal": "string",
      "palatable_browse_animal": "string",
      "nursery_stock": "string",
      "naval_store": "string",
      "lumber": "string",
      "fuelwood": "string",
      "fodder": "string",
      "christmas_tree": "string",
      "berry_nut_seed": "string"
    },
    "native_status": "string",
    "main_species_id": "string",
    "is_main_species": "string",
    "images": [
      {
        "url": "string"
      }
    ],
    "id": "integer",
    "growth": {
      "temperature_minimum": {
        "deg_f": "float",
        "deg_c": "float"
      },
      "shade_tolerance": "string",
      "salinity_tolerance": "string",
      "root_depth_minimum": {
        "inches": "float",
        "cm": "float"
      },
      "resprout_ability": "string",
      "precipitation_minimum": {
        "inches": "float",
        "cm": "float"
      },
      "precipitation_maximum": {
        "inches": "float",
        "cm": "float"
      },
      "planting_density_minimum": {
        "sqm": "float",
        "acre": "float"
      },
      "planting_density_maximum": {
        "sqm": "float",
        "acre": "float"
      },
      "ph_minimum": "float",
      "ph_maximum": "float",
      "moisture_use": "string",
      "hedge_tolerance": "string",
      "frost_free_days_minimum": "float",
      "fire_tolerance": "string",
      "fertility_requirement": "string",
      "drought_tolerance": "string",
      "cold_stratification_required": "string",
      "caco_3_tolerance": "string",
      "anaerobic_tolerance": "string"
    },
    "fruit_or_seed": {
      "seed_persistence": "string",
      "seed_period_end": "string",
      "seed_period_begin": "string",
      "seed_abundance": "string",
      "conspicuous": "string",
      "color": "string"
    },
    "foliage": {
      "texture": "string",
      "porosity_winter": "string",
      "porosity_summer": "string",
      "color": "string"
    },
    "flower": {
      "conspicuous": "string",
      "color": "string"
    },
    "family_common_name": "string",
    "duration": "string",
    "complete_data": "string",
    "common_name": "string",
    "bibliography": "string",
    "author": "string"
  },
  "images": [
    {
      "url": "string"
    }
  ],
  "id": "integer",
  "hybrids": "list",
  "genus": {
    "slug": "string",
    "name": "string",
    "link": "string",
    "id": "integer"
  },
  "forms": "list",
  "family_common_name": "string",
  "family": {
    "slug": "string",
    "name": "string",
    "link": "string",
    "id": "integer",
    "common_name": "string"
  },
  "duration": "string",
  "division": {
    "slug": "string",
    "name": "string",
    "link": "string",
    "id": "integer"
  },
  "cultivars": "list",
  "common_name": "string",
  "class": {
    "slug": "string",
    "name": "string",
    "link": "string",
    "id": "integer"
  }
}
# Out:
# {'varieties': 'list',
#  'sub_species': 'list',
#  'scientific_name': 'string',
#  'order': {'slug': 'string',
#   'name': 'string',
#   'link': 'string',
#   'id': 'integer'},
#  'native_status': 'string',
#  'main_species': {'year': 'string',
#   'type': 'string',
#   'synonym': 'string',
#   'status': 'string',
#   'specifications': {'toxicity': 'string',
#    'shape_and_orientation': 'string',
#    'regrowth_rate': 'string',
#    'nitrogen_fixation': 'string',
#    'max_height_at_base_age': {'ft': 'float', 'cm': 'float'},
#    'mature_height': {'ft': 'float', 'cm': 'float'},
#    'low_growing_grass': 'string',
#    'lifespan': 'string',
#    'leaf_retention': 'string',
#    'known_allelopath': 'string',
#    'growth_rate': 'string',
#    'growth_period': 'string',
#    'growth_habit': 'string',
#    'growth_form': 'string',
#    'fire_resistance': 'string',
#    'fall_conspicuous': 'string',
#    'coppice_potential': 'string',
#    'c_n_ratio': 'string',
#    'bloat': 'string'},
#   'sources': [{'species_id': 'integer',
#     'source_url': 'string',
#     'name': 'string',
#     'last_update': 'string'}],
#   'soils_adaptation': {'medium': 'string',
#    'fine': 'string',
#    'coarse': 'string'},
#   'slug': 'string',
#   'seed': {'vegetative_spread_rate': 'string',
#    'small_grain': 'string',
#    'seeds_per_pound': 'string',
#    'seedling_vigor': 'string',
#    'seed_spread_rate': 'string',
#    'commercial_availability': 'string',
#    'bloom_period': 'string'},
#   'scientific_name': 'string',
#   'propagation': {'tubers': 'string',
#    'sprigs': 'string',
#    'sod': 'string',
#    'seed': 'string',
#    'cuttings': 'string',
#    'corms': 'string',
#    'container': 'string',
#    'bulbs': 'string',
#    'bare_root': 'string'},
#   'products': {'veneer': 'string',
#    'pulpwood': 'string',
#    'protein_potential': 'string',
#    'post': 'string',
#    'palatable_human': 'string',
#    'palatable_graze_animal': 'string',
#    'palatable_browse_animal': 'string',
#    'nursery_stock': 'string',
#    'naval_store': 'string',
#    'lumber': 'string',
#    'fuelwood': 'string',
#    'fodder': 'string',
#    'christmas_tree': 'string',
#    'berry_nut_seed': 'string'},
#   'native_status': 'string',
#   'main_species_id': 'string',
#   'is_main_species': 'string',
#   'images': [{'url': 'string'}],
#   'id': 'integer',
#   'growth': {'temperature_minimum': {'deg_f': 'float', 'deg_c': 'float'},
#    'shade_tolerance': 'string',
#    'salinity_tolerance': 'string',
#    'root_depth_minimum': {'inches': 'float', 'cm': 'float'},
#    'resprout_ability': 'string',
#    'precipitation_minimum': {'inches': 'float', 'cm': 'float'},
#    'precipitation_maximum': {'inches': 'float', 'cm': 'float'},
#    'planting_density_minimum': {'sqm': 'float', 'acre': 'float'},
#    'planting_density_maximum': {'sqm': 'float', 'acre': 'float'},
#    'ph_minimum': 'float',
#    'ph_maximum': 'float',
#    'moisture_use': 'string',
#    'hedge_tolerance': 'string',
#    'frost_free_days_minimum': 'float',
#    'fire_tolerance': 'string',
#    'fertility_requirement': 'string',
#    'drought_tolerance': 'string',
#    'cold_stratification_required': 'string',
#    'caco_3_tolerance': 'string',
#    'anaerobic_tolerance': 'string'},
#   'fruit_or_seed': {'seed_persistence': 'string',
#    'seed_period_end': 'string',
#    'seed_period_begin': 'string',
#    'seed_abundance': 'string',
#    'conspicuous': 'string',
#    'color': 'string'},
#   'foliage': {'texture': 'string',
#    'porosity_winter': 'string',
#    'porosity_summer': 'string',
#    'color': 'string'},
#   'flower': {'conspicuous': 'string', 'color': 'string'},
#   'family_common_name': 'string',
#   'duration': 'string',
#   'complete_data': 'string',
#   'common_name': 'string',
#   'bibliography': 'string',
#   'author': 'string'},
#  'images': [{'url': 'string'}],
#  'id': 'integer',
#  'hybrids': 'list',
#  'genus': {'slug': 'string',
#   'name': 'string',
#   'link': 'string',
#   'id': 'integer'},
#  'forms': 'list',
#  'family_common_name': 'string',
#  'family': {'slug': 'string',
#   'name': 'string',
#   'link': 'string',
#   'id': 'integer',
#   'common_name': 'string'},
#  'duration': 'string',
#  'division': {'slug': 'string',
#   'name': 'string',
#   'link': 'string',
#   'id': 'integer'},
#  'cultivars': 'list',
#  'common_name': 'string',
#  'class': {'slug': 'string',
#   'name': 'string',
#   'link': 'string',
#   'id': 'integer'}}
